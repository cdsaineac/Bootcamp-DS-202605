# %% [markdown]
# # Introducción a las apis

# %% [markdown]
# ## ¿Qué son las APIs y cómo funcionan?
#
# ---
#
# Una API (Application Programming Interface) o Interfaz de Programación de Aplicaciones es esencialmente un intermediario.
# Permite que dos aplicaciones de software se comuniquen entre sí. Imagina un camarero en un restaurante:
# tú (una aplicación) le dices al camarero (la API) lo que quieres pedir (una solicitud),
# el camarero va a la cocina (otro sistema) y trae tu comida (la respuesta).
#
# En el contexto de las APIs, esto se traduce en:
#
# 1.  **Solicitud (Request):** Una aplicación envía una solicitud a otra aplicación a través de su API. Esta solicitud especifica qué acción se desea realizar (por ejemplo, obtener datos, enviar información).
# 2.  **Respuesta (Response):** La aplicación que recibe la solicitud procesa la petición y envía una respuesta de vuelta a la aplicación solicitante. Esta respuesta contiene los datos solicitados o un mensaje indicando el resultado de la acción.
#
# Existen diferentes estilos o arquitecturas para diseñar APIs, siendo **REST (Representational State Transfer)** uno de los más comunes. Las APIs RESTful utilizan métodos estándar de HTTP (como GET para obtener datos, POST para enviar datos, PUT para actualizar y DELETE para eliminar) para interactuar con recursos.
#
# ## Ejemplos de APIs en la vida real:
# ---
#
# *   Cuando inicias sesión en un sitio web usando tu cuenta de Google o Facebook, estás utilizando sus APIs de autenticación.
# *   Las aplicaciones del clima obtienen los datos meteorológicos de APIs proporcionadas por servicios meteorológicos.
# *   Las aplicaciones de mapas utilizan APIs para obtener información de ubicación, rutas y puntos de interés.

# %% [markdown]
# ## Conexión a la api
# ---
# https://api-colombia.com/

# %%
pip install requests

# %%
import requests

base_url = "https://api-colombia.com/"
endpoint = "/api/v1/TypicalDish"
response1 =  requests.get(base_url + endpoint)

response1.json()
# Out:
# [{'id': 1,
#   'name': 'Bandeja Paisa',
#   'description': 'La bandeja paisa es el orgullo de la cocina paisa y uno de los platos más emblemáticos de Colombia. Originaria de Antioquia y los departamentos vecinos de Caldas, Risaralda y Quindío, refleja la tradición y riqueza cultural de esta región.',
#   'ingredients': 'Frijoles, arroz, carne molida, chicharrón, huevo, plátano maduro, chorizo, arepa, aguacate.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/1. Bandeja Paisa.jpg',
#   'departmentId': 2,
#   'department': {'id': 2,
#    'name': 'Antioquia',
#    'description': 'Antioquia es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Medellín, la segunda ciudad más poblada del país. Está ubicado al noroccidente colombiano, en las regiones Andina y Caribe, limitando al norte con el mar Caribe (océano Atlántico), Córdoba y Bolívar, al este con Santander y Boyacá, al sur con Caldas y Risaralda, y al oeste con Chocó. Con unos 6 500 000 habitantes en 2015 es el departamento más poblado, y con 63 600 km², el sexto más extenso, superado por Amazonas, Vichada, Caquetá, Meta y Guainía.',
#    'cityCapitalId': 12,
#    'municipalities': 125,
#    'surface': 63612,
#    'population': 6887306,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 2,
#   'name': 'Sancocho Antioqueño',
#   'description': 'El sancocho antioqueño es un plato típico de Antioquia, preparado con carne, plátano verde, mazorca, papa, yuca y condimentos, servido con arroz, aguacate y arepas, ideal para reuniones familiares y festividades.',
#   'ingredients': 'Carne de res, pollo, plátano verde, yuca, papa, mazorca, cilantro.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/2. Sancocho Antioqueno.jpg',
#   'departmentId': 2,
#   'department': {'id': 2,
#    'name': 'Antioquia',
#    'description': 'Antioquia es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Medellín, la segunda ciudad más poblada del país. Está ubicado al noroccidente colombiano, en las regiones Andina y Caribe, limitando al norte con el mar Caribe (océano Atlántico), Córdoba y Bolívar, al este con Santander y Boyacá, al sur con Caldas y Risaralda, y al oeste con Chocó. Con unos 6 500 000 habitantes en 2015 es el departamento más poblado, y con 63 600 km², el sexto más extenso, superado por Amazonas, Vichada, Caquetá, Meta y Guainía.',
#    'cityCapitalId': 12,
#    'municipalities': 125,
#    'surface': 63612,
#    'population': 6887306,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 3,
#   'name': 'Ajiaco Santafereño',
#   'description': ' Sopa tradicional de Bogotá y el altiplano cundiboyacense, caracterizada por el uso de diferentes tipos de papa y la guasca como hierba aromática.',
#   'ingredients': 'Papas sabaneras, criollas y pastusas, Pechuga de pollo, Mazorca, Guasca, Crema de leche, Alcaparras, Arroz blanco',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/3. Ajiaco Santafereno.png',
#   'departmentId': 5,
#   'department': {'id': 5,
#    'name': 'Bogotá',
#    'description': 'Bogotá, oficialmente Bogotá, Distrito Capital\u200b (antiguamente, Santafé de Bogotá),\u200b es la capital de la República de Colombia y del departamento de Cundinamarca. Está administrada como distrito capital, y goza de autonomía para la gestión de sus intereses dentro de los límites de la Constitución y la ley.12\u200b18\u200b A diferencia de los demás distritos de Colombia, Bogotá es una entidad territorial de primer orden, con las atribuciones administrativas que la ley confiere a los departamentos',
#    'cityCapitalId': 167,
#    'municipalities': 1,
#    'surface': 1139,
#    'population': 8906342,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 4,
#   'name': 'Sancocho de Gallina',
#   'description': 'Sopa tradicional del Valle del Cauca, ideal para reuniones familiares y celebraciones.',
#   'ingredients': 'Gallina, Plátano verde, Yuca, Papa, Mazorca, Cilantro, Cebolla, Ajo',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/4. Sancocho de gallina.jpeg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 5,
#   'name': 'Lechona Tolimense',
#   'description': 'Preparación típica para celebraciones, consiste en cerdo relleno con arroz y arvejas, cocinado lentamente en horno de barro.',
#   'ingredients': 'Carne de cerdo, Arroz, Arvejas, Aliños (ajo, cebolla, comino), Piel de cerdo crocante',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/5. Lechona Tolimense.png',
#   'departmentId': 30,
#   'department': {'id': 30,
#    'name': 'Tolima',
#    'description': 'Tolima es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Ibagué. Está ubicado en el centro-oeste del país, en la región andina, limitando al norte con Caldas, al este con Cundinamarca, al sur con Huila y Cauca; y al oeste con Valle del Cauca, Quindío y Risaralda.6\u200b El río Magdalena atraviesa Tolima de sur a norte.',
#    'cityCapitalId': 1069,
#    'municipalities': 47,
#    'surface': 23562,
#    'population': 1346935,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 6,
#   'name': 'Arepas de Huevo',
#   'description': 'Arepas fritas rellenas de huevo, típicas de la región caribeña, ideales para desayunos o meriendas.',
#   'ingredients': 'Harina de maíz, Huevo, Aceite para freír, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/6. Arepas de Huevo.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 7,
#   'name': 'Mazamorra Chiquita',
#   'description': 'Sopa densa hecha a base de maíz, legumbres y carne.',
#   'ingredients': 'Maíz pelado, Habas, Arvejas, Tocino o costilla de cerdo, Cilantro',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/7. Mazamorra Chiquita.jpg',
#   'departmentId': 7,
#   'department': {'id': 7,
#    'name': 'Boyacá',
#    'description': 'Boyacá es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Tunja. Está ubicado en el centro-este del país, en la región andina, limitando al norte con Santander y Norte de Santander, al noreste con Venezuela y Arauca, al este con Casanare,8\u200b9\u200b al sur con Cundinamarca y al occidente el río Magdalena con los departamentos de Caldas y Antioquia.',
#    'cityCapitalId': 217,
#    'municipalities': 123,
#    'surface': 23189,
#    'population': 1259601,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 8,
#   'name': 'Sobrebarriga al Horno',
#   'description': 'Carne de res cocida al horno, acompañada con papas, arroz y ensalada.',
#   'ingredients': 'Sobrebarriga de res, Ajo, cebolla y tomate, Papa criolla, Arroz blanco',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/8. Sobrebarriga al Horno.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 9,
#   'name': 'Arroz Atollado',
#   'description': 'Plato típico con arroz cocido mezclado con cerdo, pollo y verduras',
#   'ingredients': 'Arroz, Costilla de cerdo, Pollo, Hogao, Arvejas y zanahoria',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/9. Arroz Atollado.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 10,
#   'name': 'Tamal Tolimense',
#   'description': 'Masa de maíz rellena de carne y vegetales, envuelta en hojas de plátano.',
#   'ingredients': 'Harina de maíz, Carne de cerdo o pollo, Papa, Zanahoria, Hojas de plátano',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/10.Tamal Tolimense.jpg',
#   'departmentId': 30,
#   'department': {'id': 30,
#    'name': 'Tolima',
#    'description': 'Tolima es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Ibagué. Está ubicado en el centro-oeste del país, en la región andina, limitando al norte con Caldas, al este con Cundinamarca, al sur con Huila y Cauca; y al oeste con Valle del Cauca, Quindío y Risaralda.6\u200b El río Magdalena atraviesa Tolima de sur a norte.',
#    'cityCapitalId': 1069,
#    'municipalities': 47,
#    'surface': 23562,
#    'population': 1346935,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 11,
#   'name': 'Arroz con Coco',
#   'description': 'Arroz dulce o salado preparado con leche de coco.',
#   'ingredients': 'Arroz, Coco rallado, Azúcar (para dulce) o sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/11. Arroz con Coco.jpg',
#   'departmentId': 6,
#   'department': {'id': 6,
#    'name': 'Bolívar',
#    'description': 'Bolívar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cartagena de Indias, sede de la asamblea departamental, mientras que en Turbaco se encuentra la sede de la gobernación. Está ubicado en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al noreste con Atlántico, al este con Magdalena y Cesar, al sureste con Santander, al suroeste con Antioquia y al oeste con Córdoba y Sucre.',
#    'cityCapitalId': 210,
#    'municipalities': 45,
#    'surface': 25978,
#    'population': 2236603,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 12,
#   'name': 'Cabrito Asado',
#   'description': 'Carne de cabro sazonada y asada lentamente, típico de Santander.',
#   'ingredients': 'Carne de cabro, Limón, Ajol Comino, Sal y pimienta',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/12. Cabrito Asado.jpg',
#   'departmentId': 28,
#   'department': {'id': 28,
#    'name': 'Santander',
#    'description': 'Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bucaramanga. Está ubicado al noreste del país, en la región andina, limitando al norte con Cesar y Norte de Santander, al este y sur con Boyacá, al oeste con Antioquia y al noroeste con Bolívar.7\u200b Con unos 2 280 908 habitantes en 2018 es el sexto departamento por población. Recibe su nombre en alusión a Francisco de Paula Santander, prócer de la independencia de la Nueva Granada',
#    'cityCapitalId': 915,
#    'municipalities': 87,
#    'surface': 30537,
#    'population': 2324090,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 13,
#   'name': 'Pepitoria',
#   'description': 'Guiso preparado con vísceras de cabrito, arroz y especias.',
#   'ingredients': 'Vísceras de cabro, Arroz, Cebolla, Ajo, Comino y achiote',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/13. Pepitoria.jpg',
#   'departmentId': 28,
#   'department': {'id': 28,
#    'name': 'Santander',
#    'description': 'Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bucaramanga. Está ubicado al noreste del país, en la región andina, limitando al norte con Cesar y Norte de Santander, al este y sur con Boyacá, al oeste con Antioquia y al noroeste con Bolívar.7\u200b Con unos 2 280 908 habitantes en 2018 es el sexto departamento por población. Recibe su nombre en alusión a Francisco de Paula Santander, prócer de la independencia de la Nueva Granada',
#    'cityCapitalId': 915,
#    'municipalities': 87,
#    'surface': 30537,
#    'population': 2324090,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 14,
#   'name': 'Cuy Asado',
#   'description': 'Raza especial de cuy, asado sobre brasas, acompañado de papas.',
#   'ingredients': 'Cuy, Papas, Ajo, Comino, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/14. Cuy Asado.jpg',
#   'departmentId': 22,
#   'department': {'id': 22,
#    'name': 'Nariño',
#    'description': 'Nariño es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es San Juan de Pasto. Está ubicado en el extremo suroeste del país, en las regiones andina y pacífica, limitando al norte con Cauca, al este con Putumayo, al sur con las provincias de Esmeraldas, Carchi y Sucumbíos de la República de Ecuador y al oeste con el océano Pacífico. Fue fundado en 1904 con la unión de lo que eran las provincias de Pasto y Obando.',
#    'cityCapitalId': 769,
#    'municipalities': 64,
#    'surface': 33268,
#    'population': 1629181,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 15,
#   'name': 'Empanadas de Pipián',
#   'description': 'Empanadas rellenas de un guiso de papa y maní.',
#   'ingredients': 'Masa de maíz, Papa, Maní, Achiote, Comino',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/15. Empanadas de Pipian.png',
#   'departmentId': 11,
#   'department': {'id': 11,
#    'name': 'Cauca',
#    'description': 'Cauca es uno de los treinta y dos departamentos que, junto al Distrito Capital de Bogotá, conforman la República de Colombia. Su capital y ciudad más poblada es Popayán. Está ubicado al suroccidente del país entre las regiones andina y pacífica, limitando al norte con Valle del Cauca y Tolima, al oriente con Huila, al suroriente con Caquetá, al sur con Putumayo y Nariño, y al noroccidente con el océano Pacífico',
#    'cityCapitalId': 399,
#    'municipalities': 41,
#    'surface': 29308,
#    'population': 1516018,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 16,
#   'name': 'Arroz de Lisa',
#   'description': 'Arroz cocido con pescado lisa, típico de Barranquilla.',
#   'ingredients': 'Arroz, Lisa (pescado), Suero costeño, Plátano maduro, Yuca',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/16. Arroz de Lisa.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 17,
#   'name': 'Butifarra Soledeña',
#   'description': 'Embutido de cerdo, típico de Soledad, Atlántico.',
#   'ingredients': 'Carne de cerdo, Ajo, Pimienta, Comino, SalCarne de cerdo, Ajo, Pimienta, Comino, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/17. Butifarra Soledena.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 18,
#   'name': 'Asado Huilense',
#   'description': 'Carne de cerdo marinada y asada lentamente en hojas de plátano.',
#   'ingredients': 'Carne de cerdo, Hojas de plátano, Ajo y cebolla, Sal y pimienta, Cerveza (opcional)',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/18. Asado Huilense.jpg',
#   'departmentId': 18,
#   'department': {'id': 18,
#    'name': 'Huila',
#    'description': 'Huila es uno de los treinta y dos departamentos que junto con Bogotá, Distrito Capital, conforman la República de Colombia. Su capital y ciudad más poblada es Neiva. Está ubicado al suroeste del país, en la región andina, limitando al norte con Tolima y Cundinamarca, al este con Meta, al sur con Caquetá y al oeste con Cauca.',
#    'cityCapitalId': 657,
#    'municipalities': 37,
#    'surface': 19890,
#    'population': 1140932,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 19,
#   'name': 'Champús',
#   'description': 'Bebida espesa preparada con maíz, frutas y especias.',
#   'ingredients': 'Maíz molido, Lulo, Piña, Panela, Canela y clavos',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/19. Champus.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 20,
#   'name': 'Sopa de Carantanta',
#   'description': 'Sopa hecha con carantanta (corteza de maíz tostada) y leche.',
#   'ingredients': 'Carantanta, Leche, Papa, Cilantro, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/20. Sopa de carantanta.png',
#   'departmentId': 11,
#   'department': {'id': 11,
#    'name': 'Cauca',
#    'description': 'Cauca es uno de los treinta y dos departamentos que, junto al Distrito Capital de Bogotá, conforman la República de Colombia. Su capital y ciudad más poblada es Popayán. Está ubicado al suroccidente del país entre las regiones andina y pacífica, limitando al norte con Valle del Cauca y Tolima, al oriente con Huila, al suroriente con Caquetá, al sur con Putumayo y Nariño, y al noroccidente con el océano Pacífico',
#    'cityCapitalId': 399,
#    'municipalities': 41,
#    'surface': 29308,
#    'population': 1516018,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 21,
#   'name': 'Caldo de Pirarucú',
#   'description': 'Sopa con el pescado pirarucú, típico del Amazonas.',
#   'ingredients': 'Pirarucú (pescado), Papa, Yuca, Cebolla, Cilantro',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/21. Caldo de pirarucu.png',
#   'departmentId': 1,
#   'department': {'id': 1,
#    'name': 'Amazonas',
#    'description': 'Amazonas es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Leticia. Está ubicado en el extremo sur del país, en gran parte al sur de la línea ecuatorial, en la región Amazonia. Limita al norte con Caquetá y Vaupés, al este con el estado brasileño del mismo nombre, al sur con el departamento peruano de Loreto y al oeste con Putumayo. Con 110 000 km² es el departamento más extenso de Colombia, con unos 75\xa0000 habitantes en 2015, el cuarto menos poblado —por delante de Vichada, Vaupés y Guainía, el menos poblado— y con 0.68\xa0hab/km², el tercero menos densamente poblado, por delante de Vichada y Guainía, el menos densamente poblado.',
#    'cityCapitalId': 1,
#    'municipalities': 2,
#    'surface': 109665,
#    'population': 82068,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 22,
#   'name': 'Chivo Guisado',
#   'description': 'Guiso de carne de chivo cocida con especias y aliños.',
#   'ingredients': 'Carne de chivo, Ajo y cebolla, Tomate, Comino, Achote',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/22. Chivo Guisado.png',
#   'departmentId': 19,
#   'department': {'id': 19,
#    'name': 'La Guajira',
#    'description': 'La Guajira (en wayuunaiki: Wajiira o Karibyczonn) es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. La traducción más precisa de su nombre sería «Caribe hermoso» y en wayunaiki antiguo Karive Pala «Mar Caribe» también puede significar Mar del Caribe. Su capital es Riohacha. Está ubicado en el extremo noreste del país, en la región Caribe, limitando al norte y este con el mar Caribe (océano Atlántico), al sureste con el estado Venezolano del Zulia, al sur con el departamento del Cesar y al oeste con el del Magdalena.',
#    'cityCapitalId': 694,
#    'municipalities': 15,
#    'surface': 20848,
#    'population': 1002394,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 23,
#   'name': 'Tacacho con Cecina',
#   'description': 'Plátano asado y aplastado, acompañado de carne seca.',
#   'ingredients': 'Plátano verde, Carne de cecina (seca), Aceite o manteca, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/23. Tacacho con cecina.png',
#   'departmentId': 1,
#   'department': {'id': 1,
#    'name': 'Amazonas',
#    'description': 'Amazonas es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Leticia. Está ubicado en el extremo sur del país, en gran parte al sur de la línea ecuatorial, en la región Amazonia. Limita al norte con Caquetá y Vaupés, al este con el estado brasileño del mismo nombre, al sur con el departamento peruano de Loreto y al oeste con Putumayo. Con 110 000 km² es el departamento más extenso de Colombia, con unos 75\xa0000 habitantes en 2015, el cuarto menos poblado —por delante de Vichada, Vaupés y Guainía, el menos poblado— y con 0.68\xa0hab/km², el tercero menos densamente poblado, por delante de Vichada y Guainía, el menos densamente poblado.',
#    'cityCapitalId': 1,
#    'municipalities': 2,
#    'surface': 109665,
#    'population': 82068,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 24,
#   'name': 'Arepa ocañera',
#   'description': 'Arepa pequeña y crocante, hecha con maíz y mantequilla.',
#   'ingredients': 'Maíz, mantequilla y sal.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/24. Arepa Ocanera.jpg',
#   'departmentId': 23,
#   'department': {'id': 23,
#    'name': 'Norte de Santander',
#    'description': 'Norte de Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es la ciudad de Cúcuta. Es una entidad territorial que goza de autonomía para la administración de los asuntos seccionales y la planificación y promoción del desarrollo económico y social dentro de su territorio, tiene una extensión de 22.648 km², que equivalen al 1.91% del territorio nacional, ubicado en la región nororiental de Colombia. Limita al norte y al este con los estados de Zulia y Táchira de Venezuela, al sur con los departamentos de Boyacá y Santander, y al oeste con Santander y Cesar.',
#    'cityCapitalId': 870,
#    'municipalities': 40,
#    'surface': 21658,
#    'population': 1651278,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 25,
#   'name': 'Arroz clavado',
#   'description': 'Es un arroz preparado con ingredientes básicos como arroz, aceite, ajo, cebolla, y caldo, que se cocina a fuego lento para formar una capa crujiente en el fondo de la olla. Es un plato típico del Chocó, servido tradicionalmente con pescados, mariscos, o carne.',
#   'ingredients': 'Arroz, Ajo, Cebolla, Caldo o agua, Aceite o manteca y Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/25. Arroz clavado.jpg',
#   'departmentId': 13,
#   'department': {'id': 13,
#    'name': 'Chocó',
#    'description': 'Chocó es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Quibdó. Está ubicado al noroeste del país, en las regiones andina y Pacífico, limitando al norte con la República de Panamá y el mar Caribe (océano Atlántico), al este con Antioquia y Risaralda, al sur con Valle del Cauca y al oeste con el océano Pacífico.',
#    'cityCapitalId': 467,
#    'municipalities': 31,
#    'surface': 46530,
#    'population': 553519,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 26,
#   'name': 'Mote de queso',
#   'description': 'Sopa de ñame con queso costeño y suero.',
#   'ingredients': 'Ñame, queso costeño, suero, cebolla y ajo.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/26. Mote de queso.jpg',
#   'departmentId': 14,
#   'department': {'id': 14,
#    'name': 'Córdoba',
#    'description': 'Córdoba es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Montería. Está ubicado al norte del país, en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al este con los departamentos de Sucre y Bolívar, y al sur y oeste con el departamento de Antioquia. Con 1\xa0710\xa0000 habitantes en 2015, es el octavo departamento más poblado, por detrás de Bogotá, Antioquia, Valle del Cauca, Cundinamarca, Atlántico, Santander y Bolívar. Fue creado por medio de la Ley 9 del 18 de diciembre de 1951, reglamentada el 18 de junio de 1952.',
#    'cityCapitalId': 498,
#    'municipalities': 30,
#    'surface': 25020,
#    'population': 1856496,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 27,
#   'name': 'Cayeye',
#   'description': 'Puré de banano verde con queso costeño.',
#   'ingredients': 'Banano verde, queso costeño, mantequilla y sal.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/27. Cayeye.jpg',
#   'departmentId': 20,
#   'department': {'id': 20,
#    'name': 'Magdalena',
#    'description': 'Magdalena es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Santa Marta. Está ubicado al noreste del país, en la región Caribe. Limita al norte con el mar Caribe, al este con La Guajira, al sureste con Cesar, al sur y oeste con Bolívar y al oeste con Atlántico. Fue uno de los originales nueve estados que conformaron los Estados Unidos de Colombia. El departamento toma el nombre del río Magdalena. Entre sus municipios se encuentra Aracataca, el lugar de nacimiento del premio Nobel de literatura Gabriel García Márquez.',
#    'cityCapitalId': 709,
#    'municipalities': 30,
#    'surface': 23188,
#    'population': 1463427,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 28,
#   'name': 'Arepa guajira',
#   'description': 'Arepa grande hecha de maíz o yuca, típica de La Guajira.',
#   'ingredients': 'Maíz o yuca, sal y agua.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/28. Arepa Guajira.jpg',
#   'departmentId': 19,
#   'department': {'id': 19,
#    'name': 'La Guajira',
#    'description': 'La Guajira (en wayuunaiki: Wajiira o Karibyczonn) es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. La traducción más precisa de su nombre sería «Caribe hermoso» y en wayunaiki antiguo Karive Pala «Mar Caribe» también puede significar Mar del Caribe. Su capital es Riohacha. Está ubicado en el extremo noreste del país, en la región Caribe, limitando al norte y este con el mar Caribe (océano Atlántico), al sureste con el estado Venezolano del Zulia, al sur con el departamento del Cesar y al oeste con el del Magdalena.',
#    'cityCapitalId': 694,
#    'municipalities': 15,
#    'surface': 20848,
#    'population': 1002394,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 29,
#   'name': 'Ternera a la llanera',
#   'description': 'Carne de res asada a la brasa, sazonada con sal y acompañada de yuca, plátano y arepas de maíz.',
#   'ingredients': 'Carne de res, sal, yuca, plátano, arepas',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/29. Ternera a la llanera.png',
#   'departmentId': 3,
#   'department': {'id': 3,
#    'name': 'Arauca',
#    'description': 'Arauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es la homónima Arauca. Está ubicado al este del país, en la región Orinoquía, limitando al norte y este con Venezuela, al sur con Vichada y Casanare, y al oeste con Boyacá',
#    'cityCapitalId': 143,
#    'municipalities': 7,
#    'surface': 23818,
#    'population': 304978,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 30,
#   'name': 'Natilla',
#   'description': 'Plato tipico de caldas,se trata de un flan hecho con leche, fécula de maíz, panela rallada, canela y a veces pasas. Es un postre muy popular en Colombia y se suele comer en Navidad. ',
#   'ingredients': 'Leche, Harina de maíz o maicena, Panela o azúcar, Canela en rama, Coco rallado (opcional), Uvas pasas (opcional)',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/30. Natilla.png',
#   'departmentId': 8,
#   'department': {'id': 8,
#    'name': 'Caldas',
#    'description': 'Caldas es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Manizales. Está ubicado en el centro del país, en la región andina, limitando al norte con Antioquia, al noreste con Boyacá, al este con Cundinamarca, al sur con Tolima y Risaralda y al oeste con Risaralda. Con 7888\xa0km² es el quinto departamento menos extenso —por delante de Risaralda, Atlántico, Quindío y San Andrés y Providencia, el menos extenso— y con 125 hab/km², el sexto más densamente poblado, por detrás de San Andrés y Providencia, Atlántico, Quindío, Risaralda y Valle del Cauca',
#    'cityCapitalId': 337,
#    'municipalities': 27,
#    'surface': 7888,
#    'population': 1036455,
#    'phonePrefix': '6',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 31,
#   'name': 'Pescado muquiao',
#   'description': 'Se trata de una tradicion que consiste en sazonar el pescado con sal, envolverlo en hojas de plátano previamente ahumadas y cocinarlo en un horno subterráneo. Este método se acompaña con yuca, plátano asado y arroz, mientras que la bebida típica es la chicha.',
#   'ingredients': 'pescado, sal gruesa al gusto, hojas de plátano frescas y limpias, yuca, plátanos verdes o maduros, arroz blanco cocido, chicha (opcional).',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/31. Pescado Muquiao.jpg',
#   'departmentId': 9,
#   'department': {'id': 9,
#    'name': 'Caquetá',
#    'description': 'Caquetá es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Florencia. Está ubicado al sur del país, en la región Amazonia, limitando al norte con Meta y Guaviare, al noreste con Vaupés, al sur con Amazonas y Putumayo, y al oeste con Cauca y Huila. Con 88 965 km² es el tercer departamento más extenso —por detrás de Amazonas y Vichada—. Todos sus municipios forman parte de los territorios focalizados',
#    'cityCapitalId': 364,
#    'municipalities': 16,
#    'surface': 88965,
#    'population': 419275,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 32,
#   'name': 'Pisillo de chigüiro',
#   'description': 'Plato tradicional que se elabora desmechando la carne de este roedor típico de la región',
#   'ingredients': 'ajo, cebolla, pimentón y otros condimentos. Se sirve con arroz, plátano y yuca.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/32. Pisillo de chiguiro.png',
#   'departmentId': 10,
#   'department': {'id': 10,
#    'name': 'Casanare',
#    'description': 'Casanare es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Yopal. Está ubicado en la región Orinoquía, limitando al norte con Arauca, al este con Vichada, al sur con Meta y al oeste con Boyacá. Con 44 490\xa0km² es el décimo departamento más extenso —por detrás de Amazonas, Vichada',
#    'cityCapitalId': 380,
#    'municipalities': 19,
#    'surface': 44640,
#    'population': 442068,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 33,
#   'name': 'Chicharrón',
#   'description': 'El chicharrón es un acompañante frecuente en el Cesar, preparado con carne de cerdo frita hasta quedar crujiente. Se sirve con arroz, arepas y otros acompañantes.',
#   'ingredients': 'Carne de cerdo, sal al gusto, ajo, pimienta al gusto y aceite',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/33. Chicharron.jpg',
#   'departmentId': 12,
#   'department': {'id': 12,
#    'name': 'Cesar',
#    'description': 'Cesar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Valledupar. Está ubicado al noreste del país, en las regiones Andina y Caribe, limitando al norte con La Guajira, al este con el Estado Zulia de Venezuela, al sureste con Norte de Santander, al sur con Santander, al suroeste con Bolívar y al oeste con Magdalena.',
#    'cityCapitalId': 441,
#    'municipalities': 25,
#    'surface': 22905,
#    'population': 1341697,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 34,
#   'name': 'Sancocho de pescado',
#   'description': 'Este caldo espeso se prepara con pescado fresco, yuca, plátano, arroz y otros ingredientes locales. Es común en las zonas ribereñas de Guainía.',
#   'ingredients': 'Pescado fresco, yuca, plátano verde, papas, mazorca de maíz, cebolla, ajo, pimentón, cilantro, comino, sal, pimienta, aceite y agua para cocinar el caldo',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/34. Sancocho de pescado.png',
#   'departmentId': 16,
#   'department': {'id': 16,
#    'name': 'Guainía',
#    'description': 'Guainía (idioma yurí: "Tierra de muchas aguas") es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Inírida. Está ubicado al este del país, en la región Amazonia, limitando al norte con Vichada, al este con el Estado de Amazonas de Venezuela, al sur con el brasileño del mismo nombre, al suroeste con Vaupés y al oeste con Guaviare. Con 72 238\xa0km² es el quinto departamento más extenso —por detrás de Amazonas, Vichada, Caquetá y Meta—, con unos 50 000 habitantes en 2020, el segundo menos poblado, y con 0,56 hab/km², el menos densamente poblado. Antiguamente era una comisaría, pero desde 1991 es oficialmente un departamento',
#    'cityCapitalId': 644,
#    'municipalities': 2,
#    'surface': 72238,
#    'population': 52061,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 35,
#   'name': 'Casabe',
#   'description': 'Es una tortilla grande y delgada hecha a base de yuca brava, un alimento ancestral preparado por las comunidades indígenas. Se sirve como acompañamiento para otros platos o se come solo.',
#   'ingredients': 'Harina de yuca o mandioca',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/35. Casabe.png',
#   'departmentId': 17,
#   'department': {'id': 17,
#    'name': 'Guaviare',
#    'description': 'Guaviare es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es San José del Guaviare. Está ubicado en la región Amazonia, limitando al norte con Meta, al noreste con Vichada, al oeste con Guainía y al sur con Vaupés y Caquetá. Con 77,276 hab. según estimaciones del DANE,5\u200b es el quinto departamento menos poblado —por delante de Amazonas, San Andrés y Providencia, Guainía y Vaupés— y con 2,04 hab/km², el quinto menos densamente poblado, por delante de Vaupés, Amazonas, Vichada y Guainía, el menos densamente poblado',
#    'cityCapitalId': 654,
#    'municipalities': 4,
#    'surface': 53460,
#    'population': 90357,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 36,
#   'name': 'Pan de arroz',
#   'description': 'Un panecillo suave y crujiente por fuera, hecho a base de masa de arroz, queso y mantequilla, muy popular como merienda o desayuno.',
#   'ingredients': 'Arroz, queso costeño o queso campesino, harina de maíz, mantequilla, huevos, leche, sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/36. Pan de arroz.png',
#   'departmentId': 21,
#   'department': {'id': 21,
#    'name': 'Meta',
#    'description': 'Meta es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Villavicencio. Está ubicado en el centro del país, en la región Orinoquía, limitando al norte con Bogotá, Distrito Capital, Cundinamarca y Casanare, al este con Vichada, al sur con Guaviare y Caquetá, y al oeste con Huila. Con 85 635 km² es el cuarto departamento más extenso —por detrás de Amazonas, Vichada y Caquetá',
#    'cityCapitalId': 740,
#    'municipalities': 29,
#    'surface': 85635,
#    'population': 1080706,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 37,
#   'name': 'Maito de pescado',
#   'description': 'El maito consiste en un pescado fresco, como tilapia, bocachico o bagre, que se sazona con sal y especias, se envuelve en hojas de bijao y se cocina al carbón o al vapor.',
#   'ingredients': 'Pescado fresco, hojas de bijao, cebolla larga, ajo, limón, sal (al gusto), pimienta, aceite y aji amazonico',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/37. Maito de pescado.png',
#   'departmentId': 24,
#   'department': {'id': 24,
#    'name': 'Putumayo',
#    'description': 'Putumayo (Quechua: Putumayu) es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Mocoa y su ciudad más poblada es Puerto Asís. Está ubicado al suroeste del país, en la región Amazónica, limitando al norte con Cauca y Caquetá, al este con Amazonas, al sur con Perú y Ecuador, y al oeste con Nariño. La mayoría de sus municipios hace parte de los territorios focalizados',
#    'cityCapitalId': 872,
#    'municipalities': 13,
#    'surface': 24885,
#    'population': 369064,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 38,
# ...
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 56,
#   'name': 'Chorizo antioqueño',
#   'description': 'Embutido de carne de cerdo sazonada, servido tradicionalmente con arepa y limón.',
#   'ingredients': 'Carne de cerdo, ajo, sal, comino, pimienta.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/56. Chorizo antioqueno.jpg',
#   'departmentId': 2,
#   'department': {'id': 2,
#    'name': 'Antioquia',
#    'description': 'Antioquia es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Medellín, la segunda ciudad más poblada del país. Está ubicado al noroccidente colombiano, en las regiones Andina y Caribe, limitando al norte con el mar Caribe (océano Atlántico), Córdoba y Bolívar, al este con Santander y Boyacá, al sur con Caldas y Risaralda, y al oeste con Chocó. Con unos 6 500 000 habitantes en 2015 es el departamento más poblado, y con 63 600 km², el sexto más extenso, superado por Amazonas, Vichada, Caquetá, Meta y Guainía.',
#    'cityCapitalId': 12,
#    'municipalities': 125,
#    'surface': 63612,
#    'population': 6887306,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 57,
#   'name': 'Mamona',
#   'description': 'Carne de res (ternera) asada lentamente al carbón, típica de los llanos orientales.',
#   'ingredients': 'Ternera, sal, ajo, especias.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/57. Mamona.png',
#   'departmentId': 21,
#   'department': {'id': 21,
#    'name': 'Meta',
#    'description': 'Meta es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Villavicencio. Está ubicado en el centro del país, en la región Orinoquía, limitando al norte con Bogotá, Distrito Capital, Cundinamarca y Casanare, al este con Vichada, al sur con Guaviare y Caquetá, y al oeste con Huila. Con 85 635 km² es el cuarto departamento más extenso —por detrás de Amazonas, Vichada y Caquetá',
#    'cityCapitalId': 740,
#    'municipalities': 29,
#    'surface': 85635,
#    'population': 1080706,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 58,
#   'name': 'Empanada de maíz',
#   'description': 'Masa de maíz rellena de carne, papa o queso, frita hasta quedar crujiente.',
#   'ingredients': 'Harina de maíz, carne, papa, cebolla, comin',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/58. Empanada de maiz.png',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 59,
#   'name': 'Arroz con pollo',
#   'description': 'Plato colorido de arroz con pollo desmenuzado y vegetales.',
#   'ingredients': 'Arroz, pollo, zanahoria, cebolla, arvejas, pimientos.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/59. Arroz con pollo.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 60,
#   'name': 'Pan de yuca',
#   'description': 'Panecillo suave hecho con harina de yuca y queso.',
#   'ingredients': 'Harina de yuca, queso, mantequilla, huevo.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/60. Pan de yuca.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 61,
#   'name': 'Merengón',
#   'description': 'Postre crujiente de merengue, crema y frutas frescas como guanábana o fresas.',
#   'ingredients': 'Claras de huevo, azúcar, crema de leche, frutas.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/61. Merengon.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 62,
#   'name': 'Breva con arequipe',
#   'description': 'Postre dulce de brevas cocidas en almíbar, rellenas con arequipe.',
#   'ingredients': 'Brevas, azúcar, canela, arequipe.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/62. Brevas con arequipe.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 63,
#   'name': 'Agua de panela',
#   'description': 'Bebida caliente o fría preparada con panela disuelta en agua.',
#   'ingredients': 'Panela, agua, limón',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/63. Agua de panela.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 64,
#   'name': 'Carimañola',
#   'description': 'Fritura hecha de masa de yuca rellena de carne, queso o pollo.',
#   'ingredients': 'Yuca, carne, queso, huevo.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/64. Carimanola.jpg',
#   'departmentId': 6,
#   'department': {'id': 6,
#    'name': 'Bolívar',
#    'description': 'Bolívar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cartagena de Indias, sede de la asamblea departamental, mientras que en Turbaco se encuentra la sede de la gobernación. Está ubicado en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al noreste con Atlántico, al este con Magdalena y Cesar, al sureste con Santander, al suroeste con Antioquia y al oeste con Córdoba y Sucre.',
#    'cityCapitalId': 210,
#    'municipalities': 45,
#    'surface': 25978,
#    'population': 2236603,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 65,
#   'name': 'Gelatina de pata',
#   'description': 'Dulce hecho a base de patas de res cocidas, con sabor a panela.',
#   'ingredients': 'Pata de res, panela, canela.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/65. Gelatina de pata.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 66,
#   'name': 'Lengua sudada',
#   'description': 'Lengua de res cocida a fuego lento con una salsa espesa de tomate y especias.',
#   'ingredients': 'Lengua de res, tomate, cebolla, ajo, especias.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/66. Lengua sudada.png',
#   'departmentId': 28,
#   'department': {'id': 28,
#    'name': 'Santander',
#    'description': 'Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bucaramanga. Está ubicado al noreste del país, en la región andina, limitando al norte con Cesar y Norte de Santander, al este y sur con Boyacá, al oeste con Antioquia y al noroeste con Bolívar.7\u200b Con unos 2 280 908 habitantes en 2018 es el sexto departamento por población. Recibe su nombre en alusión a Francisco de Paula Santander, prócer de la independencia de la Nueva Granada',
#    'cityCapitalId': 915,
#    'municipalities': 87,
#    'surface': 30537,
#    'population': 2324090,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 67,
#   'name': 'Pollo asado',
#   'description': 'Pollo marinado y asado al carbón, acompañado de papa y ensalada.',
#   'ingredients': 'Pollo, ajo, sal, pimienta, especias.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/67. Pollo asado.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 68,
#   'name': 'Cazuela de mariscos',
#   'description': 'Sopa cremosa de mariscos, preparada con leche de coco y vegetales.',
#   'ingredients': 'Mariscos variados, leche de coco, cebolla, ajo, pimientos.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/68. Cazuela de mariscos.jpg',
#   'departmentId': 6,
#   'department': {'id': 6,
#    'name': 'Bolívar',
#    'description': 'Bolívar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cartagena de Indias, sede de la asamblea departamental, mientras que en Turbaco se encuentra la sede de la gobernación. Está ubicado en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al noreste con Atlántico, al este con Magdalena y Cesar, al sureste con Santander, al suroeste con Antioquia y al oeste con Córdoba y Sucre.',
#    'cityCapitalId': 210,
#    'municipalities': 45,
#    'surface': 25978,
#    'population': 2236603,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}}]

# %%
import requests

base_url = "https://stephen-king-api.onrender.com/"
endpoint = "api/books"
response = requests.get(base_url + endpoint)

if response.status_code == 200:
  print("Conexión exitosa a la API. Codigo de estado:", response.status_code)
else:
  print("Conexión fallida a la API. Codigo de estado", response.status_code)
# Out:
# Conexión exitosa a la API. Codigo de estado: 200

# %%
response.json()
# Out:
# {'data': [{'id': 1,
#    'Year': 1974,
#    'Title': 'Carrie',
#    'handle': 'carrie',
#    'Publisher': 'Doubleday',
#    'ISBN': '978-0-385-08695-0',
#    'Pages': 199,
#    'Notes': [''],
#    'created_at': '2023-11-13T23:48:47.848Z',
#    'villains': [{'name': 'Tina Blake',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/4'},
#     {'name': 'Cindi',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/14'},
#     {'name': 'Myra Crewes',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/16'},
#     {'name': 'Billy deLois',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/25'},
#     {'name': 'Kenny Garson',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/38'},
#     {'name': 'Mary Lila Grace',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/44'},
#     {'name': 'Christine Hargensen',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/49'},
#     {'name': 'Vic Mooney',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/75'},
#     {'name': 'The Mortimer Snerds',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/77'},
#     {'name': 'Billy Nolan',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/80'},
#     {'name': 'Elenor Richmond',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/90'},
#     {'name': 'Rachel Spies',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/94'},
#     {'name': 'Jackie Talbot',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/99'},
#     {'name': 'Donna and Mary Lila Grace Thibodeau',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/102'},
#     {'name': 'Jessica Upshaw',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/108'},
#     {'name': 'Norma Watson',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/109'},
#     {'name': 'Margaret White',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/113'}]},
#   {'id': 2,
#    'Year': 1975,
#    'Title': "Salem's Lot",
#    'handle': 'salem-s-lot',
#    'Publisher': 'Doubleday',
#    'ISBN': '978-0-385-00751-1',
#    'Pages': 439,
#    'Notes': ['Nominee, World Fantasy Award, 1976[2]'],
#    'created_at': '2023-11-13T23:48:48.098Z',
#    'villains': [{'name': 'Kurt Barlow',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/2'},
#     {'name': 'Richard Straker',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/98'}]},
#   {'id': 3,
#    'Year': 1977,
#    'Title': 'The Shining',
#    'handle': 'the-shining',
#    'Publisher': 'Doubleday',
#    'ISBN': '978-0-385-12167-5',
#    'Pages': 447,
#    'Notes': ['Runner-up (4th place), Locus Award for Best Fantasy Novel, 1978[2]'],
#    'created_at': '2023-11-13T23:48:48.219Z',
#    'villains': [{'name': 'Horace M. Derwent',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/26'},
#     {'name': 'Delbert Grady',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/45'},
#     {'name': 'Jack Torrance',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/106'}]},
#   {'id': 4,
#    'Year': 1977,
#    'Title': 'Rage',
#    'handle': 'rage',
#    'Publisher': 'Signet Books',
#    'ISBN': '978-0-451-07645-8',
#    'Pages': 211,
#    'Notes': ['Published under pseudonym Richard Bachman'],
#    'created_at': '2023-11-13T23:48:48.339Z',
#    'villains': []},
#   {'id': 5,
#    'Year': 1978,
#    'Title': 'The Stand',
#    'handle': 'the-stand',
#    'Publisher': 'Doubleday',
#    'ISBN': '978-0-385-12168-2',
#    'Pages': 823,
#    'Notes': ['Nominee, World Fantasy Award, 1979',
#     'Runner-up (15th place), Locus Award, 1979[2]'],
#    'created_at': '2023-11-13T23:48:48.477Z',
#    'villains': [{'name': 'Donald Merwin Elbert',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/34'},
#     {'name': 'Randall Flagg',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/37'},
#     {'name': 'Lloyd Henreid',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/51'},
#     {'name': 'The Kid',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/62'},
#     {'name': 'Harold Lauder',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/64'},
#     {'name': 'Rat Man',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/87'}]},
#   {'id': 6,
#    'Year': 1979,
#    'Title': 'The Long Walk',
#    'handle': 'the-long-walk',
#    'Publisher': 'Signet Books',
#    'ISBN': '978-0-451-08754-6',
#    'Pages': 384,
#    'Notes': ['Published under pseudonym Richard Bachman'],
#    'created_at': '2023-11-13T23:48:48.608Z',
#    'villains': [{'name': 'Randall Flagg',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/37'},
#     {'name': 'The Major',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/70'}]},
#   {'id': 7,
#    'Year': 1979,
#    'Title': 'The Dead Zone',
#    'handle': 'the-dead-zone',
#    'Publisher': 'Viking Press',
#    'ISBN': '978-0-670-26077-5',
#    'Pages': 428,
#    'Notes': ['Runner-up (2nd place), Locus Award for Best Fantasy Novel, 1980[2]'],
#    'created_at': '2023-11-13T23:48:48.753Z',
#    'villains': [{'name': 'Frank Dodd',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/29'},
#     {'name': 'Henrietta Dodd',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/30'},
#     {'name': 'Malcolm Janus',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/71'},
#     {'name': 'Sonny Elliman',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/93'},
#     {'name': 'Greg Stillson',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/97'},
#     {'name': "The Devil's Dozen",
#      'url': 'https://stephen-king-api.onrender.com/api/villain/100'}]},
#   {'id': 8,
#    'Year': 1980,
#    'Title': 'Firestarter',
#    'handle': 'firestarter',
#    'Publisher': 'Viking Press',
#    'ISBN': '978-0-670-31541-3',
#    'Pages': 426,
#    'Notes': ['Nominee, British Fantasy Award’s August Derleth Award, 1981',
#     'Runner-up (8th place), Locus Award for Best Science Fiction Novel, 1981[2]'],
#    'created_at': '2023-11-13T23:48:48.876Z',
#    'villains': [{'name': 'James Hollister',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/54'},
#     {'name': 'Charlie McGee',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/73'},
#     {'name': 'John Rainbird',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/86'}]},
#   {'id': 9,
#    'Year': 1981,
#    'Title': 'Roadwork',
#    'handle': 'roadwork',
#    'Publisher': 'Signet Books',
#    'ISBN': '978-0-451-09668-5',
#    'Pages': 274,
#    'Notes': ['Published under pseudonym Richard Bachman'],
#    'created_at': '2023-11-13T23:48:49.005Z',
#    'villains': []},
#   {'id': 10,
#    'Year': 1981,
#    'Title': 'Cujo',
#    'handle': 'cujo',
#    'Publisher': 'Viking Press',
#    'ISBN': '978-0-670-45193-7',
#    'Pages': 319,
#    'Notes': ['Winner, British Fantasy Award’s August Derleth Award, 1982',
#     'Runner-up (21st place), Locus Award for Best Fantasy Novel, 1982[2]'],
#    'created_at': '2023-11-13T23:48:49.131Z',
#    'villains': [{'name': 'Cujo',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/19'}]},
#   {'id': 11,
#    'Year': 1982,
#    'Title': 'The Running Man',
#    'handle': 'the-running-man',
#    'Publisher': 'Signet Books',
#    'ISBN': '978-0-451-11508-9',
#    'Pages': 219,
#    'Notes': ['Published under pseudonym Richard Bachman'],
#    'created_at': '2023-11-13T23:48:49.252Z',
#    'villains': [{'name': 'The Gladiators',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/42'},
#     {'name': 'Damon Killian',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/63'}]},
#   {'id': 12,
#    'Year': 1982,
#    'Title': 'The Dark Tower: The Gunslinger',
#    'handle': 'the-dark-tower-the-gunslinger',
#    'Publisher': 'Grant',
#    'ISBN': '978-0-937986-50-9',
#    'Pages': 224,
#    'Notes': [''],
#    'created_at': '2023-11-13T23:48:49.374Z',
#    'villains': [{'name': 'Marten Broadcloak',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/10'},
#     {'name': 'Crimson King',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/17'},
#     {'name': 'Randall Flagg',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/37'},
#     {'name': 'Sylvia Pittston',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/84'}]},
#   {'id': 13,
#    'Year': 1983,
#    'Title': 'Christine',
#    'handle': 'christine',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-22026-7',
#    'Pages': 526,
#    'Notes': ['Runner-up (6th place), Locus Award for Best Fantasy Novel, 1984[2]'],
#    'created_at': '2023-11-13T23:48:49.505Z',
#    'villains': [{'name': 'Christine (car)',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/11'},
#     {'name': 'Arnie Cunningham',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/20'}]},
#   {'id': 14,
#    'Year': 1983,
#    'Title': 'Pet Sematary',
#    'handle': 'pet-sematary',
#    'Publisher': 'Doubleday',
#    'ISBN': '978-0-385-18244-7',
#    'Pages': 374,
#    'Notes': ['Nominee, World Fantasy Award, 1984',
#     'Runner-up (7th place), Locus Award for Best Fantasy Novel, 1984[2]'],
#    'created_at': '2023-11-13T23:48:49.637Z',
#    'villains': [{'name': 'Winston Church',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/13'},
#     {'name': 'Gage Creed',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/15'},
#     {'name': 'Victor Pascow',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/83'},
#     {'name': 'Wendigo',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/110'}]},
#   {'id': 15,
#    'Year': 1983,
#    'Title': 'Cycle of the Werewolf',
#    'handle': 'cycle-of-the-werewolf',
#    'Publisher': 'Land of Enchantment',
#    'ISBN': '978-0-960-38282-8',
#    'Pages': 127,
#    'Notes': ['Illustrated by Bernie Wrightson'],
#    'created_at': '2023-11-13T23:48:49.757Z',
#    'villains': [{'name': 'Lester Lowe',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/68'}]},
#   {'id': 16,
#    'Year': 1984,
#    'Title': 'The Talisman',
#    'handle': 'the-talisman',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-69199-9',
#    'Pages': 646,
#    'Notes': ['Written with Peter Straub',
#     'Nominee, World Fantasy Award, 1985',
#     'Runner-up (4th place), Locus Award for Best Fantasy Novel, 1985[2]'],
#    'created_at': '2023-11-13T23:48:49.872Z',
#    'villains': []},
#   {'id': 17,
#    'Year': 1984,
#    'Title': 'The Eyes of the Dragon',
#    'handle': 'the-eyes-of-the-dragon',
#    'Publisher': 'Philtrum Press (1984)Viking (1987)',
#    'ISBN': '978-0-670-81458-9',
#    'Pages': 326,
#    'Notes': ['First published as a limited edition in 1984, then for the mass market in 1987'],
#    'created_at': '2023-11-13T23:48:49.988Z',
#    'villains': [{'name': 'Randall Flagg',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/37'}]},
#   {'id': 18,
#    'Year': 1984,
#    'Title': 'Thinner',
#    'handle': 'thinner',
#    'Publisher': 'NAL',
#    'ISBN': '978-0-453-00468-8',
#    'Pages': 309,
#    'Notes': ['Published under pseudonym Richard Bachman'],
#    'created_at': '2023-11-13T23:48:50.102Z',
#    'villains': []},
#   {'id': 19,
#    'Year': 1986,
#    'Title': 'It',
#    'handle': 'it',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-81302-5',
#    'Pages': 1138,
#    'Notes': ['Winner, British Fantasy Award’s August Derleth Award, 1987',
#     'Nominee, World Fantasy Award, 1987',
#     'Runner-up (3rd place), Locus Award for Best Fantasy Novel, 1987[2]'],
#    'created_at': '2023-11-13T23:48:50.223Z',
#    'villains': [{'name': 'Henry Bowers',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/7'},
#     {'name': 'Butch Bowers',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/8'},
#     {'name': 'Greta Bowie',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/9'},
#     {'name': 'Victor Criss',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/18'},
#     {'name': 'Marcia Fadden',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/35'},
#     {'name': 'John Garton',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/39'},
#     {'name': 'Peter Gordon',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/43'},
#     {'name': 'Patrick Hockstetter',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/53'},
#     {'name': 'Belch Huggins',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/55'},
#     {'name': 'It (Creature)',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/57'},
#     {'name': 'Richard P. Macklin',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/69'},
#     {'name': 'Alvin Marsh',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/72'},
#     {'name': 'Sally Mueller',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/79'},
#     {'name': 'Tom Rogan',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/91'},
#     {'name': 'Christopher Unwin',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/107'}]},
#   {'id': 20,
#    'Year': 1987,
#    'Title': 'The Dark Tower II: The Drawing of the Three',
#    'handle': 'the-dark-tower-ii-the-drawing-of-the-three',
#    'Publisher': 'Grant',
#    'ISBN': '978-0-937986-90-5',
#    'Pages': 400,
#    'Notes': ['Runner-up (16th place), Locus Award for Best Fantasy Novel, 1988[2]'],
#    'created_at': '2023-11-13T23:48:50.339Z',
#    'villains': [{'name': 'Jack Mort',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/76'}]},
#   {'id': 21,
#    'Year': 1987,
#    'Title': 'Misery',
#    'handle': 'misery',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-81364-3',
#    'Pages': 310,
#    'Notes': ['Winner, Bram Stoker Award, 1988',
#     'Nominee, World Fantasy Award, 1988[2]'],
#    'created_at': '2023-11-13T23:48:50.459Z',
#    'villains': [{'name': 'Annie Wilkes',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/114'}]},
#   {'id': 22,
#    'Year': 1987,
#    'Title': 'The Tommyknockers',
#    'handle': 'the-tommyknockers',
#    'Publisher': 'Putnam',
#    'ISBN': '978-0-399-13314-5',
#    'Pages': 558,
#    'Notes': ['Runner-up (16th place), Locus Award for Best Science Fiction Novel, 1988[2]'],
#    'created_at': '2023-11-13T23:48:50.579Z',
#    'villains': [{'name': 'Tommyknockers',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/104'}]},
#   {'id': 23,
#    'Year': 1989,
#    'Title': 'The Dark Half',
#    'handle': 'the-dark-half',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-82982-8',
#    'Pages': 431,
#    'Notes': ['Runner-up (2nd place), Locus Award for Best Horror Novel, 1990[2]'],
#    'created_at': '2023-11-13T23:48:50.696Z',
#    'villains': [{'name': 'George Stark',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/96'}]},
#   {'id': 24,
#    'Year': 1990,
#    'Title': 'The Stand Uncut',
#    'handle': 'the-stand-uncut',
#    'Publisher': 'Doubleday',
#    'ISBN': '978-0-385-19957-5',
#    'Pages': 1152,
#    'Notes': ['The Complete & Uncut Edition',
#     "Runner-up (2nd place), Locus Award's Best Horror/Dark Fantasy Novel, 1991[2]"],
#    'created_at': '2023-11-13T23:48:50.809Z',
#    'villains': []},
#   {'id': 25,
#    'Year': 1991,
#    'Title': 'The Dark Tower III: The Waste Lands',
#    'handle': 'the-dark-tower-iii-the-waste-lands',
#    'Publisher': 'Grant',
#    'ISBN': '978-0-937986-17-2',
#    'Pages': 512,
#    'Notes': ['Nominee, Bram Stoker Award, 1992',
#     'Runner-up (3rd place), Locus Award for Best Horror/Dark Fantasy Novel, 1992[2]'],
#    'created_at': '2023-11-13T23:48:50.926Z',
#    'villains': [{'name': 'Blaine the Mono',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/3'},
#     {'name': 'Randall Flagg',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/37'}]},
#   {'id': 26,
#    'Year': 1991,
#    'Title': 'Needful Things',
#    'handle': 'needful-things',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-83953-7',
#    'Pages': 690,
#    'Notes': ['Nominee, Bram Stoker Award, 1992',
#     'Runner-up (13th place), Locus Award for Best Horror/Dark Fantasy Novel, 1992[2]'],
#    'created_at': '2023-11-13T23:48:51.044Z',
#    'villains': [{'name': 'Leland Gaunt',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/40'}]},
#   {'id': 27,
#    'Year': 1992,
#    'Title': "Gerald's Game",
#    'handle': 'gerald-s-game',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-84650-4',
#    'Pages': 352,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:51.165Z',
#    'villains': [{'name': 'Gerald Burlingame',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/41'},
#     {'name': 'Raymond Andrew Joubert',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/61'},
#     {'name': 'Tom Mahout',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/103'}]},
#   {'id': 28,
#    'Year': 1992,
#    'Title': 'Dolores Claiborne',
#    'handle': 'dolores-claiborne',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-84452-4',
#    'Pages': 305,
#    'Notes': ['Runner-up (14th place), Locus Award for Best Horror/Dark Fantasy Novel, 1993[2]'],
#    'created_at': '2023-11-13T23:48:51.295Z',
#    'villains': [{'name': 'Joe St. George',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/95'}]},
#   {'id': 29,
#    'Year': 1994,
#    'Title': 'Insomnia',
#    'handle': 'insomnia',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-85503-2',
#    'Pages': 787,
#    'Notes': ['Nominee, Bram Stoker Award, 1995',
#     'Runner-up (3rd place), Locus Award for Best Fantasy/Horror Novel, 1995[2]'],
#    'created_at': '2023-11-13T23:48:51.415Z',
#    'villains': [{'name': 'Crimson King',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/17'},
#     {'name': 'Susan Day',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/23'}]},
#   {'id': 30,
#    'Year': 1995,
#    'Title': 'Rose Madder',
#    'handle': 'rose-madder',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-85869-9',
#    'Pages': 420,
#    'Notes': ['Runner-up (3rd place), Locus Award for Best Horror/Dark Fantasy Novel, 1995[2]'],
#    'created_at': '2023-11-13T23:48:51.533Z',
#    'villains': [{'name': 'Norman Daniels',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/22'},
#     {'name': 'Susan Day',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/23'}]},
#   {'id': 31,
#    'Year': 1996,
#    'Title': 'The Green Mile',
#    'handle': 'the-green-mile',
#    'Publisher': 'Signet Books',
#    'ISBN': '978-0-451-19049-9978-0-451-19052-9978-0-451-19054-3978-0-451-19055-0978-0-451-19056-7978-0-451-19057-4',
#    'Pages': 400,
#    'Notes': ['Winner, Bram Stoker Award, 1997',
#     'Runner-up (8th place), Locus Award for Best Horror/Dark Fantasy Novel, 1997[2]'],
#    'created_at': '2023-11-13T23:48:51.660Z',
#    'villains': [{'name': 'Percy Wetmore',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/111'},
#     {'name': 'William Wharton',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/112'}]},
#   {'id': 32,
#    'Year': 1996,
#    'Title': 'Desperation',
#    'handle': 'desperation',
#    'Publisher': 'Viking',
#    'ISBN': '978-0-670-86836-0',
#    'Pages': 704,
#    'Notes': ['Twin novel of The Regulators',
#     'Winner, Locus Award for Best Horror/Dark Fantasy Novel, 1997[2]'],
#    'created_at': '2023-11-13T23:48:51.784Z',
#    'villains': []},
#   {'id': 33,
#    'Year': 1996,
#    'Title': 'The Regulators',
#    'handle': 'the-regulators',
#    'Publisher': 'Dutton',
#    'ISBN': '978-0-525-94190-3',
#    'Pages': 480,
#    'Notes': ['Published under pseudonym Richard Bachman',
#     'Twin novel of Desperation'],
#    'created_at': '2023-11-13T23:48:51.900Z',
#    'villains': []},
#   {'id': 34,
#    'Year': 1997,
#    'Title': 'The Dark Tower IV: Wizard and Glass',
#    'handle': 'the-dark-tower-iv-wizard-and-glass',
#    'Publisher': 'Grant',
#    'ISBN': '978-1-880418-38-3',
#    'Pages': 787,
#    'Notes': ['Runner-up (4th place), Locus Award for Best Fantasy Novel, 1998',
#     'Runner-up (6th place), Locus Award for Best Art Book, 1998[2]'],
#    'created_at': '2023-11-13T23:48:52.019Z',
#    'villains': [{'name': 'Blaine the Mono',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/3'},
#     {'name': 'Cordelia Delgado',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/24'},
#     {'name': 'Rhea Dubativo',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/32'},
#     {'name': 'John Farson',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/36'},
#     {'name': 'Randall Flagg',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/37'},
#     {'name': 'Eldred Jonas',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/60'}]},
#   {'id': 35,
#    'Year': 1998,
#    'Title': 'Bag of Bones',
#    'handle': 'bag-of-bones',
#    'Publisher': 'Scribner',
#    'ISBN': '978-0-684-85350-5',
#    'Pages': 529,
#    'Notes': ['Winner, Bram Stoker Award, 1999',
#     'Winner, British Fantasy Award’s August Derleth Award, 1999',
#     'Winner, Locus Award for Best Dark Fantasy/Horror Novel, 1999[2]'],
#    'created_at': '2023-11-13T23:48:52.137Z',
#    'villains': []},
#   {'id': 36,
#    'Year': 1999,
#    'Title': 'The Girl Who Loved Tom Gordon',
#    'handle': 'the-girl-who-loved-tom-gordon',
#    'Publisher': 'Scribner',
#    'ISBN': '978-0-684-86762-5',
#    'Pages': 224,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:52.251Z',
#    'villains': []},
#   {'id': 37,
#    'Year': 2001,
#    'Title': 'Dreamcatcher',
#    'handle': 'dreamcatcher',
#    'Publisher': 'Scribner',
#    'ISBN': '978-0-743-21138-3',
#    'Pages': 620,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:52.368Z',
#    'villains': []},
#   {'id': 38,
#    'Year': 2001,
#    'Title': 'Black House',
#    'handle': 'black-house',
#    'Publisher': 'Random House',
#    'ISBN': '978-0-375-50439-6',
#    'Pages': 625,
#    'Notes': ['Sequel to The Talisman',
#     'Written with Peter Straub',
#     'Nominee, Bram Stoker Award, 2002',
#     'Runner-up (7th place), Locus Award for Best Fantasy Novel, 2002[2]'],
#    'created_at': '2023-11-13T23:48:52.483Z',
#    'villains': [{'name': 'Crimson King',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/17'}]},
#   {'id': 39,
#    'Year': 2002,
#    'Title': 'From a Buick 8',
#    'handle': 'from-a-buick-8',
#    'Publisher': 'Scribner',
#    'ISBN': '978-0-743-21137-6',
#    'Pages': 368,
#    'Notes': ['Nominee, Bram Stoker Award, 2003'],
#    'created_at': '2023-11-13T23:48:52.604Z',
#    'villains': [{'name': 'Brian Lippy',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/66'}]},
#   {'id': 40,
#    'Year': 2003,
#    'Title': 'The Dark Tower V: Wolves of the Calla',
#    'handle': 'the-dark-tower-v-wolves-of-the-calla',
#    'Publisher': 'Grant',
#    'ISBN': '978-1-880-41856-7',
#    'Pages': 714,
#    'Notes': ['Nominee, Bram Stoker Award, 2004',
#     'Runner-up (4th place), Locus Award for Best Fantasy Novel, 2004[2]'],
#    'created_at': '2023-11-13T23:48:52.735Z',
#    'villains': []},
#   {'id': 41,
#    'Year': 2004,
#    'Title': 'The Dark Tower VI: Song of Susannah',
#    'handle': 'the-dark-tower-vi-song-of-susannah',
#    'Publisher': 'Grant',
#    'ISBN': '978-1-880-41859-8',
#    'Pages': 432,
#    'Notes': ['Runner-up (4th place), Locus Award for Best Fantasy Novel, 2005'],
#    'created_at': '2023-11-13T23:48:52.856Z',
#    'villains': []},
#   {'id': 42,
#    'Year': 2004,
#    'Title': 'The Dark Tower VII: The Dark Tower',
#    'handle': 'the-dark-tower-vii-the-dark-tower',
#    'Publisher': '978-1-880-41862-8',
#    'ISBN': 'Grant',
#    'Pages': 845,
#    'Notes': ["Winner, British Fantasy Award's August Derleth Award, 2005",
#     'Nominee, Bram Stoker Award, 2005[2]'],
#    'created_at': '2023-11-13T23:48:53.001Z',
#    'villains': [{'name': 'Crimson King',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/17'},
#     {'name': 'Dandelo',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/21'},
#     {'name': 'Mordred Deschain',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/27'},
#     {'name': 'Randall Flagg',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/37'}]},
#   {'id': 43,
#    'Year': 2005,
#    'Title': 'The Colorado Kid',
#    'handle': 'the-colorado-kid',
#    'Publisher': 'Hard Case Crime',
#    'ISBN': '978-0-843-95584-2',
#    'Pages': 184,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:53.124Z',
#    'villains': []},
#   {'id': 44,
#    'Year': 2006,
#    'Title': 'Cell',
#    'handle': 'cell',
#    'Publisher': 'Scribner',
#    'ISBN': '978-0-743-29233-7',
#    'Pages': 351,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:53.244Z',
#    'villains': [{'name': 'The Raggedy Man',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/85'}]},
#   {'id': 45,
#    'Year': 2006,
#    'Title': "Lisey's Story",
#    'handle': 'lisey-s-story',
#    'Publisher': 'Scribner',
#    'ISBN': '978-0-743-28941-2',
#    'Pages': 528,
#    'Notes': ['Winner, Bram Stoker Award, 2007',
#     'Nominee, World Fantasy Award, 2007',
#     'Runner-up (10th place), Locus Award for Best Fantasy Novel, 2007[2]'],
#    'created_at': '2023-11-13T23:48:53.382Z',
#    'villains': []},
#   {'id': 46,
#    'Year': 2007,
#    'Title': 'Blaze',
#    'handle': 'blaze',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-416-55484-4',
#    'Pages': 304,
#    'Notes': ['Published under pseudonym Richard Bachman'],
#    'created_at': '2023-11-13T23:48:53.504Z',
#    'villains': []},
#   {'id': 47,
#    'Year': 2008,
#    'Title': 'Duma Key',
#    'handle': 'duma-key',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-416-55251-2',
#    'Pages': 607,
#    'Notes': ['Winner, Bram Stoker Award,  2009[2]'],
#    'created_at': '2023-11-13T23:48:53.622Z',
#    'villains': []},
#   {'id': 48,
#    'Year': 2009,
#    'Title': 'Under the Dome',
#    'handle': 'under-the-dome',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-439-14850-1',
#    'Pages': 1074,
#    'Notes': ["Nominee, British Fantasy Award's August Derleth Award, 2010",
#     'Runner-up (7th place), Locus Award for Best Science Fiction Novel, 2010[2]'],
#    'created_at': '2023-11-13T23:48:53.748Z',
#    'villains': [{'name': 'Jim Rennie, Jr.',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/88'},
#     {'name': 'Jim Rennie',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/89'},
#     {'name': 'Carter Thibodeau',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/101'}]},
#   {'id': 49,
#    'Year': 2011,
#    'Title': '11/22/63',
#    'handle': '11-22-63',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-451-62728-2',
#    'Pages': 849,
#    'Notes': ['Nominee, British Fantasy Award, 2012',
#     'Nominee, World Fantasy Award, 2012',
#     'Runner-up (2nd place), Locus Award for Best Science Fiction Novel, 2012[2]'],
#    'created_at': '2023-11-13T23:48:53.869Z',
#    'villains': []},
#   {'id': 50,
#    'Year': 2012,
#    'Title': 'The Dark Tower: The Wind Through the Keyhole',
#    'handle': 'the-dark-tower-the-wind-through-the-keyhole',
#    'Publisher': 'Grant',
#    'ISBN': '978-1-880-41876-5',
#    'Pages': 336,
#    'Notes': ['The eighth Dark Tower novel, but chronologically set between the fourth and fifth volumes.'],
#    'created_at': '2023-11-13T23:48:53.984Z',
#    'villains': []},
#   {'id': 51,
#    'Year': 2013,
#    'Title': 'Joyland',
#    'handle': 'joyland',
#    'Publisher': 'Hard Case Crime',
#    'ISBN': '978-1-781-16264-4',
#    'Pages': 288,
#    'Notes': ['Nominee, Edgar Award for Best Paperback Original, 2014[3]',
#     'Runner-up (11th place), Locus Award for Best Fantasy Novel, 2014[2]'],
#    'created_at': '2023-11-13T23:48:54.117Z',
#    'villains': [{'name': 'Lane Hardy',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/48'}]},
#   {'id': 52,
#    'Year': 2013,
#    'Title': 'Doctor Sleep',
#    'handle': 'doctor-sleep',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-476-72765-3',
#    'Pages': 531,
#    'Notes': ['Sequel to The Shining',
#     'Winner, Bram Stoker Award, 2014',
#     'Runner-up (5th place), Locus Award for Best Fantasy Novel, 2014[2]'],
#    'created_at': '2023-11-13T23:48:54.259Z',
#    'villains': [{'name': 'Rose the Hat',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/31'}]},
#   {'id': 53,
#    'Year': 2014,
#    'Title': 'Mr. Mercedes',
#    'handle': 'mr-mercedes',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-476-75445-1',
#    'Pages': 436,
#    'Notes': ['First novel in the Bill Hodges Trilogy',
#     'Winner, Edgar Award for Best Novel, 2015[3]'],
#    'created_at': '2023-11-13T23:48:54.379Z',
#    'villains': [{'name': 'Brady Hartsfield',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/50'}]},
#   {'id': 54,
#    'Year': 2014,
#    'Title': 'Revival',
#    'handle': 'revival',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-476-77038-3',
#    'Pages': 403,
#    'Notes': ['Runner-up (8th place), Locus Award for Best Fantasy Novel, 2015[2]'],
#    'created_at': '2023-11-13T23:48:54.494Z',
#    'villains': [{'name': 'Mother of the Null',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/78'}]},
#   {'id': 55,
#    'Year': 2015,
#    'Title': 'Finders Keepers',
#    'handle': 'finders-keepers',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-501-10007-9',
#    'Pages': 434,
#    'Notes': ['Second novel in the Bill Hodges Trilogy.'],
#    'created_at': '2023-11-13T23:48:54.614Z',
#    'villains': [{'name': 'Brady Hartsfield',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/50'}]},
#   {'id': 56,
#    'Year': 2016,
#    'Title': 'End of Watch',
#    'handle': 'end-of-watch',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-501-12974-2',
#    'Pages': 496,
#    'Notes': ['Third novel in the Bill Hodges Trilogy.'],
#    'created_at': '2023-11-13T23:48:54.730Z',
#    'villains': [{'name': 'Brady Hartsfield',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/50'}]},
#   {'id': 57,
#    'Year': 2017,
#    'Title': "Gwendy's Button Box",
#    'handle': 'gwendy-s-button-box',
#    'Publisher': 'Cemetery Dance Publications',
#    'ISBN': '978-1-58767-610-9',
#    'Pages': 175,
#    'Notes': ['Written with Richard Chizmar'],
#    'created_at': '2023-11-13T23:48:54.850Z',
#    'villains': []},
#   {'id': 58,
#    'Year': 2017,
#    'Title': 'Sleeping Beauties',
#    'handle': 'sleeping-beauties',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-50116-340-1',
#    'Pages': 702,
#    'Notes': ['Written with Owen King', 'Nominee, Bram Stoker Award, 2018[2]'],
#    'created_at': '2023-11-13T23:48:54.973Z',
#    'villains': []},
#   {'id': 59,
#    'Year': 2018,
#    'Title': 'The Outsider',
#    'handle': 'the-outsider',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-50118-098-9',
#    'Pages': 576,
#    'Notes': ['First novel in the Holly Gibney Series',
#     'Runner-up (2nd place), Locus Award for Best Horror Novel, 2019[2]'],
#    'created_at': '2023-11-13T23:48:55.165Z',
#    'villains': [{'name': 'The Outsider (Creature)',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/82'}]},
#   {'id': 60,
#    'Year': 2018,
#    'Title': 'Elevation',
#    'handle': 'elevation',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-98210-231-9',
#    'Pages': 144,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:55.291Z',
#    'villains': []},
#   {'id': 61,
#    'Year': 2019,
#    'Title': 'The Institute',
#    'handle': 'the-institute',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-98211-056-7',
#    'Pages': 576,
#    'Notes': ["Nominee, British Fantasy Award's August Derleth Award, 2020",
#     'Runner-up (3rd place), Locus Award for Best Horror Novel, 2020[2]'],
#    'created_at': '2023-11-13T23:48:55.457Z',
#    'villains': [{'name': 'Gladys Hickson',
#      'url': 'https://stephen-king-api.onrender.com/api/villain/52'}]},
#   {'id': 62,
#    'Year': 2021,
#    'Title': 'Later',
#    'handle': 'later',
#    'Publisher': 'Hard Case Crime',
#    'ISBN': '978-1-78909-649-1',
#    'Pages': 256,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:55.579Z',
#    'villains': []},
#   {'id': 63,
#    'Year': 2021,
#    'Title': 'Billy Summers',
#    'handle': 'billy-summers',
#    'Publisher': 'Scribner',
#    'ISBN': '978-1-982-17361-6',
#    'Pages': 528,
#    'Notes': [],
#    'created_at': '2023-11-13T23:48:55.753Z',
#    'villains': []},
#   {'id': 72,
#    'Year': 1979,
#    'Title': 'The Roopak Zone',
#    'handle': 'the-roopak-zone',
#    'Publisher': 'Viking Press',
#    'ISBN': '978-0-670-26069697-5',
#    'Pages': 428,
#    'Notes': ['Runner-up (2nd place), Locus Award for Best Fantasy Novel, 1980[2]'],
#    'created_at': '2026-06-26T18:20:32.285Z',
#    'villains': []}]}

# %%
data = response1.json()
print("Primeros 10 platos tipicos:")
for item in data[:10]:
  print(item['name'],":", item['description'])
# Out:
# Primeros 10 platos tipicos:
# Bandeja Paisa : La bandeja paisa es el orgullo de la cocina paisa y uno de los platos más emblemáticos de Colombia. Originaria de Antioquia y los departamentos vecinos de Caldas, Risaralda y Quindío, refleja la tradición y riqueza cultural de esta región.
# Sancocho Antioqueño : El sancocho antioqueño es un plato típico de Antioquia, preparado con carne, plátano verde, mazorca, papa, yuca y condimentos, servido con arroz, aguacate y arepas, ideal para reuniones familiares y festividades.
# Ajiaco Santafereño :  Sopa tradicional de Bogotá y el altiplano cundiboyacense, caracterizada por el uso de diferentes tipos de papa y la guasca como hierba aromática.
# Sancocho de Gallina : Sopa tradicional del Valle del Cauca, ideal para reuniones familiares y celebraciones.
# Lechona Tolimense : Preparación típica para celebraciones, consiste en cerdo relleno con arroz y arvejas, cocinado lentamente en horno de barro.
# Arepas de Huevo : Arepas fritas rellenas de huevo, típicas de la región caribeña, ideales para desayunos o meriendas.
# Mazamorra Chiquita : Sopa densa hecha a base de maíz, legumbres y carne.
# Sobrebarriga al Horno : Carne de res cocida al horno, acompañada con papas, arroz y ensalada.
# Arroz Atollado : Plato típico con arroz cocido mezclado con cerdo, pollo y verduras
# Tamal Tolimense : Masa de maíz rellena de carne y vegetales, envuelta en hojas de plátano.

# %% [markdown]
# ## Exploración de datos
# ---

# %%
print("Vista general de los datos:")
display(data)
# Out:
# Vista general de los datos:
# [{'id': 1,
#   'name': 'Bandeja Paisa',
#   'description': 'La bandeja paisa es el orgullo de la cocina paisa y uno de los platos más emblemáticos de Colombia. Originaria de Antioquia y los departamentos vecinos de Caldas, Risaralda y Quindío, refleja la tradición y riqueza cultural de esta región.',
#   'ingredients': 'Frijoles, arroz, carne molida, chicharrón, huevo, plátano maduro, chorizo, arepa, aguacate.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/1. Bandeja Paisa.jpg',
#   'departmentId': 2,
#   'department': {'id': 2,
#    'name': 'Antioquia',
#    'description': 'Antioquia es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Medellín, la segunda ciudad más poblada del país. Está ubicado al noroccidente colombiano, en las regiones Andina y Caribe, limitando al norte con el mar Caribe (océano Atlántico), Córdoba y Bolívar, al este con Santander y Boyacá, al sur con Caldas y Risaralda, y al oeste con Chocó. Con unos 6 500 000 habitantes en 2015 es el departamento más poblado, y con 63 600 km², el sexto más extenso, superado por Amazonas, Vichada, Caquetá, Meta y Guainía.',
#    'cityCapitalId': 12,
#    'municipalities': 125,
#    'surface': 63612,
#    'population': 6887306,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 2,
#   'name': 'Sancocho Antioqueño',
#   'description': 'El sancocho antioqueño es un plato típico de Antioquia, preparado con carne, plátano verde, mazorca, papa, yuca y condimentos, servido con arroz, aguacate y arepas, ideal para reuniones familiares y festividades.',
#   'ingredients': 'Carne de res, pollo, plátano verde, yuca, papa, mazorca, cilantro.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/2. Sancocho Antioqueno.jpg',
#   'departmentId': 2,
#   'department': {'id': 2,
#    'name': 'Antioquia',
#    'description': 'Antioquia es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Medellín, la segunda ciudad más poblada del país. Está ubicado al noroccidente colombiano, en las regiones Andina y Caribe, limitando al norte con el mar Caribe (océano Atlántico), Córdoba y Bolívar, al este con Santander y Boyacá, al sur con Caldas y Risaralda, y al oeste con Chocó. Con unos 6 500 000 habitantes en 2015 es el departamento más poblado, y con 63 600 km², el sexto más extenso, superado por Amazonas, Vichada, Caquetá, Meta y Guainía.',
#    'cityCapitalId': 12,
#    'municipalities': 125,
#    'surface': 63612,
#    'population': 6887306,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 3,
#   'name': 'Ajiaco Santafereño',
#   'description': ' Sopa tradicional de Bogotá y el altiplano cundiboyacense, caracterizada por el uso de diferentes tipos de papa y la guasca como hierba aromática.',
#   'ingredients': 'Papas sabaneras, criollas y pastusas, Pechuga de pollo, Mazorca, Guasca, Crema de leche, Alcaparras, Arroz blanco',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/3. Ajiaco Santafereno.png',
#   'departmentId': 5,
#   'department': {'id': 5,
#    'name': 'Bogotá',
#    'description': 'Bogotá, oficialmente Bogotá, Distrito Capital\u200b (antiguamente, Santafé de Bogotá),\u200b es la capital de la República de Colombia y del departamento de Cundinamarca. Está administrada como distrito capital, y goza de autonomía para la gestión de sus intereses dentro de los límites de la Constitución y la ley.12\u200b18\u200b A diferencia de los demás distritos de Colombia, Bogotá es una entidad territorial de primer orden, con las atribuciones administrativas que la ley confiere a los departamentos',
#    'cityCapitalId': 167,
#    'municipalities': 1,
#    'surface': 1139,
#    'population': 8906342,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 4,
#   'name': 'Sancocho de Gallina',
#   'description': 'Sopa tradicional del Valle del Cauca, ideal para reuniones familiares y celebraciones.',
#   'ingredients': 'Gallina, Plátano verde, Yuca, Papa, Mazorca, Cilantro, Cebolla, Ajo',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/4. Sancocho de gallina.jpeg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 5,
#   'name': 'Lechona Tolimense',
#   'description': 'Preparación típica para celebraciones, consiste en cerdo relleno con arroz y arvejas, cocinado lentamente en horno de barro.',
#   'ingredients': 'Carne de cerdo, Arroz, Arvejas, Aliños (ajo, cebolla, comino), Piel de cerdo crocante',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/5. Lechona Tolimense.png',
#   'departmentId': 30,
#   'department': {'id': 30,
#    'name': 'Tolima',
#    'description': 'Tolima es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Ibagué. Está ubicado en el centro-oeste del país, en la región andina, limitando al norte con Caldas, al este con Cundinamarca, al sur con Huila y Cauca; y al oeste con Valle del Cauca, Quindío y Risaralda.6\u200b El río Magdalena atraviesa Tolima de sur a norte.',
#    'cityCapitalId': 1069,
#    'municipalities': 47,
#    'surface': 23562,
#    'population': 1346935,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 6,
#   'name': 'Arepas de Huevo',
#   'description': 'Arepas fritas rellenas de huevo, típicas de la región caribeña, ideales para desayunos o meriendas.',
#   'ingredients': 'Harina de maíz, Huevo, Aceite para freír, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/6. Arepas de Huevo.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 7,
#   'name': 'Mazamorra Chiquita',
#   'description': 'Sopa densa hecha a base de maíz, legumbres y carne.',
#   'ingredients': 'Maíz pelado, Habas, Arvejas, Tocino o costilla de cerdo, Cilantro',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/7. Mazamorra Chiquita.jpg',
#   'departmentId': 7,
#   'department': {'id': 7,
#    'name': 'Boyacá',
#    'description': 'Boyacá es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Tunja. Está ubicado en el centro-este del país, en la región andina, limitando al norte con Santander y Norte de Santander, al noreste con Venezuela y Arauca, al este con Casanare,8\u200b9\u200b al sur con Cundinamarca y al occidente el río Magdalena con los departamentos de Caldas y Antioquia.',
#    'cityCapitalId': 217,
#    'municipalities': 123,
#    'surface': 23189,
#    'population': 1259601,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 8,
#   'name': 'Sobrebarriga al Horno',
#   'description': 'Carne de res cocida al horno, acompañada con papas, arroz y ensalada.',
#   'ingredients': 'Sobrebarriga de res, Ajo, cebolla y tomate, Papa criolla, Arroz blanco',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/8. Sobrebarriga al Horno.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 9,
#   'name': 'Arroz Atollado',
#   'description': 'Plato típico con arroz cocido mezclado con cerdo, pollo y verduras',
#   'ingredients': 'Arroz, Costilla de cerdo, Pollo, Hogao, Arvejas y zanahoria',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/9. Arroz Atollado.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 10,
#   'name': 'Tamal Tolimense',
#   'description': 'Masa de maíz rellena de carne y vegetales, envuelta en hojas de plátano.',
#   'ingredients': 'Harina de maíz, Carne de cerdo o pollo, Papa, Zanahoria, Hojas de plátano',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/10.Tamal Tolimense.jpg',
#   'departmentId': 30,
#   'department': {'id': 30,
#    'name': 'Tolima',
#    'description': 'Tolima es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Ibagué. Está ubicado en el centro-oeste del país, en la región andina, limitando al norte con Caldas, al este con Cundinamarca, al sur con Huila y Cauca; y al oeste con Valle del Cauca, Quindío y Risaralda.6\u200b El río Magdalena atraviesa Tolima de sur a norte.',
#    'cityCapitalId': 1069,
#    'municipalities': 47,
#    'surface': 23562,
#    'population': 1346935,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 11,
#   'name': 'Arroz con Coco',
#   'description': 'Arroz dulce o salado preparado con leche de coco.',
#   'ingredients': 'Arroz, Coco rallado, Azúcar (para dulce) o sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/11. Arroz con Coco.jpg',
#   'departmentId': 6,
#   'department': {'id': 6,
#    'name': 'Bolívar',
#    'description': 'Bolívar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cartagena de Indias, sede de la asamblea departamental, mientras que en Turbaco se encuentra la sede de la gobernación. Está ubicado en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al noreste con Atlántico, al este con Magdalena y Cesar, al sureste con Santander, al suroeste con Antioquia y al oeste con Córdoba y Sucre.',
#    'cityCapitalId': 210,
#    'municipalities': 45,
#    'surface': 25978,
#    'population': 2236603,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 12,
#   'name': 'Cabrito Asado',
#   'description': 'Carne de cabro sazonada y asada lentamente, típico de Santander.',
#   'ingredients': 'Carne de cabro, Limón, Ajol Comino, Sal y pimienta',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/12. Cabrito Asado.jpg',
#   'departmentId': 28,
#   'department': {'id': 28,
#    'name': 'Santander',
#    'description': 'Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bucaramanga. Está ubicado al noreste del país, en la región andina, limitando al norte con Cesar y Norte de Santander, al este y sur con Boyacá, al oeste con Antioquia y al noroeste con Bolívar.7\u200b Con unos 2 280 908 habitantes en 2018 es el sexto departamento por población. Recibe su nombre en alusión a Francisco de Paula Santander, prócer de la independencia de la Nueva Granada',
#    'cityCapitalId': 915,
#    'municipalities': 87,
#    'surface': 30537,
#    'population': 2324090,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 13,
#   'name': 'Pepitoria',
#   'description': 'Guiso preparado con vísceras de cabrito, arroz y especias.',
#   'ingredients': 'Vísceras de cabro, Arroz, Cebolla, Ajo, Comino y achiote',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/13. Pepitoria.jpg',
#   'departmentId': 28,
#   'department': {'id': 28,
#    'name': 'Santander',
#    'description': 'Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bucaramanga. Está ubicado al noreste del país, en la región andina, limitando al norte con Cesar y Norte de Santander, al este y sur con Boyacá, al oeste con Antioquia y al noroeste con Bolívar.7\u200b Con unos 2 280 908 habitantes en 2018 es el sexto departamento por población. Recibe su nombre en alusión a Francisco de Paula Santander, prócer de la independencia de la Nueva Granada',
#    'cityCapitalId': 915,
#    'municipalities': 87,
#    'surface': 30537,
#    'population': 2324090,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 14,
#   'name': 'Cuy Asado',
#   'description': 'Raza especial de cuy, asado sobre brasas, acompañado de papas.',
#   'ingredients': 'Cuy, Papas, Ajo, Comino, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/14. Cuy Asado.jpg',
#   'departmentId': 22,
#   'department': {'id': 22,
#    'name': 'Nariño',
#    'description': 'Nariño es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es San Juan de Pasto. Está ubicado en el extremo suroeste del país, en las regiones andina y pacífica, limitando al norte con Cauca, al este con Putumayo, al sur con las provincias de Esmeraldas, Carchi y Sucumbíos de la República de Ecuador y al oeste con el océano Pacífico. Fue fundado en 1904 con la unión de lo que eran las provincias de Pasto y Obando.',
#    'cityCapitalId': 769,
#    'municipalities': 64,
#    'surface': 33268,
#    'population': 1629181,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 15,
#   'name': 'Empanadas de Pipián',
#   'description': 'Empanadas rellenas de un guiso de papa y maní.',
#   'ingredients': 'Masa de maíz, Papa, Maní, Achiote, Comino',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/15. Empanadas de Pipian.png',
#   'departmentId': 11,
#   'department': {'id': 11,
#    'name': 'Cauca',
#    'description': 'Cauca es uno de los treinta y dos departamentos que, junto al Distrito Capital de Bogotá, conforman la República de Colombia. Su capital y ciudad más poblada es Popayán. Está ubicado al suroccidente del país entre las regiones andina y pacífica, limitando al norte con Valle del Cauca y Tolima, al oriente con Huila, al suroriente con Caquetá, al sur con Putumayo y Nariño, y al noroccidente con el océano Pacífico',
#    'cityCapitalId': 399,
#    'municipalities': 41,
#    'surface': 29308,
#    'population': 1516018,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 16,
#   'name': 'Arroz de Lisa',
#   'description': 'Arroz cocido con pescado lisa, típico de Barranquilla.',
#   'ingredients': 'Arroz, Lisa (pescado), Suero costeño, Plátano maduro, Yuca',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/16. Arroz de Lisa.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 17,
#   'name': 'Butifarra Soledeña',
#   'description': 'Embutido de cerdo, típico de Soledad, Atlántico.',
#   'ingredients': 'Carne de cerdo, Ajo, Pimienta, Comino, SalCarne de cerdo, Ajo, Pimienta, Comino, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/17. Butifarra Soledena.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 18,
#   'name': 'Asado Huilense',
#   'description': 'Carne de cerdo marinada y asada lentamente en hojas de plátano.',
#   'ingredients': 'Carne de cerdo, Hojas de plátano, Ajo y cebolla, Sal y pimienta, Cerveza (opcional)',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/18. Asado Huilense.jpg',
#   'departmentId': 18,
#   'department': {'id': 18,
#    'name': 'Huila',
#    'description': 'Huila es uno de los treinta y dos departamentos que junto con Bogotá, Distrito Capital, conforman la República de Colombia. Su capital y ciudad más poblada es Neiva. Está ubicado al suroeste del país, en la región andina, limitando al norte con Tolima y Cundinamarca, al este con Meta, al sur con Caquetá y al oeste con Cauca.',
#    'cityCapitalId': 657,
#    'municipalities': 37,
#    'surface': 19890,
#    'population': 1140932,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 19,
#   'name': 'Champús',
#   'description': 'Bebida espesa preparada con maíz, frutas y especias.',
#   'ingredients': 'Maíz molido, Lulo, Piña, Panela, Canela y clavos',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/19. Champus.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 20,
#   'name': 'Sopa de Carantanta',
#   'description': 'Sopa hecha con carantanta (corteza de maíz tostada) y leche.',
#   'ingredients': 'Carantanta, Leche, Papa, Cilantro, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/20. Sopa de carantanta.png',
#   'departmentId': 11,
#   'department': {'id': 11,
#    'name': 'Cauca',
#    'description': 'Cauca es uno de los treinta y dos departamentos que, junto al Distrito Capital de Bogotá, conforman la República de Colombia. Su capital y ciudad más poblada es Popayán. Está ubicado al suroccidente del país entre las regiones andina y pacífica, limitando al norte con Valle del Cauca y Tolima, al oriente con Huila, al suroriente con Caquetá, al sur con Putumayo y Nariño, y al noroccidente con el océano Pacífico',
#    'cityCapitalId': 399,
#    'municipalities': 41,
#    'surface': 29308,
#    'population': 1516018,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 21,
#   'name': 'Caldo de Pirarucú',
#   'description': 'Sopa con el pescado pirarucú, típico del Amazonas.',
#   'ingredients': 'Pirarucú (pescado), Papa, Yuca, Cebolla, Cilantro',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/21. Caldo de pirarucu.png',
#   'departmentId': 1,
#   'department': {'id': 1,
#    'name': 'Amazonas',
#    'description': 'Amazonas es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Leticia. Está ubicado en el extremo sur del país, en gran parte al sur de la línea ecuatorial, en la región Amazonia. Limita al norte con Caquetá y Vaupés, al este con el estado brasileño del mismo nombre, al sur con el departamento peruano de Loreto y al oeste con Putumayo. Con 110 000 km² es el departamento más extenso de Colombia, con unos 75\xa0000 habitantes en 2015, el cuarto menos poblado —por delante de Vichada, Vaupés y Guainía, el menos poblado— y con 0.68\xa0hab/km², el tercero menos densamente poblado, por delante de Vichada y Guainía, el menos densamente poblado.',
#    'cityCapitalId': 1,
#    'municipalities': 2,
#    'surface': 109665,
#    'population': 82068,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 22,
#   'name': 'Chivo Guisado',
#   'description': 'Guiso de carne de chivo cocida con especias y aliños.',
#   'ingredients': 'Carne de chivo, Ajo y cebolla, Tomate, Comino, Achote',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/22. Chivo Guisado.png',
#   'departmentId': 19,
#   'department': {'id': 19,
#    'name': 'La Guajira',
#    'description': 'La Guajira (en wayuunaiki: Wajiira o Karibyczonn) es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. La traducción más precisa de su nombre sería «Caribe hermoso» y en wayunaiki antiguo Karive Pala «Mar Caribe» también puede significar Mar del Caribe. Su capital es Riohacha. Está ubicado en el extremo noreste del país, en la región Caribe, limitando al norte y este con el mar Caribe (océano Atlántico), al sureste con el estado Venezolano del Zulia, al sur con el departamento del Cesar y al oeste con el del Magdalena.',
#    'cityCapitalId': 694,
#    'municipalities': 15,
#    'surface': 20848,
#    'population': 1002394,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 23,
#   'name': 'Tacacho con Cecina',
#   'description': 'Plátano asado y aplastado, acompañado de carne seca.',
#   'ingredients': 'Plátano verde, Carne de cecina (seca), Aceite o manteca, Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/23. Tacacho con cecina.png',
#   'departmentId': 1,
#   'department': {'id': 1,
#    'name': 'Amazonas',
#    'description': 'Amazonas es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Leticia. Está ubicado en el extremo sur del país, en gran parte al sur de la línea ecuatorial, en la región Amazonia. Limita al norte con Caquetá y Vaupés, al este con el estado brasileño del mismo nombre, al sur con el departamento peruano de Loreto y al oeste con Putumayo. Con 110 000 km² es el departamento más extenso de Colombia, con unos 75\xa0000 habitantes en 2015, el cuarto menos poblado —por delante de Vichada, Vaupés y Guainía, el menos poblado— y con 0.68\xa0hab/km², el tercero menos densamente poblado, por delante de Vichada y Guainía, el menos densamente poblado.',
#    'cityCapitalId': 1,
#    'municipalities': 2,
#    'surface': 109665,
#    'population': 82068,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 24,
#   'name': 'Arepa ocañera',
#   'description': 'Arepa pequeña y crocante, hecha con maíz y mantequilla.',
#   'ingredients': 'Maíz, mantequilla y sal.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/24. Arepa Ocanera.jpg',
#   'departmentId': 23,
#   'department': {'id': 23,
#    'name': 'Norte de Santander',
#    'description': 'Norte de Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es la ciudad de Cúcuta. Es una entidad territorial que goza de autonomía para la administración de los asuntos seccionales y la planificación y promoción del desarrollo económico y social dentro de su territorio, tiene una extensión de 22.648 km², que equivalen al 1.91% del territorio nacional, ubicado en la región nororiental de Colombia. Limita al norte y al este con los estados de Zulia y Táchira de Venezuela, al sur con los departamentos de Boyacá y Santander, y al oeste con Santander y Cesar.',
#    'cityCapitalId': 870,
#    'municipalities': 40,
#    'surface': 21658,
#    'population': 1651278,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 25,
#   'name': 'Arroz clavado',
#   'description': 'Es un arroz preparado con ingredientes básicos como arroz, aceite, ajo, cebolla, y caldo, que se cocina a fuego lento para formar una capa crujiente en el fondo de la olla. Es un plato típico del Chocó, servido tradicionalmente con pescados, mariscos, o carne.',
#   'ingredients': 'Arroz, Ajo, Cebolla, Caldo o agua, Aceite o manteca y Sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/25. Arroz clavado.jpg',
#   'departmentId': 13,
#   'department': {'id': 13,
#    'name': 'Chocó',
#    'description': 'Chocó es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Quibdó. Está ubicado al noroeste del país, en las regiones andina y Pacífico, limitando al norte con la República de Panamá y el mar Caribe (océano Atlántico), al este con Antioquia y Risaralda, al sur con Valle del Cauca y al oeste con el océano Pacífico.',
#    'cityCapitalId': 467,
#    'municipalities': 31,
#    'surface': 46530,
#    'population': 553519,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 26,
#   'name': 'Mote de queso',
#   'description': 'Sopa de ñame con queso costeño y suero.',
#   'ingredients': 'Ñame, queso costeño, suero, cebolla y ajo.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/26. Mote de queso.jpg',
#   'departmentId': 14,
#   'department': {'id': 14,
#    'name': 'Córdoba',
#    'description': 'Córdoba es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Montería. Está ubicado al norte del país, en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al este con los departamentos de Sucre y Bolívar, y al sur y oeste con el departamento de Antioquia. Con 1\xa0710\xa0000 habitantes en 2015, es el octavo departamento más poblado, por detrás de Bogotá, Antioquia, Valle del Cauca, Cundinamarca, Atlántico, Santander y Bolívar. Fue creado por medio de la Ley 9 del 18 de diciembre de 1951, reglamentada el 18 de junio de 1952.',
#    'cityCapitalId': 498,
#    'municipalities': 30,
#    'surface': 25020,
#    'population': 1856496,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 27,
#   'name': 'Cayeye',
#   'description': 'Puré de banano verde con queso costeño.',
#   'ingredients': 'Banano verde, queso costeño, mantequilla y sal.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/27. Cayeye.jpg',
#   'departmentId': 20,
#   'department': {'id': 20,
#    'name': 'Magdalena',
#    'description': 'Magdalena es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Santa Marta. Está ubicado al noreste del país, en la región Caribe. Limita al norte con el mar Caribe, al este con La Guajira, al sureste con Cesar, al sur y oeste con Bolívar y al oeste con Atlántico. Fue uno de los originales nueve estados que conformaron los Estados Unidos de Colombia. El departamento toma el nombre del río Magdalena. Entre sus municipios se encuentra Aracataca, el lugar de nacimiento del premio Nobel de literatura Gabriel García Márquez.',
#    'cityCapitalId': 709,
#    'municipalities': 30,
#    'surface': 23188,
#    'population': 1463427,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 28,
#   'name': 'Arepa guajira',
#   'description': 'Arepa grande hecha de maíz o yuca, típica de La Guajira.',
#   'ingredients': 'Maíz o yuca, sal y agua.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/28. Arepa Guajira.jpg',
#   'departmentId': 19,
#   'department': {'id': 19,
#    'name': 'La Guajira',
#    'description': 'La Guajira (en wayuunaiki: Wajiira o Karibyczonn) es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. La traducción más precisa de su nombre sería «Caribe hermoso» y en wayunaiki antiguo Karive Pala «Mar Caribe» también puede significar Mar del Caribe. Su capital es Riohacha. Está ubicado en el extremo noreste del país, en la región Caribe, limitando al norte y este con el mar Caribe (océano Atlántico), al sureste con el estado Venezolano del Zulia, al sur con el departamento del Cesar y al oeste con el del Magdalena.',
#    'cityCapitalId': 694,
#    'municipalities': 15,
#    'surface': 20848,
#    'population': 1002394,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 29,
#   'name': 'Ternera a la llanera',
#   'description': 'Carne de res asada a la brasa, sazonada con sal y acompañada de yuca, plátano y arepas de maíz.',
#   'ingredients': 'Carne de res, sal, yuca, plátano, arepas',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/29. Ternera a la llanera.png',
#   'departmentId': 3,
#   'department': {'id': 3,
#    'name': 'Arauca',
#    'description': 'Arauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es la homónima Arauca. Está ubicado al este del país, en la región Orinoquía, limitando al norte y este con Venezuela, al sur con Vichada y Casanare, y al oeste con Boyacá',
#    'cityCapitalId': 143,
#    'municipalities': 7,
#    'surface': 23818,
#    'population': 304978,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 30,
#   'name': 'Natilla',
#   'description': 'Plato tipico de caldas,se trata de un flan hecho con leche, fécula de maíz, panela rallada, canela y a veces pasas. Es un postre muy popular en Colombia y se suele comer en Navidad. ',
#   'ingredients': 'Leche, Harina de maíz o maicena, Panela o azúcar, Canela en rama, Coco rallado (opcional), Uvas pasas (opcional)',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/30. Natilla.png',
#   'departmentId': 8,
#   'department': {'id': 8,
#    'name': 'Caldas',
#    'description': 'Caldas es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Manizales. Está ubicado en el centro del país, en la región andina, limitando al norte con Antioquia, al noreste con Boyacá, al este con Cundinamarca, al sur con Tolima y Risaralda y al oeste con Risaralda. Con 7888\xa0km² es el quinto departamento menos extenso —por delante de Risaralda, Atlántico, Quindío y San Andrés y Providencia, el menos extenso— y con 125 hab/km², el sexto más densamente poblado, por detrás de San Andrés y Providencia, Atlántico, Quindío, Risaralda y Valle del Cauca',
#    'cityCapitalId': 337,
#    'municipalities': 27,
#    'surface': 7888,
#    'population': 1036455,
#    'phonePrefix': '6',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 31,
#   'name': 'Pescado muquiao',
#   'description': 'Se trata de una tradicion que consiste en sazonar el pescado con sal, envolverlo en hojas de plátano previamente ahumadas y cocinarlo en un horno subterráneo. Este método se acompaña con yuca, plátano asado y arroz, mientras que la bebida típica es la chicha.',
#   'ingredients': 'pescado, sal gruesa al gusto, hojas de plátano frescas y limpias, yuca, plátanos verdes o maduros, arroz blanco cocido, chicha (opcional).',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/31. Pescado Muquiao.jpg',
#   'departmentId': 9,
#   'department': {'id': 9,
#    'name': 'Caquetá',
#    'description': 'Caquetá es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Florencia. Está ubicado al sur del país, en la región Amazonia, limitando al norte con Meta y Guaviare, al noreste con Vaupés, al sur con Amazonas y Putumayo, y al oeste con Cauca y Huila. Con 88 965 km² es el tercer departamento más extenso —por detrás de Amazonas y Vichada—. Todos sus municipios forman parte de los territorios focalizados',
#    'cityCapitalId': 364,
#    'municipalities': 16,
#    'surface': 88965,
#    'population': 419275,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 32,
#   'name': 'Pisillo de chigüiro',
#   'description': 'Plato tradicional que se elabora desmechando la carne de este roedor típico de la región',
#   'ingredients': 'ajo, cebolla, pimentón y otros condimentos. Se sirve con arroz, plátano y yuca.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/32. Pisillo de chiguiro.png',
#   'departmentId': 10,
#   'department': {'id': 10,
#    'name': 'Casanare',
#    'description': 'Casanare es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Yopal. Está ubicado en la región Orinoquía, limitando al norte con Arauca, al este con Vichada, al sur con Meta y al oeste con Boyacá. Con 44 490\xa0km² es el décimo departamento más extenso —por detrás de Amazonas, Vichada',
#    'cityCapitalId': 380,
#    'municipalities': 19,
#    'surface': 44640,
#    'population': 442068,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 33,
#   'name': 'Chicharrón',
#   'description': 'El chicharrón es un acompañante frecuente en el Cesar, preparado con carne de cerdo frita hasta quedar crujiente. Se sirve con arroz, arepas y otros acompañantes.',
#   'ingredients': 'Carne de cerdo, sal al gusto, ajo, pimienta al gusto y aceite',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/33. Chicharron.jpg',
#   'departmentId': 12,
#   'department': {'id': 12,
#    'name': 'Cesar',
#    'description': 'Cesar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Valledupar. Está ubicado al noreste del país, en las regiones Andina y Caribe, limitando al norte con La Guajira, al este con el Estado Zulia de Venezuela, al sureste con Norte de Santander, al sur con Santander, al suroeste con Bolívar y al oeste con Magdalena.',
#    'cityCapitalId': 441,
#    'municipalities': 25,
#    'surface': 22905,
#    'population': 1341697,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 34,
#   'name': 'Sancocho de pescado',
#   'description': 'Este caldo espeso se prepara con pescado fresco, yuca, plátano, arroz y otros ingredientes locales. Es común en las zonas ribereñas de Guainía.',
#   'ingredients': 'Pescado fresco, yuca, plátano verde, papas, mazorca de maíz, cebolla, ajo, pimentón, cilantro, comino, sal, pimienta, aceite y agua para cocinar el caldo',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/34. Sancocho de pescado.png',
#   'departmentId': 16,
#   'department': {'id': 16,
#    'name': 'Guainía',
#    'description': 'Guainía (idioma yurí: "Tierra de muchas aguas") es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Inírida. Está ubicado al este del país, en la región Amazonia, limitando al norte con Vichada, al este con el Estado de Amazonas de Venezuela, al sur con el brasileño del mismo nombre, al suroeste con Vaupés y al oeste con Guaviare. Con 72 238\xa0km² es el quinto departamento más extenso —por detrás de Amazonas, Vichada, Caquetá y Meta—, con unos 50 000 habitantes en 2020, el segundo menos poblado, y con 0,56 hab/km², el menos densamente poblado. Antiguamente era una comisaría, pero desde 1991 es oficialmente un departamento',
#    'cityCapitalId': 644,
#    'municipalities': 2,
#    'surface': 72238,
#    'population': 52061,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 35,
#   'name': 'Casabe',
#   'description': 'Es una tortilla grande y delgada hecha a base de yuca brava, un alimento ancestral preparado por las comunidades indígenas. Se sirve como acompañamiento para otros platos o se come solo.',
#   'ingredients': 'Harina de yuca o mandioca',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/35. Casabe.png',
#   'departmentId': 17,
#   'department': {'id': 17,
#    'name': 'Guaviare',
#    'description': 'Guaviare es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es San José del Guaviare. Está ubicado en la región Amazonia, limitando al norte con Meta, al noreste con Vichada, al oeste con Guainía y al sur con Vaupés y Caquetá. Con 77,276 hab. según estimaciones del DANE,5\u200b es el quinto departamento menos poblado —por delante de Amazonas, San Andrés y Providencia, Guainía y Vaupés— y con 2,04 hab/km², el quinto menos densamente poblado, por delante de Vaupés, Amazonas, Vichada y Guainía, el menos densamente poblado',
#    'cityCapitalId': 654,
#    'municipalities': 4,
#    'surface': 53460,
#    'population': 90357,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 36,
#   'name': 'Pan de arroz',
#   'description': 'Un panecillo suave y crujiente por fuera, hecho a base de masa de arroz, queso y mantequilla, muy popular como merienda o desayuno.',
#   'ingredients': 'Arroz, queso costeño o queso campesino, harina de maíz, mantequilla, huevos, leche, sal',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/36. Pan de arroz.png',
#   'departmentId': 21,
#   'department': {'id': 21,
#    'name': 'Meta',
#    'description': 'Meta es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Villavicencio. Está ubicado en el centro del país, en la región Orinoquía, limitando al norte con Bogotá, Distrito Capital, Cundinamarca y Casanare, al este con Vichada, al sur con Guaviare y Caquetá, y al oeste con Huila. Con 85 635 km² es el cuarto departamento más extenso —por detrás de Amazonas, Vichada y Caquetá',
#    'cityCapitalId': 740,
#    'municipalities': 29,
#    'surface': 85635,
#    'population': 1080706,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 37,
#   'name': 'Maito de pescado',
#   'description': 'El maito consiste en un pescado fresco, como tilapia, bocachico o bagre, que se sazona con sal y especias, se envuelve en hojas de bijao y se cocina al carbón o al vapor.',
#   'ingredients': 'Pescado fresco, hojas de bijao, cebolla larga, ajo, limón, sal (al gusto), pimienta, aceite y aji amazonico',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/37. Maito de pescado.png',
#   'departmentId': 24,
#   'department': {'id': 24,
#    'name': 'Putumayo',
#    'description': 'Putumayo (Quechua: Putumayu) es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Mocoa y su ciudad más poblada es Puerto Asís. Está ubicado al suroeste del país, en la región Amazónica, limitando al norte con Cauca y Caquetá, al este con Amazonas, al sur con Perú y Ecuador, y al oeste con Nariño. La mayoría de sus municipios hace parte de los territorios focalizados',
#    'cityCapitalId': 872,
#    'municipalities': 13,
#    'surface': 24885,
#    'population': 369064,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 4,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
# ...
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 56,
#   'name': 'Chorizo antioqueño',
#   'description': 'Embutido de carne de cerdo sazonada, servido tradicionalmente con arepa y limón.',
#   'ingredients': 'Carne de cerdo, ajo, sal, comino, pimienta.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/56. Chorizo antioqueno.jpg',
#   'departmentId': 2,
#   'department': {'id': 2,
#    'name': 'Antioquia',
#    'description': 'Antioquia es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Medellín, la segunda ciudad más poblada del país. Está ubicado al noroccidente colombiano, en las regiones Andina y Caribe, limitando al norte con el mar Caribe (océano Atlántico), Córdoba y Bolívar, al este con Santander y Boyacá, al sur con Caldas y Risaralda, y al oeste con Chocó. Con unos 6 500 000 habitantes en 2015 es el departamento más poblado, y con 63 600 km², el sexto más extenso, superado por Amazonas, Vichada, Caquetá, Meta y Guainía.',
#    'cityCapitalId': 12,
#    'municipalities': 125,
#    'surface': 63612,
#    'population': 6887306,
#    'phonePrefix': '4',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 57,
#   'name': 'Mamona',
#   'description': 'Carne de res (ternera) asada lentamente al carbón, típica de los llanos orientales.',
#   'ingredients': 'Ternera, sal, ajo, especias.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/57. Mamona.png',
#   'departmentId': 21,
#   'department': {'id': 21,
#    'name': 'Meta',
#    'description': 'Meta es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Villavicencio. Está ubicado en el centro del país, en la región Orinoquía, limitando al norte con Bogotá, Distrito Capital, Cundinamarca y Casanare, al este con Vichada, al sur con Guaviare y Caquetá, y al oeste con Huila. Con 85 635 km² es el cuarto departamento más extenso —por detrás de Amazonas, Vichada y Caquetá',
#    'cityCapitalId': 740,
#    'municipalities': 29,
#    'surface': 85635,
#    'population': 1080706,
#    'phonePrefix': '8',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 3,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 58,
#   'name': 'Empanada de maíz',
#   'description': 'Masa de maíz rellena de carne, papa o queso, frita hasta quedar crujiente.',
#   'ingredients': 'Harina de maíz, carne, papa, cebolla, comin',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/58. Empanada de maiz.png',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 59,
#   'name': 'Arroz con pollo',
#   'description': 'Plato colorido de arroz con pollo desmenuzado y vegetales.',
#   'ingredients': 'Arroz, pollo, zanahoria, cebolla, arvejas, pimientos.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/59. Arroz con pollo.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 60,
#   'name': 'Pan de yuca',
#   'description': 'Panecillo suave hecho con harina de yuca y queso.',
#   'ingredients': 'Harina de yuca, queso, mantequilla, huevo.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/60. Pan de yuca.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 61,
#   'name': 'Merengón',
#   'description': 'Postre crujiente de merengue, crema y frutas frescas como guanábana o fresas.',
#   'ingredients': 'Claras de huevo, azúcar, crema de leche, frutas.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/61. Merengon.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 62,
#   'name': 'Breva con arequipe',
#   'description': 'Postre dulce de brevas cocidas en almíbar, rellenas con arequipe.',
#   'ingredients': 'Brevas, azúcar, canela, arequipe.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/62. Brevas con arequipe.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 63,
#   'name': 'Agua de panela',
#   'description': 'Bebida caliente o fría preparada con panela disuelta en agua.',
#   'ingredients': 'Panela, agua, limón',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/63. Agua de panela.jpg',
#   'departmentId': 15,
#   'department': {'id': 15,
#    'name': 'Cundinamarca',
#    'description': 'Cundinamarca es uno de los 32 departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bogotá, la capital del país. Está ubicado en el centro del país, en la región andina, limitando al norte Boyacá, al este y al sur con Meta, al sur con Huila y al oeste con Tolima y Caldas. Enclavado en su territorio se encuentra el Distrito Capital de Bogotá, al que rodea excepto por su límite suroriental.',
#    'cityCapitalId': 167,
#    'municipalities': 116,
#    'surface': 23071,
#    'population': 2473634,
#    'phonePrefix': '1',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 64,
#   'name': 'Carimañola',
#   'description': 'Fritura hecha de masa de yuca rellena de carne, queso o pollo.',
#   'ingredients': 'Yuca, carne, queso, huevo.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/64. Carimanola.jpg',
#   'departmentId': 6,
#   'department': {'id': 6,
#    'name': 'Bolívar',
#    'description': 'Bolívar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cartagena de Indias, sede de la asamblea departamental, mientras que en Turbaco se encuentra la sede de la gobernación. Está ubicado en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al noreste con Atlántico, al este con Magdalena y Cesar, al sureste con Santander, al suroeste con Antioquia y al oeste con Córdoba y Sucre.',
#    'cityCapitalId': 210,
#    'municipalities': 45,
#    'surface': 25978,
#    'population': 2236603,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 65,
#   'name': 'Gelatina de pata',
#   'description': 'Dulce hecho a base de patas de res cocidas, con sabor a panela.',
#   'ingredients': 'Pata de res, panela, canela.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/65. Gelatina de pata.jpg',
#   'departmentId': 31,
#   'department': {'id': 31,
#    'name': 'Valle del Cauca',
#    'description': 'Valle del Cauca es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cali. Está ubicado en las regiones Andina y del Pacífico, limitando al norte con Chocó y Risaralda, al este con Quindío y Tolima, al sur con Cauca y al oeste con el océano Pacífico. Con 4 600 000 habitantes en 2015 es el segundo departamento más poblado',
#    'cityCapitalId': 1093,
#    'municipalities': 42,
#    'surface': 22140,
#    'population': 4589278,
#    'phonePrefix': '2',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 2,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 66,
#   'name': 'Lengua sudada',
#   'description': 'Lengua de res cocida a fuego lento con una salsa espesa de tomate y especias.',
#   'ingredients': 'Lengua de res, tomate, cebolla, ajo, especias.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/66. Lengua sudada.png',
#   'departmentId': 28,
#   'department': {'id': 28,
#    'name': 'Santander',
#    'description': 'Santander es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Bucaramanga. Está ubicado al noreste del país, en la región andina, limitando al norte con Cesar y Norte de Santander, al este y sur con Boyacá, al oeste con Antioquia y al noroeste con Bolívar.7\u200b Con unos 2 280 908 habitantes en 2018 es el sexto departamento por población. Recibe su nombre en alusión a Francisco de Paula Santander, prócer de la independencia de la Nueva Granada',
#    'cityCapitalId': 915,
#    'municipalities': 87,
#    'surface': 30537,
#    'population': 2324090,
#    'phonePrefix': '7',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 5,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 67,
#   'name': 'Pollo asado',
#   'description': 'Pollo marinado y asado al carbón, acompañado de papa y ensalada.',
#   'ingredients': 'Pollo, ajo, sal, pimienta, especias.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/67. Pollo asado.jpg',
#   'departmentId': 4,
#   'department': {'id': 4,
#    'name': 'Atlántico',
#    'description': 'El Atlántico es uno de los treinta y dos departamentos que, junto a Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Barranquilla. Ubicado en la región Caribe, limita al norte con el mar Caribe, al Oriente con el río Magdalena y al Sur y al Occidente con el departamento de Bolívar. Con unos 2 500 000 habitantes en 2015, es el cuarto departamento más poblado (por detrás de Antioquia, Valle del Cauca y Cundinamarca); con 3019 km² es el tercero menos extenso (por delante de Quindío y San Andrés y Providencia, el menos extenso) y con 815 hab/km² es el segundo más densamente poblado (por detrás de San Andrés y Providencia)',
#    'cityCapitalId': 144,
#    'municipalities': 23,
#    'surface': 3388,
#    'population': 2804025,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}},
#  {'id': 68,
#   'name': 'Cazuela de mariscos',
#   'description': 'Sopa cremosa de mariscos, preparada con leche de coco y vegetales.',
#   'ingredients': 'Mariscos variados, leche de coco, cebolla, ajo, pimientos.',
#   'imageUrl': 'https://apicolombiastorage.blob.core.windows.net/typicaldishes/68. Cazuela de mariscos.jpg',
#   'departmentId': 6,
#   'department': {'id': 6,
#    'name': 'Bolívar',
#    'description': 'Bolívar es uno de los treinta y dos departamentos que, junto con Bogotá, Distrito Capital, forman la República de Colombia. Su capital es Cartagena de Indias, sede de la asamblea departamental, mientras que en Turbaco se encuentra la sede de la gobernación. Está ubicado en la región Caribe, limitando al norte con el mar Caribe (océano Atlántico), al noreste con Atlántico, al este con Magdalena y Cesar, al sureste con Santander, al suroeste con Antioquia y al oeste con Córdoba y Sucre.',
#    'cityCapitalId': 210,
#    'municipalities': 45,
#    'surface': 25978,
#    'population': 2236603,
#    'phonePrefix': '5',
#    'countryId': 1,
#    'cityCapital': None,
#    'country': None,
#    'cities': None,
#    'regionId': 1,
#    'region': None,
#    'naturalAreas': None,
#    'maps': None,
#    'indigenousReservations': None,
#    'airports': None}}]

# %%
print("Número de items en la lista de datos obtenida:")
print(len(data))
# Out:
# Número de items en la lista de datos obtenida:
# 68

# %%
# 3. Analizar uno de los items de la data
if data:
  first_item = data[32]
  print("Tipo de datos del primer item:")
  print(type(first_item))

  # Imprimir las llaves del diccionario:
  if isinstance(first_item, dict): # Check if the item is a dictionary
    print("Llaves del diccionario:")
    print(first_item.keys())

    # 5. Acceder a la llave descripcion del primer item de la lista
    if 'description' in first_item:
      print("Descripcion del primer item:")
      print(first_item['description'])
    else:
      print("'Llave 'description' no encontrada.")
  else:
    print("El primer item no es un diccionario.")
else:
  print("La lista de datos está vacia")
# Out:
# Tipo de datos del primer item:
# <class 'dict'>
# Llaves del diccionario:
# dict_keys(['id', 'name', 'description', 'ingredients', 'imageUrl', 'departmentId', 'department'])
# Descripcion del primer item:
# El chicharrón es un acompañante frecuente en el Cesar, preparado con carne de cerdo frita hasta quedar crujiente. Se sirve con arroz, arepas y otros acompañantes.

# %% [markdown]
# ## Códigos de estado HTTP comunes que indican errores:
# ---
# Los códigos de estado HTTP son números de tres dígitos que el servidor envía en la respuesta para indicar el resultado de la solicitud. Los códigos en el rango 4xx y 5xx generalmente indican errores:
#
# - **400 Bad Request:** La solicitud no pudo ser entendida por el servidor debido a una sintaxis inválida.
# - **401 Unauthorized:** La solicitud requiere autenticación. Puede que no hayas proporcionado credenciales o que estas sean inválidas.
# - **403 Forbidden:** La solicitud fue válida, pero el servidor se rehúsa a autorizarla. Puede que no tengas permisos para acceder al recurso.
# - **404 Not Found:** El servidor no pudo encontrar el recurso solicitado. El URL podría estar incorrecto.
# - **500 Internal Server Error:** El servidor encontró una condición inesperada que le impidió completar la solicitud. Esto es un error general del lado del servidor.
# - **503 Service Unavailable:** El servidor no está listo para manejar la solicitud. Esto puede ocurrir si el servidor está sobrecargado o en mantenimiento.
#
# Ejemplo:
# - https://www.google.com/test
# - https://www.google.com/search?q=test
#
# Cómo verificar el `response.status_code`:
#
# Después de realizar una solicitud utilizando la librería `requests`, el objeto `response` tiene un atributo `status_code` que contiene el código de estado HTTP. Podemos usar una sentencia `if` para verificar este código.

# %%
import requests

base_url = "https://api-colombia.com/api/v1"
endpoint = "/Department" # Este endpoint debería funcionar (código 200)
invalid_endpoint = "/NonExistentEndpoint" # Este endpoint debería generar un error 404

response_valid = requests.get(base_url + endpoint)
print(f"\nSolicitud a {base_url + endpoint}")
print(f"Código de estado: {response_valid.status_code}")

if response_valid.status_code == 200:
    print("Solicitud exitosa.")
elif response_valid.status_code == 404:
    print("Error 404: Recurso no encontrado.")
elif response_valid.status_code == 401:
    print("Error 401: No autorizado.")
else:
    print(f"Error inesperado: Código de estado {response_valid.status_code}")
# Out:
# Solicitud a https://api-colombia.com/api/v1/Department
# Código de estado: 200
# Solicitud exitosa.

# %%
response_invalid = requests.get(base_url + invalid_endpoint)
print(f"\nSolicitud a {base_url + invalid_endpoint}")
print(f"Código de estado: {response_invalid.status_code}")

if response_invalid.status_code == 200:
    print("Solicitud exitosa.")
elif response_invalid.status_code == 404:
    print("Error 404: Recurso no encontrado.")
    print("Verifica que el URL del endpoint sea correcto.")
elif response_invalid.status_code == 401:
    print("Error 401: No autorizado.")
else:
    print(f"Error inesperado: Código de estado {response_invalid.status_code}")
# Out:
# Solicitud a https://api-colombia.com/api/v1/NonExistentEndpoint
# Código de estado: 404
# Error 404: Recurso no encontrado.
# Verifica que el URL del endpoint sea correcto.

# %% [markdown]
# ## Ejercicios prácticos
#
# ---
# Ejercicio 1: Explora otro endpoint
#
# Ya has visto cómo obtener una lista de departamentos. Ahora, intenta obtener información sobre otro recurso.
#
# Instrucciones:
# 1. Haz una solicitud GET al endpoint `/Country` (para obtener información sobre Colombia) o `/City` (para obtener una lista de ciudades). Elige uno de ellos.
# 2. Imprime el código de estado de la respuesta para asegurarte de que la solicitud fue exitosa (debería ser 200).
# 3. Si la solicitud fue exitosa y obtuviste una lista de datos (como en el caso de `/City`), imprime el nombre del primer elemento en la lista de datos. Si elegiste `/Country`, imprime el nombre del país.
#
# Aquí tienes un ejemplo de cómo empezar (completa las partes que faltan):

# %%
base_url = "https://api-colombia.com/api/v1"
chosen_endpoint = "/City" 

respuesta_api = requests.get(base_url + chosen_endpoint)

# %%
import pandas as pd
print(respuesta_api.status_code) ## Reviso el codigo de estado. DEbe ser 200 para indicar que la solicitud fue exitosa.
respuesta_json = respuesta_api.json()  ## Almaceno la respuesta en formato JSON en una variable
print(respuesta_json)
df_api = pd.DataFrame.from_dict(respuesta_json) ## Utilizo ese JSON para crear un DataFrame de pandas
# Out:
# 200
# [{'id': 3, 'image': 'https://upload.wikimedia.org/wikipedia/commons/d/db/Rafael_Nunez.JPG', 'name': 'Rafael', 'lastName': 'Nuñez Moledo', 'startPeriodDate': '1887-06-04', 'endPeriodDate': '1888-08-07', 'politicalParty': 'Partido nacional', 'description': 'Rafael Wenceslao Núñez Moledo (Cartagena, 28 de septiembre de 1825-Ib., 18 de septiembre de 1894) fue un abogado, periodista, escritor, político y militar colombiano, antiguo miembro del Partido Liberal Colombiano y luego líder del Partido Nacional. Primero como liberal moderado y luego como líder de una coalición bipartidista, Núñez fue a nombre propio presidente del país en 4 ocasiones, y fue clave para el ascenso político de figuras como Miguel Antonio Caro, Carlos Holguín, Eliseo Payán, Francisco Javier Zaldúa, entre otros importantes personajes. También fue clave para el regreso de los conservadores al poder, en lo que se conoció como hegemonía conservadora.', 'cityId': 210, 'city': None}, {'id': 4, 'image': 'https://upload.wikimedia.org/wikipedia/commons/e/e9/Carlos-holguin-Mallarino.jpg', 'name': 'Carlos', 'lastName': 'Holguín Mallarino', 'startPeriodDate': '1888-08-07', 'endPeriodDate': '1892-08-07', 'politicalParty': 'Partido nacional', 'description': 'Carlos Holguín Mallarino (Nóvita, Chocó, 11 de julio de 1832-Bogotá, 19 de octubre de 1894) fue un abogado, empresario, diplomático, político, periodista y militar colombiano, miembro del Partido Conservador Colombiano. Previamente a su presidencia Holguín había destacado como periodista. En Cali creó el periódico El Caucano (1857). En Bogotá colaboró con la redacción de La Prensa. Igualmente fue un asiduo colaborador de los periódicos conservadores de la capital, El Conservador, El Filotémico, El Porvenir y El Tradicionista entre otros. Además escribió numerosos sonetos y escritos en periódicos y revistas. En sus escritos fue sarcástico, irónico, polemista y crítico.', 'cityId': 482, 'city': None}, {'id': 5, 'image': 'https://upload.wikimedia.org/wikipedia/commons/4/4b/Miguel_antonio_caro.png', 'name': 'Miguel Antonio', 'lastName': 'Caro', 'startPeriodDate': '1892-08-07', 'endPeriodDate': '1892-09-21', 'politicalParty': 'Partido nacional', 'description': 'Miguel Antonio José Zolio Cayetano Andrés Avelino de las Mercedes Caro Tobar (Bogotá, 10 de noviembre de 1843-Bogotá, 5 de agosto de 1909), más conocido simplemente como Miguel Antonio Caro, fue un humanista, periodista, escritor, filólogo y político colombiano. Presidente de Colombia, entre 1892 a 1898 y Vicepresidente de Colombia, entre 1892 y 1894.', 'cityId': 167, 'city': None}, {'id': 6, 'image': 'https://upload.wikimedia.org/wikipedia/commons/d/db/Rafael_Nunez.JPG', 'name': 'Rafael', 'lastName': 'Nuñez Moledo', 'startPeriodDate': '1892-09-21', 'endPeriodDate': '1894-09-18', 'politicalParty': 'Partido nacional', 'description': 'Rafael Wenceslao Núñez Moledo (Cartagena, 28 de septiembre de 1825-Ib., 18 de septiembre de 1894) fue un abogado, periodista, escritor, político y militar colombiano, antiguo miembro del Partido Liberal Colombiano y luego líder del Partido Nacional. Primero como liberal moderado y luego como líder de una coalición bipartidista, Núñez fue a nombre propio presidente del país en 4 ocasiones, y fue clave para el ascenso político de figuras como Miguel Antonio Caro, Carlos Holguín, Eliseo Payán, Francisco Javier Zaldúa, entre otros importantes personajes. También fue clave para el regreso de los conservadores al poder, en lo que se conoció como hegemonía conservadora.', 'cityId': 210, 'city': None}, {'id': 7, 'image': 'https://upload.wikimedia.org/wikipedia/commons/b/b3/Antonio_Basilio_Cuervo.jpg', 'name': 'Antonio', 'lastName': 'Basilio Cuervo', 'startPeriodDate': '1893-01-16', 'endPeriodDate': '1893-01-17', 'politicalParty': 'Partido Conservador', 'description': 'Antonio Basilio Cuervo Urisarri (Bogotá, 13 de junio de 1834-Ibídem, 19 de febrero de 1893) fue un militar, geógrafo, escritor, diplomático, abogado, periodista, historiador y polít ...

# %%
df_api
# Out:
#     id                                              image               name  \
# 0    3  https://upload.wikimedia.org/wikipedia/commons...             Rafael
# 1    4  https://upload.wikimedia.org/wikipedia/commons...             Carlos
# 2    5  https://upload.wikimedia.org/wikipedia/commons...     Miguel Antonio
# 3    6  https://upload.wikimedia.org/wikipedia/commons...             Rafael
# 4    7  https://upload.wikimedia.org/wikipedia/commons...            Antonio
# 5    8  https://upload.wikimedia.org/wikipedia/commons...     Miguel Antonio
# 6    9  https://upload.wikimedia.org/wikipedia/commons...          Guillermo
# 7    2  https://upload.wikimedia.org/wikipedia/commons...             Eliseo
# 8   10  https://upload.wikimedia.org/wikipedia/commons...     Manuel Antonio
# 9   11  https://upload.wikimedia.org/wikipedia/commons...        Jose Manuel
# 10  12  https://upload.wikimedia.org/wikipedia/commons...             Rafael
# 11  14  https://upload.wikimedia.org/wikipedia/commons...              Jorge
# 12  15  https://upload.wikimedia.org/wikipedia/commons...              Ramon
# 13  16  https://upload.wikimedia.org/wikipedia/commons...     Carlos Eugenio
# 14  17  https://upload.wikimedia.org/wikipedia/commons...       Jose Vicente
# 15  13  https://enciclopedia.banrepcultural.org/images...     Diego Euclides
# 16  18  https://upload.wikimedia.org/wikipedia/commons...        Marco Fidel
# 17  19  https://upload.wikimedia.org/wikipedia/commons...              Jorge
# 18  20  https://upload.wikimedia.org/wikipedia/commons...          Pedro Nel
# 19  21  https://upload.wikimedia.org/wikipedia/commons...             Miguel
# 20  22  https://upload.wikimedia.org/wikipedia/commons...            Enrique
# 21  23  https://upload.wikimedia.org/wikipedia/commons...            Alfonso
# 22  24  https://upload.wikimedia.org/wikipedia/commons...     Eduardo Santos
# 23  46  https://upload.wikimedia.org/wikipedia/commons...              Cesar
# 24  25  https://upload.wikimedia.org/wikipedia/commons...            Alfonso
# 25  26  https://upload.wikimedia.org/wikipedia/commons...             Carlos
# 26  27  https://upload.wikimedia.org/wikipedia/commons...              Dario
# 27  28  https://upload.wikimedia.org/wikipedia/commons...            Alberto
# 28  29  https://upload.wikimedia.org/wikipedia/commons...            Mariano
# 29  30  https://upload.wikimedia.org/wikipedia/commons...           Laureano
# 30  31  https://upload.wikimedia.org/wikipedia/commons...            Roberto
# 31  32  https://upload.wikimedia.org/wikipedia/commons...            Gustavo
# 32  33  https://upload.wikimedia.org/wikipedia/commons...      Junta Militar
# 33  34  https://upload.wikimedia.org/wikipedia/commons...            Alberto
# 34  36                                                          Jose Antonio
# 35  37  https://upload.wikimedia.org/wikipedia/commons...             Carlos
# 36  38  https://upload.wikimedia.org/wikipedia/commons...             Misael
# 37  39                                                                Rafael
# 38  40  https://upload.wikimedia.org/wikipedia/commons...            Alfonso
# 39  41                                               null          Indalecio
# 40  42  https://upload.wikimedia.org/wikipedia/commons...        Julio Cesar
# 41  44  https://upload.wikimedia.org/wikipedia/commons...           Belisaio
# 42  45  https://upload.wikimedia.org/wikipedia/commons...           Virgilio
# 43  47  https://upload.wikimedia.org/wikipedia/commons...            Ernesto
# 44  48  https://upload.wikimedia.org/wikipedia/commons...             Andres
# 45  49  https://upload.wikimedia.org/wikipedia/commons...             Alvaro
# 46  50  https://upload.wikimedia.org/wikipedia/commons...        Juan Manuel
# 47  51  https://upload.wikimedia.org/wikipedia/commons...               Ivan
# 48   1  https://upload.wikimedia.org/wikipedia/commons...         José María
# 49  35  https://upload.wikimedia.org/wikipedia/commons...     Guillermo Leon
# 50  53  https://upload.wikimedia.org/wikipedia/commons...   Abelardo Gabriel
# 51  52  https://upload.wikimedia.org/wikipedia/commons...  Gustavo Francisco
# 52  43  https://upload.wikimedia.org/wikipedia/commons...      Victor Manuel
#
#                  lastName startPeriodDate endPeriodDate  \
# 0            Nuñez Moledo      1887-06-04    1888-08-07
# 1       Holguín Mallarino      1888-08-07    1892-08-07
# 2                    Caro      1892-08-07    1892-09-21
# 3            Nuñez Moledo      1892-09-21    1894-09-18
# 4          Basilio Cuervo      1893-01-16    1893-01-17
# 5                    Caro      1894-09-18    1898-08-07
# 6       Quintero Calderón      1896-03-12    1896-03-17
# 7           Payán Hurtado      1887-01-07    1887-06-04
# 8             Sanclemente      1898-07-08    1900-07-31
# 9               Marroquin      1900-07-31    1904-08-07
# 10           Reyes Prieto      1904-08-07    1909-06-09
# 11      Holguin Mallarino      1909-06-09    1909-08-04
# 12      Gonzalez Valencia      1909-08-04    1910-08-07
# 13      Restrepo Restrepo      1910-08-07    1914-08-07
# 14                 Concha      1914-08-07    1918-08-07
# 15        De Angulo Lemos      1908-03-09    1908-04-14
# 16                 Suarez      1918-08-07    1921-11-11
# 17      Holguin Mallarino      1921-11-11    1922-08-07
# 18         Ospino vasquez      1922-08-07    1926-08-07
# 19          Abadia Mendez      1926-08-07    1930-08-07
# 20          Olaya Herrera      1930-08-07    1934-08-07
# 21         Lopez Pumarejo      1934-08-07    1938-08-07
# 22                Montejo      1938-08-07    1942-08-07
# 23       gaviria Trujillo      1990-08-07    1994-08-07
# 24         Lopez Pumarejo      1942-08-07    1945-08-07
# 25        Lozano y Lozano      1942-10-09    1942-10-19
# 26         Echandia Olaya      1943-10-19    1943-05-16
# 27         Lleras Camargo      1945-08-07    1946-08-07
# 28           Ospina Perez      1946-08-07    1950-08-07
# 29           Gomez Castro      1950-08-07    1951-11-05
# 30      Urdaneta Arbelaez      1951-11-05    1953-06-13
# 31          Rojas Pinilla      1953-06-13    1957-05-10
# 32            De Gobierno      1957-05-10    1958-08-07
# 33         Lleras Camargo      1958-08-07    1962-08-07
# 34               Monsalvo      1963-08-06    1963-08-08
# 35        Lleras Restrepo      1966-08-07    1970-08-07
# 36       Pastrana Borrero      1970-08-07    1974-08-07
# 37        Azuero Manchola      1973-07-21    1973-07-24
# 38        Lopez Michelsen      1974-08-07    1978-08-07
# 39        Liévano Aguirre      1976-10-06    1976-12-30
# 40                 Turbay      1978-08-07    1982-08-07
# 41       Betancur Cuartas      1982-08-07    1986-08-07
# 42           Barco vargas      1986-08-07    1990-08-07
# 43          Samper Pizano      1994-08-07    1998-08-07
# 44        Pastrana Arango      1998-08-07    2002-08-07
# 45            Uribe Velez      2002-08-07    2010-08-07
# 46        Santos Calderon      2010-08-07    2018-08-07
# 47          Duque Marquez      2018-08-07    2022-08-07
# 48          Campo Serrano      1886-08-05    1887-01-06
# 49               Valencia      1962-08-07    1966-08-07
# 50  De la Espriella Otero      2026-08-07           NaN
# 51           Petro Urrego      2022-08-07    2026-08-07
# 52         Mosquera Chaux      1981-02-03    1981-11-27
#
#                      politicalParty  \
# 0                  Partido nacional
# 1                  Partido nacional
# 2                  Partido nacional
# 3                  Partido nacional
# 4               Partido Conservador
# 5                  Partido nacional
# 6               Partido Conservador
# 7                  Partido Nacional
# 8                  Partido nacional
# 9               Partido conservador
# 10              Partido conservador
# 11              Partido conservador
# 12              Partido conservador
# 13  Unión Republicana (Conservador)
# 14              Partido conservador
# 15              Partido conservador
# 16              Partido conservador
# 17              Partido conservador
# 18              Partido conservador
# 19              Partido conservador
# 20                  Partido Liberal
# 21                  Partido Liberal
# 22                  Partido Liberal
# 23                  Partido Liberal
# 24                  Partido Liberal
# 25                  Partido Liberal
# 26                  Partido Liberal
# 27                  Partido Liberal
# 28              Partido Conservador
# 29              Partido Conservador
# 30              Partido Conservador
# 31                          Militar
# 32                          Militar
# 33                  Partido Liberal
# 34              Partido Conservador
# 35                  Partido Liberal
# 36              Partido Conservador
# 37              Partido Conservador
# 38                  Partido Liberal
# 39                  Partido Liberal
# 40                  Partido Liberal
# 41              Partido conservador
# 42                  Partido Liberal
# 43                  Partido Liberal
# 44              Partido conservador
# 45         Partido Primero Colombia
# 46                  Partido de la U
# 47       Partido Centro Democratico
# 48                 Partido Nacional
# 49              Partido Conservador
# 50          Defensores de la Patria
# 51                  Colombia Humana
# 52                  Partido Liberal
#
#                                           description  cityId  city
# 0   Rafael Wenceslao Núñez Moledo (Cartagena, 28 d...     210  None
# 1   Carlos Holguín Mallarino (Nóvita, Chocó, 11 de...     482  None
# 2   Miguel Antonio José Zolio Cayetano Andrés Avel...     167  None
# 3   Rafael Wenceslao Núñez Moledo (Cartagena, 28 d...     210  None
# 4   Antonio Basilio Cuervo Urisarri (Bogotá, 13 de...     167  None
# 5   Miguel Antonio José Zolio Cayetano Andrés Avel...     167  None
# 6   Guillermo Quintero Calderón (Puerto Nacional, ...     452  None
# 7   José Eliseo Payán Hurtado (Cali, 1 de agosto d...    1093  None
# 8   Manuel Antonio San-clemente (Buga, 15 de septi...    1095  None
# 9   José Manuel Marroquín Ricaurte (Bogotá, 6 de a...     167  None
# 10  José Gregorio Rafael Reyes Prieto (Santa Rosa ...     328  None
# 11  Jorge Marcelo Holguín Mallarino (Santiago de C...    1093  None
# 12  José Rafael Ramón Eufrasio de Jesús González V...     857  None
# 13  Carlos Eugenio Restrepo Restrepo (Medellín, 12...      12  None
# 14  José Vicente Concha Ferreira (Bogotá, 21 de ab...     167  None
# 15  Diego Euclides de Angulo Lemos (Popayán, 12 de...     399  None
# 16  Marco Fidel Suárez Barrientos (Hatoviejo, 23 d...      29  None
# 17  Jorge Marcelo Holguín Mallarino (Santiago de C...    1093  None
# 18  Pedro Nel Ignacio Tomás de Villanueva Ospina V...     167  None
# 19  Miguel Abadía Méndez (Coello, 5 de julio de 18...      30  None
# 20  Enrique Alfredo Olaya Herrera (Guateque, 12 de...     255  None
# 21  Alfonso López Pumarejo (Honda, Tolima, 31 de e...    1043  None
# 22  Eduardo Santos Montejo (Bogotá,1​2​3​28 de ago...     167  None
# 23  César Augusto Gaviria Trujillo (Pereira, 31 de...     897  None
# 24  Alfonso López Pumarejo (Honda, Tolima, 31 de e...    1043  None
# 25  Carlos Lozano y Lozano (Fusagasugá, Cundinamar...     640  None
# 26  Darío Echandía Olaya (Chaparral, 13 de octubre...    1069  None
# 27  Alberto Lleras Camargo (Bogotá,1​ 3 de julio d...     167  None
# 28  Luis Mariano Ospina Pérez (Medellín, 24 de nov...      12  None
# 29  Laureano Eleuterio Gómez Castro1​ (Bogotá, 20 ...     167  None
# 30  Roberto Urdaneta Arbeláez (Bogotá, 27 de junio...     167  None
# 31  Gustavo Rojas Pinilla (Tunja, 12 de marzo de 1...    1046  None
# 32  La Junta Militar de Gobierno de 1957 fue el ór...     167  None
# 33  Alberto Lleras Camargo (Bogotá,1​ 3 de julio d...     167  None
# 34  Montalvo Berbeo nació en Bogotá el 22 de febre...     167  None
# 35  Carlos Alberto Lleras Restrepo (Bogotá, 12 de ...     167  None
# 36  Misael Eduardo Pastrana Borrero (Neiva, 14 de ...     167  None
# 37  Rafael Azuero Manchola (Neiva, 21 de septiembr...     657  None
# 38  Alfonso López Michelsen (Bogotá, 30 de junio d...     167  None
# 39  Indalecio Liévano Aguirre (Bogotá, 24 de julio...     167  None
# 40  Julio César Turbay Ayala (Bogotá, 18 de junio ...     167  None
# 41  Belisario Antonio Betancur Cuartas (Amagá, 4 d...      16  None
# 42  Virgilio Barco Vargas (Cúcuta, 17 de septiembr...     870  None
# 43  Ernesto Samper Pizano (Bogotá, 3 de agosto de ...     167  None
# 44  Andrés Pastrana Arango (Bogotá, 17 de agosto d...     167  None
# 45  Álvaro Uribe Vélez (Medellín, 4 de julio de 19...      12  None
# 46  Juan Manuel Santos Calderón (Bogotá, 10 de ago...     167  None
# 47  Iván Duque Márquez (Bogotá, 1 de agosto de 197...     167  None
# 48  José María Campo Serrano (Santa Marta, 8 de se...     709  None
# 49  Guillermo León Valencia Muñoz (Popayán, 27 de ...     399  None
# 50  Abelardo Gabriel de la Espriella Otero (Bogotá...     167  None
# 51  Gustavo Francisco Petro Urrego (Ciénaga de Oro...     522  None
# 52  Víctor Manuel Mosquera Chaux (Popayán, 1° de o...     399  None

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.histplot(data=df_api, x='population')
plt.title('Distribución de la población de las ciudades por departamento')
# Out:
# Text(0.5, 1.0, 'Distribución de la población de las ciudades por departamento')

# %%
# Guardar el DataFrame en un archivo CSV sin el índice
df_api.to_csv("ciudades_colombia.csv", index=False)

# %% [markdown]
# ## Ejercicio 2: Iterando sobre una lista de recursos
#
# ---
#
# Muchas veces, las APIs te devolverán listas de elementos. Es útil saber cómo recorrer estas listas para acceder a la información de cada elemento.
#
# Instrucciones:
# 1. Haz una solicitud GET al endpoint `/Department` para obtener la lista de departamentos (¡ya hicimos esto antes!).
# 2. Si la solicitud es exitosa, itera sobre la lista de departamentos obtenida.
# 3. Para cada departamento en la lista, imprime su nombre y el número de municipios que tiene. Puedes acceder a esta información a través de las claves 'name' y 'municipalities' en cada diccionario de departamento.

# %% [markdown]
# ## Ejercicio 3: ¡Explora por tu cuenta!
#
# ---
#
#
#
# La API de Colombia tiene otros endpoints interesantes, como `/President`, `/NaturalArea`, `/IndigenousReservation`, etc.
#
# Instrucciones:
# 1. Consulta la documentación de la API (puedes encontrarla buscando "API Colombia documentation" en Google).
# 2. Elige un endpoint diferente a los que hemos usado (`/Department`, `/Country`, `/City`).
# 3. Intenta hacer una solicitud a ese endpoint y explorar los datos que devuelve. ¿Qué tipo de información obtienes? Intenta imprimir algún detalle relevante de los elementos devueltos.

# %%
import requests

base_url = "https://potterapi-fedeperin.vercel.app/en"
endpoint = "/spells"
response1 = requests.get(base_url + endpoint)

if response1.status_code == 200:
  print("Conexión exitosa a la API. Codigo de estado:", response1.status_code)
else:
  print("Conexión fallida a la API. Codigo de estado", response1.status_code)
# Out:
# Conexión exitosa a la API. Codigo de estado: 200

# %%
import requests

base_url = "https://api-colombia.com/"
endpoint = "api/v1/Department"
response2 = requests.get(base_url + endpoint)

if response2.status_code == 200:
  print("Conexión exitosa a la API. Codigo de estado:", response2.status_code)
else:
  print("Conexión fallida a la API. Codigo de estado", response2.status_code)
# Out:
# Conexión exitosa a la API. Codigo de estado: 200

# %%
## Escribir datos de respuesta de la api a un archivo plano

data = response2.json()

data_string = str(data)

import json

output_filename = "api_response.txt"

with open(output_filename, "w") as f:
    f.write(data_string)
    #json.dump(data, f, indent=4)  # `indent=4` for pretty-printing
print(f"API response saved to {output_filename}")
# Out:
# API response saved to api_response.txt

# %% [markdown]
# ## Beneficios de usar APIs:
# ---
# **Para desarrolladores:**
# *   Ahorro de tiempo y esfuerzo al no tener que crear funcionalidades desde cero.
# *   Acceso a datos y servicios de terceros para enriquecer sus propias aplicaciones.
# *   Mayor modularidad y mantenibilidad del código.
#
# **Para usuarios:**
# *   Experiencias de usuario más integradas y fluidas (por ejemplo, iniciar sesión con una sola cuenta).
# *   Acceso a una mayor variedad de funcionalidades y servicios dentro de una sola aplicación.

# %% [markdown]
# # Prueba API con Logeo

# %%
base_url = "http://api.weatherapi.com/v1/"
endpoint = "forecast.json?key=1bc42701513e41cc82024016261405&q=London&aqi=no&days=5"

response = requests.get(base_url + endpoint)

print(response.status_code)
# Out:
# 200

# %%
import pandas as pd
import json 

diccionario  = response.json()
print(diccionario['forecast']['forecastday'])

data = pd.DataFrame.from_dict(diccionario['forecast']['forecastday'])
data
# Out:
# [{'date': '2026-08-13', 'date_epoch': 1786579200, 'day': {'maxtemp_c': 37.3, 'maxtemp_f': 99.1, 'mintemp_c': 20.0, 'mintemp_f': 68.1, 'avgtemp_c': 28.5, 'avgtemp_f': 83.3, 'maxwind_mph': 10.1, 'maxwind_kph': 16.2, 'totalprecip_mm': 0.0, 'totalprecip_in': 0.0, 'totalsnow_cm': 0.0, 'avgvis_km': 10.0, 'avgvis_miles': 6.0, 'avghumidity': 33, 'daily_will_it_rain': 0, 'daily_chance_of_rain': 1, 'daily_will_it_snow': 0, 'daily_chance_of_snow': 0, 'condition': {'text': 'Sunny', 'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png', 'code': 1000}, 'uv': 6.2}, 'astro': {'sunrise': '05:43 AM', 'sunset': '08:27 PM', 'moonrise': '06:06 AM', 'moonset': '08:41 PM', 'moon_phase': 'New Moon', 'moon_illumination': 2, 'is_moon_up': 0, 'is_sun_up': 0}, 'hour': [{'time_epoch': 1786575600, 'time': '2026-08-13 00:00', 'temp_c': 22.4, 'temp_f': 72.2, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 6.0, 'wind_kph': 9.7, 'wind_degree': 87, 'wind_dir': 'E', 'pressure_mb': 1022.0, 'pressure_in': 30.19, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 47, 'cloud': 0, 'feelslike_c': 20.6, 'feelslike_f': 69.1, 'windchill_c': 22.4, 'windchill_f': 72.2, 'heatindex_c': 24.4, 'heatindex_f': 75.9, 'dewpoint_c': 10.5, 'dewpoint_f': 50.8, 'will_it_rain': 0, 'chance_of_rain': 1, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 10.6, 'gust_kph': 17.1, 'uv': 0}, {'time_epoch': 1786579200, 'time': '2026-08-13 01:00', 'temp_c': 21.7, 'temp_f': 71.1, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 5.8, 'wind_kph': 9.4, 'wind_degree': 85, 'wind_dir': 'E', 'pressure_mb': 1022.0, 'pressure_in': 30.18, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 50, 'cloud': 0, 'feelslike_c': 20.1, 'feelslike_f': 68.2, 'windchill_c': 21.7, 'windchill_f': 71.1, 'heatindex_c': 24.4, 'heatindex_f': 75.8, 'dewpoint_c': 10.7, 'dewpoint_f': 51.3, 'will_it_rain': 0, 'chance_of_rain': 2, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 11.1, 'gust_kph': 17.8, 'uv': 0}, {'time_epoch': 1786582800, 'time': '2026-08-13 02:00', 'temp_c': 21.2, 'temp_f': 70.2, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 5.4, 'wind_kph': 8.6, 'wind_degree': 85, 'wind_dir': 'E', 'pressure_mb': 1022.0, 'pressure_in': 30.17, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 52, 'cloud': 0, 'feelslike_c': 19.9, 'feelslike_f': 67.8, 'windchill_c': 21.2, 'windchill_f': 70.2, 'heatindex_c': 24.4, 'heatindex_f': 75.8, 'dewpoint_c': 11.0, 'dewpoint_f': 51.8, 'will_it_rain': 0, 'chance_of_rain': 2, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 10.8, 'gust_kph': 17.3, 'uv': 0}, {'time_epoch': 1786586400, 'time': '2026-08-13 03:00', 'temp_c': 20.8, 'temp_f': 69.4, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 4.5, 'wind_kph': 7.2, 'wind_degree': 79, 'wind_dir': 'E', 'pressure_mb': 1021.0, 'pressure_in': 30.16, 'precip_mm': 0.0, 'precip_in': 0.0, 'snow_cm': 0.0, 'humidity': 54, 'cloud': 0, 'feelslike_c': 19.8, 'feelslike_f': 67.6, 'windchill_c': 20.8, 'windchill_f': 69.4, 'heatindex_c': 20.8, 'heatindex_f': 69.4, 'dewpoint_c': 11.2, 'dewpoint_f': 52.2, 'will_it_rain': 0, 'chance_of_rain': 2, 'will_it_snow': 0, 'chance_of_snow': 0, 'vis_km': 10.0, 'vis_miles': 6.0, 'gust_mph': 9.4, 'gust_kph': 15.1, 'uv': 0}, {'time_epoch': 1786590000, 'time': '2026-08-13 04:00', 'temp_c': 20.4, 'temp_f': 68.7, 'is_day': 0, 'condition': {'text': 'Clear', 'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png', 'code': 1000}, 'wind_mph': 4.3, 'wind_kph': 6.8, 'wind_degree': 81, 'wind_dir': 'E', 'pressure_mb': 1021.0, 'pressure_in': 30.15, 'precip_mm': 0.0, ...
#          date  date_epoch                                                day  \
# 0  2026-08-13  1786579200  {'maxtemp_c': 37.3, 'maxtemp_f': 99.1, 'mintem...
# 1  2026-08-14  1786665600  {'maxtemp_c': 33.9, 'maxtemp_f': 93.0, 'mintem...
# 2  2026-08-15  1786752000  {'maxtemp_c': 26.5, 'maxtemp_f': 79.7, 'mintem...
#
#                                                astro  \
# 0  {'sunrise': '05:43 AM', 'sunset': '08:27 PM', ...
# 1  {'sunrise': '05:44 AM', 'sunset': '08:25 PM', ...
# 2  {'sunrise': '05:46 AM', 'sunset': '08:23 PM', ...
#
#                                                 hour
# 0  [{'time_epoch': 1786575600, 'time': '2026-08-1...
# 1  [{'time_epoch': 1786662000, 'time': '2026-08-1...
# 2  [{'time_epoch': 1786748400, 'time': '2026-08-1...

# %%
data.to_csv("datosAPI.csv")

# %%
response.json()
# Out:
# {'location': {'name': 'London',
#   'region': 'City of London, Greater London',
#   'country': 'United Kingdom',
#   'lat': 51.5171,
#   'lon': -0.1062,
#   'tz_id': 'Europe/London',
#   'localtime_epoch': 1786576679,
#   'localtime': '2026-08-13 00:17'},
#  'current': {'last_updated_epoch': 1786575600,
#   'last_updated': '2026-08-13 00:00',
#   'temp_c': 21.7,
#   'temp_f': 71.1,
#   'is_day': 0,
#   'condition': {'text': 'Clear',
#    'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#    'code': 1000},
#   'wind_mph': 5.8,
#   'wind_kph': 9.4,
#   'wind_degree': 85,
#   'wind_dir': 'E',
#   'pressure_mb': 1022.0,
#   'pressure_in': 30.18,
#   'precip_mm': 0.0,
#   'precip_in': 0.0,
#   'humidity': 50,
#   'cloud': 0,
#   'feelslike_c': 20.1,
#   'feelslike_f': 68.2,
#   'windchill_c': 21.7,
#   'windchill_f': 71.1,
#   'heatindex_c': 24.4,
#   'heatindex_f': 75.8,
#   'dewpoint_c': 10.7,
#   'dewpoint_f': 51.3,
#   'vis_km': 10.0,
#   'vis_miles': 6.0,
#   'uv': 0.0,
#   'gust_mph': 11.1,
#   'gust_kph': 17.8,
#   'will_it_rain': 0,
#   'chance_of_rain': 2,
#   'will_it_snow': 0,
#   'chance_of_snow': 0},
#  'forecast': {'forecastday': [{'date': '2026-08-13',
#     'date_epoch': 1786579200,
#     'day': {'maxtemp_c': 37.3,
#      'maxtemp_f': 99.1,
#      'mintemp_c': 20.0,
#      'mintemp_f': 68.1,
#      'avgtemp_c': 28.5,
#      'avgtemp_f': 83.3,
#      'maxwind_mph': 10.1,
#      'maxwind_kph': 16.2,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 33,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 1,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'uv': 6.2},
#     'astro': {'sunrise': '05:43 AM',
#      'sunset': '08:27 PM',
#      'moonrise': '06:06 AM',
#      'moonset': '08:41 PM',
#      'moon_phase': 'New Moon',
#      'moon_illumination': 2,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1786575600,
#       'time': '2026-08-13 00:00',
#       'temp_c': 22.4,
#       'temp_f': 72.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 87,
#       'wind_dir': 'E',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.19,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 47,
#       'cloud': 0,
#       'feelslike_c': 20.6,
#       'feelslike_f': 69.1,
#       'windchill_c': 22.4,
#       'windchill_f': 72.2,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.9,
#       'dewpoint_c': 10.5,
#       'dewpoint_f': 50.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.1,
#       'uv': 0},
#      {'time_epoch': 1786579200,
#       'time': '2026-08-13 01:00',
#       'temp_c': 21.7,
#       'temp_f': 71.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 85,
#       'wind_dir': 'E',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.18,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 0,
#       'feelslike_c': 20.1,
#       'feelslike_f': 68.2,
#       'windchill_c': 21.7,
#       'windchill_f': 71.1,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.8,
#       'dewpoint_c': 10.7,
#       'dewpoint_f': 51.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.8,
#       'uv': 0},
#      {'time_epoch': 1786582800,
#       'time': '2026-08-13 02:00',
#       'temp_c': 21.2,
#       'temp_f': 70.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 85,
#       'wind_dir': 'E',
#       'pressure_mb': 1022.0,
#       'pressure_in': 30.17,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 52,
#       'cloud': 0,
#       'feelslike_c': 19.9,
#       'feelslike_f': 67.8,
#       'windchill_c': 21.2,
#       'windchill_f': 70.2,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.8,
#       'dewpoint_c': 11.0,
#       'dewpoint_f': 51.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.8,
#       'gust_kph': 17.3,
#       'uv': 0},
#      {'time_epoch': 1786586400,
#       'time': '2026-08-13 03:00',
#       'temp_c': 20.8,
#       'temp_f': 69.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.5,
#       'wind_kph': 7.2,
#       'wind_degree': 79,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.16,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 0,
#       'feelslike_c': 19.8,
#       'feelslike_f': 67.6,
#       'windchill_c': 20.8,
#       'windchill_f': 69.4,
#       'heatindex_c': 20.8,
#       'heatindex_f': 69.4,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.4,
#       'gust_kph': 15.1,
#       'uv': 0},
#      {'time_epoch': 1786590000,
#       'time': '2026-08-13 04:00',
#       'temp_c': 20.4,
#       'temp_f': 68.7,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.3,
#       'wind_kph': 6.8,
#       'wind_degree': 81,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 56,
#       'cloud': 0,
#       'feelslike_c': 19.5,
#       'feelslike_f': 67.1,
#       'windchill_c': 20.4,
#       'windchill_f': 68.7,
#       'heatindex_c': 20.4,
#       'heatindex_f': 68.7,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.4,
#       'uv': 0},
#      {'time_epoch': 1786593600,
#       'time': '2026-08-13 05:00',
#       'temp_c': 20.1,
#       'temp_f': 68.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.0,
#       'wind_kph': 6.5,
#       'wind_degree': 82,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 2,
#       'feelslike_c': 19.4,
#       'feelslike_f': 66.9,
#       'windchill_c': 20.1,
#       'windchill_f': 68.3,
#       'heatindex_c': 20.1,
#       'heatindex_f': 68.3,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 0},
#      {'time_epoch': 1786597200,
#       'time': '2026-08-13 06:00',
#       'temp_c': 20.0,
#       'temp_f': 68.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 85,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 3,
#       'feelslike_c': 19.3,
#       'feelslike_f': 66.7,
#       'windchill_c': 20.0,
#       'windchill_f': 68.1,
#       'heatindex_c': 20.0,
#       'heatindex_f': 68.1,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.0,
#       'gust_kph': 12.9,
#       'uv': 0.0},
#      {'time_epoch': 1786600800,
#       'time': '2026-08-13 07:00',
#       'temp_c': 21.2,
#       'temp_f': 70.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.7,
#       'wind_kph': 4.3,
#       'wind_degree': 82,
#       'wind_dir': 'E',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.15,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 8,
#       'feelslike_c': 20.9,
#       'feelslike_f': 69.6,
#       'windchill_c': 21.2,
#       'windchill_f': 70.1,
#       'heatindex_c': 24.4,
#       'heatindex_f': 75.9,
#       'dewpoint_c': 11.6,
#       'dewpoint_f': 52.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.5,
#       'gust_kph': 8.9,
#       'uv': 0.3},
#      {'time_epoch': 1786604400,
#       'time': '2026-08-13 08:00',
#       'temp_c': 23.6,
#       'temp_f': 74.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 2.9,
#       'wind_kph': 4.7,
#       'wind_degree': 76,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 46,
#       'cloud': 11,
#       'feelslike_c': 23.1,
#       'feelslike_f': 73.6,
#       'windchill_c': 23.6,
#       'windchill_f': 74.5,
#       'heatindex_c': 24.9,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 11.3,
#       'dewpoint_f': 52.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.5,
#       'gust_kph': 7.3,
#       'uv': 0.9},
#      {'time_epoch': 1786608000,
#       'time': '2026-08-13 09:00',
#       'temp_c': 26.1,
#       'temp_f': 79.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.4,
#       'wind_kph': 5.4,
#       'wind_degree': 78,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1021.0,
#       'pressure_in': 30.14,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 37,
#       'cloud': 15,
#       'feelslike_c': 25.2,
#       'feelslike_f': 77.4,
#       'windchill_c': 26.1,
#       'windchill_f': 79.1,
#       'heatindex_c': 26.0,
#       'heatindex_f': 78.7,
#       'dewpoint_c': 10.3,
#       'dewpoint_f': 50.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.2,
#       'gust_kph': 6.7,
#       'uv': 1.9},
#      {'time_epoch': 1786611600,
#       'time': '2026-08-13 10:00',
#       'temp_c': 28.9,
#       'temp_f': 84.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 88,
#       'wind_dir': 'E',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.13,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 29,
#       'cloud': 21,
#       'feelslike_c': 27.5,
#       'feelslike_f': 81.5,
#       'windchill_c': 28.9,
#       'windchill_f': 84.0,
#       'heatindex_c': 27.7,
#       'heatindex_f': 81.8,
#       'dewpoint_c': 9.0,
#       'dewpoint_f': 48.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 3.3},
#      {'time_epoch': 1786615200,
#       'time': '2026-08-13 11:00',
#       'temp_c': 31.5,
#       'temp_f': 88.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 91,
#       'wind_dir': 'E',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.12,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 22,
#       'cloud': 22,
#       'feelslike_c': 29.7,
#       'feelslike_f': 85.5,
#       'windchill_c': 31.5,
#       'windchill_f': 88.6,
#       'heatindex_c': 29.5,
#       'heatindex_f': 85.1,
#       'dewpoint_c': 7.4,
#       'dewpoint_f': 45.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 4.7},
#      {'time_epoch': 1786618800,
#       'time': '2026-08-13 12:00',
#       'temp_c': 33.8,
#       'temp_f': 92.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.6,
#       'wind_kph': 5.8,
#       'wind_degree': 91,
#       'wind_dir': 'E',
#       'pressure_mb': 1020.0,
#       'pressure_in': 30.11,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 17,
#       'cloud': 19,
#       'feelslike_c': 31.7,
#       'feelslike_f': 89.1,
#       'windchill_c': 33.8,
#       'windchill_f': 92.8,
#       'heatindex_c': 31.7,
#       'heatindex_f': 89.1,
#       'dewpoint_c': 5.7,
#       'dewpoint_f': 42.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.1,
#       'gust_kph': 6.6,
#       'uv': 5.8},
#      {'time_epoch': 1786622400,
#       'time': '2026-08-13 13:00',
#       'temp_c': 35.6,
#       'temp_f': 96.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 90,
#       'wind_dir': 'E',
#       'pressure_mb': 1019.0,
#       'pressure_in': 30.09,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 15,
#       'cloud': 17,
#       'feelslike_c': 33.2,
#       'feelslike_f': 91.8,
#       'windchill_c': 35.6,
#       'windchill_f': 96.1,
#       'heatindex_c': 33.9,
#       'heatindex_f': 93.0,
#       'dewpoint_c': 4.7,
#       'dewpoint_f': 40.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 6.2},
#      {'time_epoch': 1786626000,
#       'time': '2026-08-13 14:00',
#       'temp_c': 36.9,
#       'temp_f': 98.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 3.8,
#       'wind_kph': 6.1,
#       'wind_degree': 98,
#       'wind_dir': 'E',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.07,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 14,
#       'cloud': 15,
#       'feelslike_c': 34.5,
#       'feelslike_f': 94.1,
#       'windchill_c': 36.9,
#       'windchill_f': 98.4,
#       'heatindex_c': 35.5,
#       'heatindex_f': 96.0,
#       'dewpoint_c': 4.8,
#       'dewpoint_f': 40.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 4.4,
#       'gust_kph': 7.1,
#       'uv': 5.8},
#      {'time_epoch': 1786629600,
#       'time': '2026-08-13 15:00',
#       'temp_c': 37.3,
#       'temp_f': 99.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 139,
#       'wind_dir': 'SE',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 14,
#       'cloud': 13,
#       'feelslike_c': 34.7,
#       'feelslike_f': 94.5,
#       'windchill_c': 37.3,
#       'windchill_f': 99.1,
#       'heatindex_c': 36.1,
#       'heatindex_f': 96.9,
#       'dewpoint_c': 5.6,
#       'dewpoint_f': 42.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 5.9,
#       'gust_kph': 9.5,
#       'uv': 4.8},
#      {'time_epoch': 1786633200,
#       'time': '2026-08-13 16:00',
#       'temp_c': 37.0,
#       'temp_f': 98.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 174,
#       'wind_dir': 'S',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 15,
#       'cloud': 14,
#       'feelslike_c': 34.0,
#       'feelslike_f': 93.2,
#       'windchill_c': 37.0,
#       'windchill_f': 98.6,
#       'heatindex_c': 35.7,
#       'heatindex_f': 96.3,
#       'dewpoint_c': 6.4,
#       'dewpoint_f': 43.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.0,
#       'gust_kph': 12.9,
#       'uv': 3.3},
#      {'time_epoch': 1786636800,
#       'time': '2026-08-13 17:00',
#       'temp_c': 36.8,
#       'temp_f': 98.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 194,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 15,
#       'cloud': 15,
#       'feelslike_c': 33.3,
#       'feelslike_f': 91.9,
#       'windchill_c': 36.8,
#       'windchill_f': 98.2,
#       'heatindex_c': 35.4,
#       'heatindex_f': 95.8,
#       'dewpoint_c': 6.4,
#       'dewpoint_f': 43.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.8,
#       'gust_kph': 15.7,
#       'uv': 1.9},
#      {'time_epoch': 1786640400,
#       'time': '2026-08-13 18:00',
#       'temp_c': 35.8,
#       'temp_f': 96.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.1,
#       'wind_kph': 16.2,
#       'wind_degree': 202,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 16,
#       'cloud': 9,
#       'feelslike_c': 31.8,
#       'feelslike_f': 89.2,
#       'windchill_c': 35.8,
#       'windchill_f': 96.5,
#       'heatindex_c': 34.2,
#       'heatindex_f': 93.6,
#       'dewpoint_c': 6.1,
#       'dewpoint_f': 43.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.2,
#       'uv': 0.9},
#      {'time_epoch': 1786644000,
#       'time': '2026-08-13 19:00',
#       'temp_c': 34.5,
#       'temp_f': 94.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.7,
#       'wind_kph': 14.0,
#       'wind_degree': 207,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 17,
#       'cloud': 7,
#       'feelslike_c': 30.9,
#       'feelslike_f': 87.6,
#       'windchill_c': 34.5,
#       'windchill_f': 94.1,
#       'heatindex_c': 32.6,
#       'heatindex_f': 90.6,
#       'dewpoint_c': 6.1,
#       'dewpoint_f': 42.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.3,
#       'gust_kph': 18.1,
#       'uv': 0.3},
#      {'time_epoch': 1786647600,
#       'time': '2026-08-13 20:00',
#       'temp_c': 32.0,
#       'temp_f': 89.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 212,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 21,
#       'cloud': 4,
#       'feelslike_c': 29.0,
#       'feelslike_f': 84.2,
#       'windchill_c': 32.0,
#       'windchill_f': 89.6,
#       'heatindex_c': 29.9,
#       'heatindex_f': 85.8,
#       'dewpoint_c': 6.9,
#       'dewpoint_f': 44.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.0,
#       'gust_kph': 17.7,
#       'uv': 0.0},
#      {'time_epoch': 1786651200,
#       'time': '2026-08-13 21:00',
#       'temp_c': 30.0,
#       'temp_f': 85.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 206,
#       'wind_dir': 'SSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 25,
#       'cloud': 0,
#       'feelslike_c': 27.8,
#       'feelslike_f': 82.0,
#       'windchill_c': 30.0,
#       'windchill_f': 85.9,
#       'heatindex_c': 28.4,
#       'heatindex_f': 83.0,
#       'dewpoint_c': 8.1,
#       'dewpoint_f': 46.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.7,
#       'gust_kph': 14.0,
#       'uv': 0},
#      {'time_epoch': 1786654800,
#       'time': '2026-08-13 22:00',
#       'temp_c': 28.5,
#       'temp_f': 83.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 214,
#       'wind_dir': 'SW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 29,
#       'cloud': 0,
#       'feelslike_c': 26.7,
#       'feelslike_f': 80.1,
#       'windchill_c': 28.5,
#       'windchill_f': 83.4,
#       'heatindex_c': 27.4,
#       'heatindex_f': 81.2,
#       'dewpoint_c': 8.8,
#       'dewpoint_f': 47.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 0},
#      {'time_epoch': 1786658400,
#       'time': '2026-08-13 23:00',
#       'temp_c': 27.4,
#       'temp_f': 81.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 235,
#       'wind_dir': 'SW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 33,
#       'cloud': 4,
#       'feelslike_c': 25.5,
#       'feelslike_f': 77.9,
#       'windchill_c': 27.4,
#       'windchill_f': 81.3,
#       'heatindex_c': 26.6,
#       'heatindex_f': 80.0,
#       'dewpoint_c': 9.5,
#       'dewpoint_f': 49.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.3,
#       'gust_kph': 14.9,
#       'uv': 0}]},
#    {'date': '2026-08-14',
#     'date_epoch': 1786665600,
#     'day': {'maxtemp_c': 33.9,
#      'maxtemp_f': 93.0,
#      'mintemp_c': 22.2,
#      'mintemp_f': 71.9,
#      'avgtemp_c': 27.9,
#      'avgtemp_f': 82.2,
#      'maxwind_mph': 12.8,
#      'maxwind_kph': 20.5,
#      'totalprecip_mm': 0.0,
#      'totalprecip_in': 0.0,
#      'totalsnow_cm': 0.0,
#      'avgvis_km': 10.0,
#      'avgvis_miles': 6.0,
#      'avghumidity': 39,
#      'daily_will_it_rain': 0,
#      'daily_chance_of_rain': 1,
#      'daily_will_it_snow': 0,
#      'daily_chance_of_snow': 0,
#      'condition': {'text': 'Sunny',
#       'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#       'code': 1000},
#      'uv': 6.2},
#     'astro': {'sunrise': '05:44 AM',
#      'sunset': '08:25 PM',
#      'moonrise': '07:39 AM',
#      'moonset': '08:56 PM',
#      'moon_phase': 'Waxing Crescent',
#      'moon_illumination': 5,
#      'is_moon_up': 0,
#      'is_sun_up': 0},
#     'hour': [{'time_epoch': 1786662000,
#       'time': '2026-08-14 00:00',
#       'temp_c': 26.3,
#       'temp_f': 79.4,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 244,
#       'wind_dir': 'WSW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 36,
#       'cloud': 0,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 26.3,
#       'windchill_f': 79.4,
#       'heatindex_c': 26.0,
#       'heatindex_f': 78.9,
#       'dewpoint_c': 10.0,
#       'dewpoint_f': 49.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.1,
#       'uv': 0},
#      {'time_epoch': 1786665600,
#       'time': '2026-08-14 01:00',
#       'temp_c': 25.5,
#       'temp_f': 77.9,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 261,
#       'wind_dir': 'W',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 39,
#       'cloud': 0,
#       'feelslike_c': 24.2,
#       'feelslike_f': 75.6,
#       'windchill_c': 25.5,
#       'windchill_f': 77.9,
#       'heatindex_c': 25.6,
#       'heatindex_f': 78.1,
#       'dewpoint_c': 10.4,
#       'dewpoint_f': 50.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.7,
#       'gust_kph': 12.3,
#       'uv': 0},
#      {'time_epoch': 1786669200,
#       'time': '2026-08-14 02:00',
#       'temp_c': 24.9,
#       'temp_f': 76.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 282,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 42,
#       'cloud': 1,
#       'feelslike_c': 23.8,
#       'feelslike_f': 74.8,
#       'windchill_c': 24.9,
#       'windchill_f': 76.8,
#       'heatindex_c': 25.4,
#       'heatindex_f': 77.8,
#       'dewpoint_c': 11.3,
#       'dewpoint_f': 52.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.9,
#       'gust_kph': 12.6,
#       'uv': 0},
#      {'time_epoch': 1786672800,
#       'time': '2026-08-14 03:00',
#       'temp_c': 24.2,
#       'temp_f': 75.5,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.9,
#       'wind_kph': 7.9,
#       'wind_degree': 294,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 46,
#       'cloud': 15,
#       'feelslike_c': 23.3,
#       'feelslike_f': 73.9,
#       'windchill_c': 24.2,
#       'windchill_f': 75.5,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.3,
#       'dewpoint_c': 12.0,
#       'dewpoint_f': 53.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.8,
#       'gust_kph': 12.5,
#       'uv': 0},
#      {'time_epoch': 1786676400,
#       'time': '2026-08-14 04:00',
#       'temp_c': 23.5,
#       'temp_f': 74.3,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 4.7,
#       'wind_kph': 7.6,
#       'wind_degree': 298,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 4,
#       'feelslike_c': 22.9,
#       'feelslike_f': 73.2,
#       'windchill_c': 23.5,
#       'windchill_f': 74.3,
#       'heatindex_c': 25.0,
#       'heatindex_f': 76.9,
#       'dewpoint_c': 12.6,
#       'dewpoint_f': 54.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.3,
#       'gust_kph': 11.7,
#       'uv': 0},
#      {'time_epoch': 1786680000,
#       'time': '2026-08-14 05:00',
#       'temp_c': 22.8,
#       'temp_f': 73.0,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.1,
#       'wind_kph': 8.3,
#       'wind_degree': 301,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 54,
#       'cloud': 2,
#       'feelslike_c': 22.1,
#       'feelslike_f': 71.8,
#       'windchill_c': 22.8,
#       'windchill_f': 73.0,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'dewpoint_c': 13.1,
#       'dewpoint_f': 55.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 0},
#      {'time_epoch': 1786683600,
#       'time': '2026-08-14 06:00',
#       'temp_c': 22.2,
#       'temp_f': 71.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 304,
#       'wind_dir': 'NW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 59,
#       'cloud': 3,
#       'feelslike_c': 21.6,
#       'feelslike_f': 70.9,
#       'windchill_c': 22.2,
#       'windchill_f': 71.9,
#       'heatindex_c': 24.6,
#       'heatindex_f': 76.3,
#       'dewpoint_c': 13.8,
#       'dewpoint_f': 56.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.9,
#       'gust_kph': 14.3,
#       'uv': 0.0},
#      {'time_epoch': 1786687200,
#       'time': '2026-08-14 07:00',
#       'temp_c': 22.5,
#       'temp_f': 72.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 308,
#       'wind_dir': 'NW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 61,
#       'cloud': 3,
#       'feelslike_c': 21.9,
#       'feelslike_f': 71.4,
#       'windchill_c': 22.5,
#       'windchill_f': 72.5,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 4,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.8,
#       'gust_kph': 14.1,
#       'uv': 0.3},
#      {'time_epoch': 1786690800,
#       'time': '2026-08-14 08:00',
#       'temp_c': 23.8,
#       'temp_f': 74.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 304,
#       'wind_dir': 'NW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 3,
#       'feelslike_c': 23.0,
#       'feelslike_f': 73.4,
#       'windchill_c': 23.8,
#       'windchill_f': 74.8,
#       'heatindex_c': 25.2,
#       'heatindex_f': 77.4,
#       'dewpoint_c': 14.2,
#       'dewpoint_f': 57.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.1,
#       'gust_kph': 13.0,
#       'uv': 0.8},
#      {'time_epoch': 1786694400,
#       'time': '2026-08-14 09:00',
#       'temp_c': 25.4,
#       'temp_f': 77.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.5,
#       'wind_kph': 10.4,
#       'wind_degree': 303,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.03,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 47,
#       'cloud': 3,
#       'feelslike_c': 24.8,
#       'feelslike_f': 76.6,
#       'windchill_c': 25.5,
#       'windchill_f': 77.8,
#       'heatindex_c': 26.0,
#       'heatindex_f': 78.8,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.5,
#       'gust_kph': 12.0,
#       'uv': 1.9},
#      {'time_epoch': 1786698000,
#       'time': '2026-08-14 10:00',
#       'temp_c': 27.2,
#       'temp_f': 81.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 300,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.02,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 39,
#       'cloud': 3,
#       'feelslike_c': 26.0,
#       'feelslike_f': 78.8,
#       'windchill_c': 27.2,
#       'windchill_f': 81.0,
#       'heatindex_c': 27.1,
#       'heatindex_f': 80.7,
#       'dewpoint_c': 12.2,
#       'dewpoint_f': 54.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.0,
#       'gust_kph': 11.2,
#       'uv': 3.2},
#      {'time_epoch': 1786701600,
#       'time': '2026-08-14 11:00',
#       'temp_c': 28.9,
#       'temp_f': 84.1,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.6,
#       'wind_kph': 9.0,
#       'wind_degree': 290,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 34,
#       'cloud': 2,
#       'feelslike_c': 27.7,
#       'feelslike_f': 81.9,
#       'windchill_c': 28.9,
#       'windchill_f': 84.1,
#       'heatindex_c': 28.3,
#       'heatindex_f': 82.9,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.4,
#       'gust_kph': 10.4,
#       'uv': 4.7},
#      {'time_epoch': 1786705200,
#       'time': '2026-08-14 12:00',
#       'temp_c': 30.5,
#       'temp_f': 86.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 280,
#       'wind_dir': 'W',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 30,
#       'cloud': 2,
#       'feelslike_c': 29.0,
#       'feelslike_f': 84.2,
#       'windchill_c': 30.5,
#       'windchill_f': 86.9,
#       'heatindex_c': 29.5,
#       'heatindex_f': 85.2,
#       'dewpoint_c': 11.2,
#       'dewpoint_f': 52.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.0,
#       'gust_kph': 11.2,
#       'uv': 5.8},
#      {'time_epoch': 1786708800,
#       'time': '2026-08-14 13:00',
#       'temp_c': 31.8,
#       'temp_f': 89.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 276,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 27,
#       'cloud': 2,
#       'feelslike_c': 30.1,
#       'feelslike_f': 86.2,
#       'windchill_c': 31.8,
#       'windchill_f': 89.2,
#       'heatindex_c': 30.6,
#       'heatindex_f': 87.0,
#       'dewpoint_c': 10.6,
#       'dewpoint_f': 51.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 0,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.0,
#       'gust_kph': 11.2,
#       'uv': 6.2},
#      {'time_epoch': 1786712400,
#       'time': '2026-08-14 14:00',
#       'temp_c': 32.8,
#       'temp_f': 91.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.8,
#       'wind_kph': 9.4,
#       'wind_degree': 268,
#       'wind_dir': 'W',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 25,
#       'cloud': 3,
#       'feelslike_c': 31.1,
#       'feelslike_f': 88.0,
#       'windchill_c': 32.8,
#       'windchill_f': 91.0,
#       'heatindex_c': 31.4,
#       'heatindex_f': 88.4,
#       'dewpoint_c': 10.2,
#       'dewpoint_f': 50.4,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.7,
#       'gust_kph': 10.8,
#       'uv': 5.8},
#      {'time_epoch': 1786716000,
#       'time': '2026-08-14 15:00',
#       'temp_c': 33.5,
#       'temp_f': 92.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 268,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 24,
#       'cloud': 7,
#       'feelslike_c': 31.8,
#       'feelslike_f': 89.2,
#       'windchill_c': 33.5,
#       'windchill_f': 92.2,
#       'heatindex_c': 32.0,
#       'heatindex_f': 89.6,
#       'dewpoint_c': 10.0,
#       'dewpoint_f': 50.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 4.7},
#      {'time_epoch': 1786719600,
#       'time': '2026-08-14 16:00',
#       'temp_c': 33.8,
#       'temp_f': 92.9,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 278,
#       'wind_dir': 'W',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.94,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 23,
#       'cloud': 6,
#       'feelslike_c': 32.1,
#       'feelslike_f': 89.8,
#       'windchill_c': 33.8,
#       'windchill_f': 92.9,
#       'heatindex_c': 32.3,
#       'heatindex_f': 90.1,
#       'dewpoint_c': 9.7,
#       'dewpoint_f': 49.5,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 6.2,
#       'gust_kph': 9.9,
#       'uv': 3.3},
#      {'time_epoch': 1786723200,
#       'time': '2026-08-14 17:00',
#       'temp_c': 33.9,
#       'temp_f': 93.0,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.3,
#       'wind_kph': 10.1,
#       'wind_degree': 288,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 22,
#       'cloud': 7,
#       'feelslike_c': 31.8,
#       'feelslike_f': 89.2,
#       'windchill_c': 33.9,
#       'windchill_f': 92.9,
#       'heatindex_c': 32.2,
#       'heatindex_f': 90.0,
#       'dewpoint_c': 9.4,
#       'dewpoint_f': 49.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.2,
#       'gust_kph': 11.6,
#       'uv': 1.9},
#      {'time_epoch': 1786726800,
#       'time': '2026-08-14 18:00',
#       'temp_c': 33.5,
#       'temp_f': 92.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.6,
#       'wind_kph': 12.2,
#       'wind_degree': 289,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 23,
#       'cloud': 7,
#       'feelslike_c': 31.0,
#       'feelslike_f': 87.8,
#       'windchill_c': 33.5,
#       'windchill_f': 92.3,
#       'heatindex_c': 31.9,
#       'heatindex_f': 89.3,
#       'dewpoint_c': 9.3,
#       'dewpoint_f': 48.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.8,
#       'gust_kph': 14.1,
#       'uv': 0.8},
#      {'time_epoch': 1786730400,
#       'time': '2026-08-14 19:00',
#       'temp_c': 32.6,
#       'temp_f': 90.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 291,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 24,
#       'cloud': 6,
#       'feelslike_c': 30.0,
#       'feelslike_f': 86.0,
#       'windchill_c': 32.6,
#       'windchill_f': 90.8,
#       'heatindex_c': 31.1,
#       'heatindex_f': 87.9,
#       'dewpoint_c': 9.6,
#       'dewpoint_f': 49.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.7,
#       'gust_kph': 17.2,
#       'uv': 0.3},
#      {'time_epoch': 1786734000,
#       'time': '2026-08-14 20:00',
#       'temp_c': 30.8,
#       'temp_f': 87.5,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 10.3,
#       'wind_kph': 16.6,
#       'wind_degree': 293,
#       'wind_dir': 'WNW',
#       'pressure_mb': 1013.0,
#       'pressure_in': 29.92,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 30,
#       'cloud': 7,
#       'feelslike_c': 28.0,
#       'feelslike_f': 82.4,
#       'windchill_c': 30.8,
#       'windchill_f': 87.5,
#       'heatindex_c': 29.8,
#       'heatindex_f': 85.6,
#       'dewpoint_c': 11.1,
#       'dewpoint_f': 52.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 14.7,
#       'gust_kph': 23.7,
#       'uv': 0.0},
#      {'time_epoch': 1786737600,
#       'time': '2026-08-14 21:00',
#       'temp_c': 27.9,
#       'temp_f': 82.2,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 12.8,
#       'wind_kph': 20.5,
#       'wind_degree': 315,
#       'wind_dir': 'NW',
#       'pressure_mb': 1014.0,
#       'pressure_in': 29.95,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 45,
#       'cloud': 7,
#       'feelslike_c': 27.9,
#       'feelslike_f': 82.2,
#       'windchill_c': 27.9,
#       'windchill_f': 82.2,
#       'heatindex_c': 28.2,
#       'heatindex_f': 82.7,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 16.5,
#       'gust_kph': 26.6,
#       'uv': 0},
#      {'time_epoch': 1786741200,
#       'time': '2026-08-14 22:00',
#       'temp_c': 26.2,
#       'temp_f': 79.1,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 11.9,
#       'wind_kph': 19.1,
#       'wind_degree': 321,
#       'wind_dir': 'NW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.96,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 10,
#       'feelslike_c': 25.6,
#       'feelslike_f': 78.1,
#       'windchill_c': 26.2,
#       'windchill_f': 79.1,
#       'heatindex_c': 26.8,
#       'heatindex_f': 80.2,
#       'dewpoint_c': 14.9,
#       'dewpoint_f': 58.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 15.3,
#       'gust_kph': 24.7,
#       'uv': 0},
#      {'time_epoch': 1786744800,
#       'time': '2026-08-14 23:00',
#       'temp_c': 24.9,
#       'temp_f': 76.8,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 11.6,
#       'wind_kph': 18.7,
#       'wind_degree': 328,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.97,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 51,
#       'cloud': 8,
#       'feelslike_c': 22.5,
#       'feelslike_f': 72.5,
#       'windchill_c': 24.9,
#       'windchill_f': 76.8,
#       'heatindex_c': 25.8,
# ...
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 343,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 59,
#       'cloud': 12,
#       'feelslike_c': 16.5,
#       'feelslike_f': 61.7,
#       'windchill_c': 19.0,
#       'windchill_f': 66.3,
#       'heatindex_c': 19.0,
#       'heatindex_f': 66.3,
#       'dewpoint_c': 10.7,
#       'dewpoint_f': 51.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 4,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.9,
#       'uv': 0.2},
#      {'time_epoch': 1786777200,
#       'time': '2026-08-15 08:00',
#       'temp_c': 19.8,
#       'temp_f': 67.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 9.2,
#       'wind_kph': 14.8,
#       'wind_degree': 338,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 10,
#       'feelslike_c': 17.3,
#       'feelslike_f': 63.1,
#       'windchill_c': 19.8,
#       'windchill_f': 67.6,
#       'heatindex_c': 19.8,
#       'heatindex_f': 67.6,
#       'dewpoint_c': 11.3,
#       'dewpoint_f': 52.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 4,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.6,
#       'gust_kph': 17.1,
#       'uv': 0.7},
#      {'time_epoch': 1786780800,
#       'time': '2026-08-15 09:00',
#       'temp_c': 21.4,
#       'temp_f': 70.4,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.5,
#       'wind_kph': 13.7,
#       'wind_degree': 343,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 55,
#       'cloud': 6,
#       'feelslike_c': 19.3,
#       'feelslike_f': 66.7,
#       'windchill_c': 21.4,
#       'windchill_f': 70.4,
#       'heatindex_c': 24.4,
#       'heatindex_f': 76.0,
#       'dewpoint_c': 12.1,
#       'dewpoint_f': 53.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.8,
#       'gust_kph': 15.7,
#       'uv': 1.7},
#      {'time_epoch': 1786784400,
#       'time': '2026-08-15 10:00',
#       'temp_c': 23.1,
#       'temp_f': 73.6,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 345,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 52,
#       'cloud': 4,
#       'feelslike_c': 21.4,
#       'feelslike_f': 70.5,
#       'windchill_c': 23.1,
#       'windchill_f': 73.6,
#       'heatindex_c': 24.8,
#       'heatindex_f': 76.7,
#       'dewpoint_c': 12.8,
#       'dewpoint_f': 55.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.3,
#       'uv': 2.9},
#      {'time_epoch': 1786788000,
#       'time': '2026-08-15 11:00',
#       'temp_c': 24.6,
#       'temp_f': 76.3,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 8.1,
#       'wind_kph': 13.0,
#       'wind_degree': 346,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 49,
#       'cloud': 22,
#       'feelslike_c': 23.2,
#       'feelslike_f': 73.8,
#       'windchill_c': 24.6,
#       'windchill_f': 76.3,
#       'heatindex_c': 25.6,
#       'heatindex_f': 78.0,
#       'dewpoint_c': 13.4,
#       'dewpoint_f': 56.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.3,
#       'gust_kph': 14.9,
#       'uv': 4.2},
#      {'time_epoch': 1786791600,
#       'time': '2026-08-15 12:00',
#       'temp_c': 25.7,
#       'temp_f': 78.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 8.3,
#       'wind_kph': 13.3,
#       'wind_degree': 343,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 52,
#       'feelslike_c': 24.9,
#       'feelslike_f': 76.8,
#       'windchill_c': 25.7,
#       'windchill_f': 78.2,
#       'heatindex_c': 26.3,
#       'heatindex_f': 79.3,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 57.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 5,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.5,
#       'gust_kph': 15.3,
#       'uv': 5.0},
#      {'time_epoch': 1786795200,
#       'time': '2026-08-15 13:00',
#       'temp_c': 25.6,
#       'temp_f': 78.1,
#       'is_day': 1,
#       'condition': {'text': 'Overcast',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/122.png',
#        'code': 1009},
#       'wind_mph': 9.6,
#       'wind_kph': 15.5,
#       'wind_degree': 352,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.0,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 100,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.5,
#       'windchill_c': 25.6,
#       'windchill_f': 78.1,
#       'heatindex_c': 26.3,
#       'heatindex_f': 79.4,
#       'dewpoint_c': 14.5,
#       'dewpoint_f': 58.1,
#       'will_it_rain': 0,
#       'chance_of_rain': 12,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.1,
#       'gust_kph': 17.8,
#       'uv': 4.2},
#      {'time_epoch': 1786798800,
#       'time': '2026-08-15 14:00',
#       'temp_c': 24.8,
#       'temp_f': 76.6,
#       'is_day': 1,
#       'condition': {'text': 'Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/119.png',
#        'code': 1006},
#       'wind_mph': 11.0,
#       'wind_kph': 17.6,
#       'wind_degree': 5,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 53,
#       'cloud': 74,
#       'feelslike_c': 22.8,
#       'feelslike_f': 73.0,
#       'windchill_c': 24.8,
#       'windchill_f': 76.6,
#       'heatindex_c': 25.8,
#       'heatindex_f': 78.4,
#       'dewpoint_c': 14.6,
#       'dewpoint_f': 58.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 9,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 12.6,
#       'gust_kph': 20.3,
#       'uv': 3.1},
#      {'time_epoch': 1786802400,
#       'time': '2026-08-15 15:00',
#       'temp_c': 25.1,
#       'temp_f': 77.1,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 2,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 50,
#       'cloud': 51,
#       'feelslike_c': 23.7,
#       'feelslike_f': 74.7,
#       'windchill_c': 25.1,
#       'windchill_f': 77.1,
#       'heatindex_c': 25.9,
#       'heatindex_f': 78.6,
#       'dewpoint_c': 14.1,
#       'dewpoint_f': 57.3,
#       'will_it_rain': 0,
#       'chance_of_rain': 5,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 10.3,
#       'gust_kph': 16.6,
#       'uv': 3.3},
#      {'time_epoch': 1786806000,
#       'time': '2026-08-15 16:00',
#       'temp_c': 26.1,
#       'temp_f': 78.9,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 3,
#       'wind_dir': 'N',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 45,
#       'cloud': 28,
#       'feelslike_c': 25.7,
#       'feelslike_f': 78.3,
#       'windchill_c': 26.1,
#       'windchill_f': 78.9,
#       'heatindex_c': 26.4,
#       'heatindex_f': 79.5,
#       'dewpoint_c': 13.2,
#       'dewpoint_f': 55.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 3,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.7,
#       'gust_kph': 12.4,
#       'uv': 2.9},
#      {'time_epoch': 1786809600,
#       'time': '2026-08-15 17:00',
#       'temp_c': 26.5,
#       'temp_f': 79.7,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.0,
#       'wind_kph': 9.7,
#       'wind_degree': 15,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1016.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 41,
#       'cloud': 20,
#       'feelslike_c': 26.3,
#       'feelslike_f': 79.3,
#       'windchill_c': 26.5,
#       'windchill_f': 79.7,
#       'heatindex_c': 26.5,
#       'heatindex_f': 79.8,
#       'dewpoint_c': 12.2,
#       'dewpoint_f': 54.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.0,
#       'gust_kph': 11.2,
#       'uv': 1.7},
#      {'time_epoch': 1786813200,
#       'time': '2026-08-15 18:00',
#       'temp_c': 26.2,
#       'temp_f': 79.2,
#       'is_day': 1,
#       'condition': {'text': 'Partly Cloudy',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/116.png',
#        'code': 1003},
#       'wind_mph': 6.7,
#       'wind_kph': 10.8,
#       'wind_degree': 31,
#       'wind_dir': 'NNE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 40,
#       'cloud': 32,
#       'feelslike_c': 25.7,
#       'feelslike_f': 78.3,
#       'windchill_c': 26.2,
#       'windchill_f': 79.2,
#       'heatindex_c': 26.3,
#       'heatindex_f': 79.3,
#       'dewpoint_c': 11.7,
#       'dewpoint_f': 53.0,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.7,
#       'gust_kph': 12.4,
#       'uv': 0.7},
#      {'time_epoch': 1786816800,
#       'time': '2026-08-15 19:00',
#       'temp_c': 25.7,
#       'temp_f': 78.2,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 6.9,
#       'wind_kph': 11.2,
#       'wind_degree': 43,
#       'wind_dir': 'NE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.98,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 41,
#       'cloud': 17,
#       'feelslike_c': 24.7,
#       'feelslike_f': 76.5,
#       'windchill_c': 25.7,
#       'windchill_f': 78.2,
#       'heatindex_c': 25.9,
#       'heatindex_f': 78.6,
#       'dewpoint_c': 11.5,
#       'dewpoint_f': 52.7,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 8.5,
#       'gust_kph': 13.6,
#       'uv': 0.3},
#      {'time_epoch': 1786820400,
#       'time': '2026-08-15 20:00',
#       'temp_c': 24.3,
#       'temp_f': 75.8,
#       'is_day': 1,
#       'condition': {'text': 'Sunny',
#        'icon': '//cdn.weatherapi.com/weather/64x64/day/113.png',
#        'code': 1000},
#       'wind_mph': 7.4,
#       'wind_kph': 11.9,
#       'wind_degree': 76,
#       'wind_dir': 'ENE',
#       'pressure_mb': 1015.0,
#       'pressure_in': 29.99,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 48,
#       'cloud': 12,
#       'feelslike_c': 22.8,
#       'feelslike_f': 73.0,
#       'windchill_c': 24.3,
#       'windchill_f': 75.8,
#       'heatindex_c': 25.3,
#       'heatindex_f': 77.5,
#       'dewpoint_c': 12.6,
#       'dewpoint_f': 54.6,
#       'will_it_rain': 0,
#       'chance_of_rain': 2,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 9.9,
#       'gust_kph': 15.9,
#       'uv': 0.0},
#      {'time_epoch': 1786824000,
#       'time': '2026-08-15 21:00',
#       'temp_c': 22.6,
#       'temp_f': 72.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 82,
#       'wind_dir': 'E',
#       'pressure_mb': 1016.0,
#       'pressure_in': 30.01,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 58,
#       'cloud': 15,
#       'feelslike_c': 22.1,
#       'feelslike_f': 71.8,
#       'windchill_c': 22.6,
#       'windchill_f': 72.6,
#       'heatindex_c': 24.7,
#       'heatindex_f': 76.5,
#       'dewpoint_c': 13.9,
#       'dewpoint_f': 56.9,
#       'will_it_rain': 0,
#       'chance_of_rain': 4,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.4,
#       'gust_kph': 11.9,
#       'uv': 0},
#      {'time_epoch': 1786827600,
#       'time': '2026-08-15 22:00',
#       'temp_c': 21.8,
#       'temp_f': 71.2,
#       'is_day': 0,
#       'condition': {'text': 'Patchy rain nearby',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/176.png',
#        'code': 1063},
#       'wind_mph': 5.4,
#       'wind_kph': 8.6,
#       'wind_degree': 356,
#       'wind_dir': 'N',
#       'pressure_mb': 1017.0,
#       'pressure_in': 30.04,
#       'precip_mm': 0.03,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 57,
#       'cloud': 73,
#       'feelslike_c': 21.0,
#       'feelslike_f': 69.8,
#       'windchill_c': 21.8,
#       'windchill_f': 71.2,
#       'heatindex_c': 24.5,
#       'heatindex_f': 76.1,
#       'dewpoint_c': 12.9,
#       'dewpoint_f': 55.2,
#       'will_it_rain': 0,
#       'chance_of_rain': 11,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 7.3,
#       'gust_kph': 11.8,
#       'uv': 0},
#      {'time_epoch': 1786831200,
#       'time': '2026-08-15 23:00',
#       'temp_c': 20.3,
#       'temp_f': 68.6,
#       'is_day': 0,
#       'condition': {'text': 'Clear',
#        'icon': '//cdn.weatherapi.com/weather/64x64/night/113.png',
#        'code': 1000},
#       'wind_mph': 8.9,
#       'wind_kph': 14.4,
#       'wind_degree': 344,
#       'wind_dir': 'NNW',
#       'pressure_mb': 1018.0,
#       'pressure_in': 30.05,
#       'precip_mm': 0.0,
#       'precip_in': 0.0,
#       'snow_cm': 0.0,
#       'humidity': 44,
#       'cloud': 6,
#       'feelslike_c': 17.0,
#       'feelslike_f': 62.6,
#       'windchill_c': 20.3,
#       'windchill_f': 68.6,
#       'heatindex_c': 20.3,
#       'heatindex_f': 68.6,
#       'dewpoint_c': 7.7,
#       'dewpoint_f': 45.8,
#       'will_it_rain': 0,
#       'chance_of_rain': 1,
#       'will_it_snow': 0,
#       'chance_of_snow': 0,
#       'vis_km': 10.0,
#       'vis_miles': 6.0,
#       'gust_mph': 11.9,
#       'gust_kph': 19.1,
#       'uv': 0}]}]}}
