# %% [markdown]
# # Clase 2: Instalación Python - Introducción al lenguaje

# %% [markdown]
# ## Introducción

# %% [markdown]
# ```
#  ⠀⠀⠀⠀⠀⠀⠀⢀⣤⣴⣶⣶⣶⣶⣶⣦⣄⠀⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⢀⣾⠟⠛⢿⣿⣿⣿⣿⣿⣿⣷⠀⠀⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⢸⣿⣄⣀⣼⣿⣿⣿⣿⣿⣿⣿⠀⢀⣀⣀⣀⡀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠈⠉⠉⠉⠉⠉⠉⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⣿⣦⠀
# ⠀⣠⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⠀⢸⣿⣿⣿⣿⣿⡇
# ⢰⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⠿⠿⠿⠿⠿⠿⠋⠀⣼⣿⣿⣿⣿⣿⡇
# ⢸⣿⣿⣿⣿⣿⡿⠉⢀⣠⣤⣤⣤⣤⣤⣤⣤⣴⣾⣿⣿⣿⣿⣿⣿⡇
# ⢸⣿⣿⣿⣿⣿⡇⠀⣾⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⣿⡿⠀
# ⠘⣿⣿⣿⣿⣿⡇⠀⣿⣿⣿⣿⣿⠛⠛⠛⠛⠛⠛⠛⠛⠛⠋⠁⠀⠀
# ⠀⠈⠛⠻⠿⠿⠇⠀⣿⣿⣿⣿⣿⣿⣿⣿⠿⠿⣿⡇⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⣿⣿⣿⣿⣿⣿⣿⣧⣀⣀⣿⠇⠀⠀⠀⠀⠀⠀
# ⠀⠀⠀⠀⠀⠀⠀⠀⠘⢿⣿⣿⣿⣿⣿⣿⣿⡿⠋⠀⠀⠀⠀⠀
# https://emojicombos.com/python-ascii-art⠀⠀
# ```
#
# Python es un lenguaje de programación ampliamente utilizado en las aplicaciones web, el desarrollo de software, la ciencia de datos y el machine learning (ML). Los desarrolladores utilizan Python porque es eficiente y fácil de aprender, además de que se puede ejecutar en muchas plataformas diferentes. El software Python se puede descargar gratis, se integra bien a todos los tipos de sistemas y aumenta la velocidad del desarrollo.
#
# Características del lenguaje:
# - **Un lenguaje interpretado:**
# Ejecuta directamente el código línea por línea. Si existen errores en el código del programa, su ejecución se detiene.
#
# - **Un lenguaje identado**
# A diferencia de otros lenguajes de programación, Python no utiliza llaves. En su lugar, utiliza sangría.
#
# - **Un lenguaje tipeado dinámicamente**
# Los programadores no tienen que anunciar tipos de variables cuando escriben código porque Python los determina en el tiempo de ejecución. Debido a esto, es posible escribir programas de Python con mayor rapidez.
#
# - **Un lenguaje de alto nivel**
# Python es más cercano a los idiomas humanos que otros lenguajes de programación. Por lo tanto, los programadores no deben preocuparse sobre sus funcionalidades subyacentes, como la arquitectura y la administración de la memoria.
#
# - **Un lenguaje orientado a los objetos**
# Python considera todo como un objeto, pero también admite otros tipos de programación, como la programación estructurada y la funcional.
#
# *Tomado de [¿Qué es Python? - AWS](https://aws.amazon.com/es/what-is/python/)*
#
#
# **Links importantes:**
# - [Descargar Anaconda](https://www.anaconda.com/download)
# - [Tutorial Instalacion Anaconda](https://www.datacamp.com/es/tutorial/installing-anaconda-windows)
# - [Descargar Python](https://www.python.org/downloads/)

# %% [markdown]
# ## Programación Básica en Python

# %%
print('Hola Mundo') #String
# Out:
# Hola Mundo

# %%
mi_nombre = "Cristian" #CADENA DE CARACTERES
print("Hola", mi_nombre)
# Out:
# Hola Cristian

# %%
mi_nombre_2 = "David"
print("Hola", mi_nombre, mi_nombre_2,"Pedro","Juan","Pablo")
# Out:
# Hola-Cristian-David-Pedro-Juan-Pablo

# %%
print(mi_nombre)
# Out:
# Cristian

# %%
mi_nombre = input("Ingresa tu nombre: ")
print("Hola", mi_nombre)
# Out:
# Ingresa tu nombre: Wantes
# Hola Wantes

# %%
# Comentario de una sola linea

"""
FUNCIONAMIENTO DEL CODIGO:
Este codigo realiza la funcion
de suma y promedio para dos numeros
"""
dato1 = 1
dato2 = 3
suma = dato1 + dato2
promedio = suma / 2
print("La suma es:", suma)
print("El promedio es:", promedio)
# Out:
# La suma es: 4
# El promedio es: 2.0

# %% [markdown]
# ### Variables

# %%
# Números:
edad = 26
temperatura = 29.3
calificacion = 3.4

# Cadenas de caracteres
funcion = "Cristian?"
cargo = 'Analista de datos!!!!'

# Booleanos
es_instructor = True
tiene_perro = False

# %% [markdown]
# ### Operadores aritmeticos

# %%
suma = 5 + 6
resta = 5 - 6
multiplicacion = 5 * 6
division = 5 / 6
division_entera = 5 // 6
modulo = 13 % 5
exponente = 3 ** 3

# %%
print("Suma: ", suma)
print("Resta: ", resta)
print("Multiplicacion: ", multiplicacion)
print("Division: ", division)
print("Division Entera: ", division_entera)
print("Modulo / Residuo: ", modulo)
print("Exponente: ", exponente)
# Out:
# Suma:  11
# Resta:  -1
# Multiplicacion:  30
# Division:  0.8333333333333334
# Division Entera:  0
# Modulo / Residuo:  3
# Exponente:  27

# %% [markdown]
# ### Operadores relacionales

# %%
igualdad = "hola" == "adios"
desigualdad = 5 != 6
menor_que = 5 < 6
menor_o_igual_que = 5 <= 6
mayor_que = 5 > 6
mayor_o_igual_que = 5 >= 6

# %%
print("igualdad:", igualdad)
print("desigualdad:", desigualdad)
print("menor_que:", menor_que)
print("menor_o_igual_que:", menor_o_igual_que)
print("mayor_que:", mayor_que)
print("mayor_o_igual_que:", mayor_o_igual_que)
# Out:
# igualdad: False
# desigualdad: True
# menor_que: True
# menor_o_igual_que: True
# mayor_que: False
# mayor_o_igual_que: False

# %% [markdown]
# ### Operadores de asignacion

# %%
asignacion = 10
print(f"inicia: {asignacion}")
#suma_asignacion
asignacion += 5
#asignacion = asignacion + 5
print(f"suma y asignacion: {asignacion}")
#resta_asignacion
asignacion -= 5
print(f"resta y asignacion: {asignacion}")
#multiplicacion_asignacion
asignacion *= 5
print(f"multiplicacion y asignacion: {asignacion}")
#division_asignacion
asignacion /= 5
print(f"division y asignacion: {asignacion}")
#exponente_asignacion
asignacion **= 5.0
print(f"exponente y asignacion: {asignacion}")
#modulo_asignacion
asignacion %= 5

asignacion = asignacion % 5


print(f"modulo y asignacion: {asignacion}")
# Out:
# inicia: 10
# suma y asignacion: 15
# resta y asignacion: 10
# multiplicacion y asignacion: 50
# division y asignacion: 10.0
# exponente y asignacion: 100000.0
# modulo y asignacion: 0.0

# %% [markdown]
# ### Operadores lógicos
# https://i.ytimg.com/vi/gnxJLLkY6bs/maxresdefault.jpg?sqp=-oaymwEmCIAKENAF8quKqQMa8AEB-AH-CYAC0AWKAgwIABABGGUgZShlMA8=&rs=AOn4CLAowAf9EfGG3FZ_zpkYhodF1BvW9Q

# %%
conjuncion = True and False
disyuncion = True or False
negacion = not True

# %%
print("conjuncion:", conjuncion)
print("disyuncion:", disyuncion)
print("negacion:", negacion)
# Out:
# conjuncion: False
# disyuncion: True
# negacion: False

# %%
## EJEMPLO

comparacion_1 = 10 > 5
comparacion_2 = 10 > 11

print(comparacion_1 or comparacion_2)
# Out:
# True

# %% [markdown]
# ### Operadores de pertenencia

# %%
lista = [1,2,3,4,5]

print("Esta 3 en la lista?", 3 in lista)
print("No está 12 en la lista?", 12 not in lista)
# Out:
# Esta 3 en la lista? True
# No está 12 en la lista? True

# %% [markdown]
# ### Ejemplo

# %%
precio_pan = 3.50
precio_leche = 2.75
total = precio_pan + precio_leche  # Suma
impuesto = total * 0.19            # Multiplicación por el impuesto del 19%
print(f"Total a pagar: ${total + impuesto}") ### Cadena de caracteres formateada
# Out:
# Total a pagar: $7.4375

# %% [markdown]
# ### Actividad
#
# Actividades de programación básica:
# 1. Calcular el area de un cuadrado de lado 4.5 cm
# 2. Calcular el costo total de comprar 35 porciones de pizza si una porcion cuesta $6000
# 3. Calcular el resultado de multiplicar dos numeros ingresados por el usuario

# %%
# Actividad 1:
lado = 4.5

# Actividad 2:

# Actividad 3:

# %% [markdown]
# ## Tipos de Datos en Python:
#
# Dentro de la información que normalmente manejamos en el entorno laboral, debemos tratar de diferentes maneras los diferentes datos que allí encontramos: el **nombre** de un producto (texto), su **precio** (número con decimales) o su **cantidad en bodega** (número entero), cada uno de estos tiene un tipo de dato distinto.
#
# En Python ocurre exactamente lo mismo. Para que el computador pueda procesar y analizar la información correctamente, necesita saber qué **Tipo de Dato** está manejando:
#
# 1. **Enteros (`int`)**: Números sin decimales.
# 2. **Flotantes (`float`)**: Números con decimales.
# 3. **Cadenas de texto (`str`)**: Palabras o caracteres.
# 4. **Booleanos (`bool`)**: Valores lógicos (Verdadero o Falso).

# %%
# EJEMPLO PRÁCTICO: Creando el registro de un cliente o producto

# 1. Entero (int - Integer): Ideal para conteos exactos (ej. edad, cantidad de hijos, stock)
edad_cliente = 32
cantidad_compras = 5

# 2. Flotante (float): Ideal para dinero, promedios o mediciones exactas. 
# IMPORTANTE: En Python los decimales se separan con un PUNTO (.), no con coma.
total_gastado = 1450.75
calificacion_promedio = 4.8

# 3. Cadena de texto (str - String): Siempre debe ir entre comillas simples ('') o dobles ("")
nombre_cliente = "Ana Gómez"
categoria_producto = 'Electrónica'

# 4. Booleano (bool - Boolean): Solo puede ser True (Verdadero) o False (Falso). 
# Siempre deben escribirse con la primera letra en mayúscula. Se usan para estados.
es_cliente_frecuente = True
tiene_deudas = False

# %% [markdown]
# ### ¿Cómo saber qué tipo de dato estamos manejando?
#
# En la vida real, cuando importamos bases de datos inmensas (por ejemplo, desde un archivo CSV o Excel), no siempre sabemos con qué tipo de datos estamos tratando.
#
# Python nos ofrece una herramienta muy útil llamada la función `type()`. Al poner una variable dentro de los paréntesis, Python nos revelará su tipo de dato.

# %%
# Usemos la función print() para mostrar el resultado en pantalla, 
# junto con la función type() para descubrir el tipo de dato.

print("El tipo de dato de edad_cliente es:")
print(type(edad_cliente))

print("El tipo de dato de total_gastado es:")
print(type(total_gastado))

print("El tipo de dato de nombre_cliente es:")
print(type(nombre_cliente))

print("El tipo de dato de es_cliente_frecuente es:")
print(type(es_cliente_frecuente))

# %% [markdown]
# ### Actividad
#
# ¡Ahora es tu turno! La mejor forma de aprender a programar es haciéndolo. Imagina que trabajas en el departamento de Recursos Humanos o Ventas de tu empresa actual.
#
# **OBjetivo:**
# En la siguiente celda de código, crea 4 variables que representen a un empleado o a un producto de tu empresa. Debes crear:
# 1. Una variable de tipo `str` (texto).
# 2. Una variable de tipo `int` (entero).
# 3. Una variable de tipo `float` (decimal).
# 4. Una variable de tipo `bool` (Verdadero/Falso).
#
# Al final, usa `print()` para mostrar las variables en pantalla.

# %%
# Escribe tu código aquí abajo:
# 1. Variable de texto (str)


# 2. Variable entera (int)


# 3. Variable decimal (float)


# 4. Variable booleana (bool)


# 5. Imprime tus variables
